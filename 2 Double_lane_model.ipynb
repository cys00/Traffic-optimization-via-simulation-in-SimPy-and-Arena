# %%
#Double lane model overview:
# Similar to the triple lane model, 
#the double lane model includes a right lane where vehicles can either turn right or go straight ahead, 
#and a left lane where vehicles can either turn left or go straight ahead. 
#In order to hold constant the overall traffic flow, 
#the average interarrival time on the right lane and the left lane are ? minutes and ? minutes respectively. 
#The pedestrians’ behavior is assumed to be unchanged. 

# Import all necessary packages
# double-ended queue
from collections import deque 
import numpy as np
import simpy
from simpy.util import start_delayed
#print right turn in red, left turn in blue
from colorama import Fore, Back, Style 

#define a utility class to keep track of the statistics
class Stats(object): 
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)

#set a random seed to get reproducible results
random_seed = 0
np.random.seed(random_seed)

#pre-define some useful variables
#total number of minutes to be simulated:
end_time = 60

#cars arrive at the traffic light according to a Poisson process with an
#1 cars per 7.91 seconds
right_interarrival_mean = 15.82/60

p_interarrival_mean = 30/60 #interarrival time for pedestrian set to be 30 seconds

left_interarrival_mean = 15.82/60 #interarrival time for left-turning vehicles set to be 30 seconds

# Traffic light green and red durations:
t_green= 26/60
t_red= 90/60

# The time for a vehicle at the head of the queue to clear the intersection
#(including turn right at red light, turn right at green light, go straight, and turn left) 
#is modeled as four triangular distributions with specified lower bound, mode and upper bound.
#considering normal distribution has negative values which can't be used to model time in simulation,

#turn right at red light
r_t_r_mode = 10/60 
r_t_r_lower = 5/60 
r_t_r_upper = 15/60

#turn right at green light
r_t_mode = 3/60
r_t_lower = 2/60
r_t_upper = 4/60

#go straight 
str_mode = 2/60 
str_lower = 1.8/60
str_upper = 2.2/60

#turn left
l_mode = 30/60
l_lower = 20/60
l_upper = 40/60

#the time for a group of pedestrians to clear the intersection is modeled as a normal distribution
p_crossing_mode = 18/60 
p_crossing_lower = 13/60
p_crossing_upper = 23/60

# Initialize queues for the right-most lane, middle lane, traffic island and for the pedestrians
right_q = deque() 
left_q = deque()
pedestrian = deque()

# initialize the number of vehicles on different lanes and the number of pedestrians
pedestrian_count = r_arrival_count = l_arrival_count = departure_count = 0

#stats for the right lane
r_q_stats = Stats(count=0, cars_waiting=0)
r_w_stats = Stats(count=0, waiting_time=0.0)

#stats for the pedestrians
P_W_stats = Stats(count=0, waiting_time=0.0)
p_num_stats = Stats(count=0, pedestrian_waiting=0)

#stats for the left lane
l_w_stats = Stats(count=0, waiting_time=0)
l_q_stats = Stats(count=0, cars_waiting=0)

def Right_arrival(): #arrival event for the right lane 
    global r_arrival_count, env, light, right_q, right_turn_boolean

    while True:
        
        r_arrival_count+= 1
        right_turn_boolean = np.random.choice([False,True], 1, p=[0.6,0.4])    

        if len(right_q):
            right_q.append((r_arrival_count, env.now))
            print(f"At time {env.now}, vehicle {r_arrival_count} arrived on the right lane and joined the queue at position {len(right_q)}.")
        elif light == 'red':   
            #assume vehicles on the right lane turn right with a 40% chance
            if right_turn_boolean:
                print(Fore.RED + f'At time {env.now}, vehicle {r_arrival_count} arrived and started to turn right.')
                print(Style.RESET_ALL)
                r_w_stats.count += 1
            else:
                right_q.append((r_arrival_count, env.now))
                print(f"At time {env.now}, vehicle {r_arrival_count} arrived on the right lane and joined the queue at position {len(right_q)}.")
        elif right_turn_boolean:
            print(Fore.RED + f'At time {env.now}, vehicle {r_arrival_count} arrived and started to turn right.')
            print(Style.RESET_ALL)
            r_w_stats.count += 1
        else:
            print(f"At time {env.now}, vehicle {r_arrival_count} arrived on the right lane and started to go straight.")
            r_w_stats.count += 1

      # Schedule next arrival:
        yield env.timeout(np.random.exponential(right_interarrival_mean))

def Left_arrival(): #arrival event for the left lane 
    global l_arrival_count, env, light, left_q, left_turn_boolean

    while True:
        
        l_arrival_count+= 1
        left_turn_boolean = np.random.choice([False,True], 1, p=[0.6,0.4])    

        if len(left_q) or light == 'red':   
            left_q.append((l_arrival_count, env.now))
            print(f"At time {env.now}, vehicle {l_arrival_count} arrived on the left lane and joined the queue at position {len(left_q)}.")
        elif left_turn_boolean:
            print(Fore.BLUE + f'At time {env.now}, vehicle {l_arrival_count} arrived and started to turn left.')
            print(Style.RESET_ALL)
            l_w_stats.count += 1
        else:
            print(f"At time {env.now}, vehicle {l_arrival_count} arrived on the left lane and started to go straight.")
            l_w_stats.count += 1

      # Schedule next arrival:
        yield env.timeout(np.random.exponential(left_interarrival_mean))

def Right_departure(): #departure event for the right lane
    global env, right_q

    while True:
        # If the queue is empty, do not schedule the next departure.
        if len(right_q) == 0:
            return
        elif right_turn_boolean:
            if light == 'red':
                car_number, t_arrival= right_q.popleft()
                print(Fore.RED + f"At time {env.now}, {car_number} turned right at red light, leaving {len(right_q)} cars in the queue.")
                print(Style.RESET_ALL)
                r_w_stats.count += 1
                r_w_stats.waiting_time += env.now - t_arrival
                yield env.timeout(np.random.triangular(r_t_r_lower,r_t_r_mode,r_t_r_upper))
            else:
                car_number, t_arrival= right_q.popleft()
                print(Fore.RED +f"At time {env.now}, {car_number} turned right at green light, leaving {len(right_q)} cars in the queue.")
                print(Style.RESET_ALL)
                r_w_stats.count += 1
                r_w_stats.waiting_time += env.now - t_arrival
                yield env.timeout(np.random.triangular(r_t_lower,r_t_mode,r_t_upper))
        elif light == 'red':
            return
        else: #car in queue and car go straight and light is green     
            car_number, t_arrival= right_q.popleft()
            print(f"At time {env.now}, {car_number} departed straight ahead, leaving {len(right_q)} cars in the queue.")
            r_w_stats.count += 1
            r_w_stats.waiting_time += env.now - t_arrival
            yield env.timeout(np.random.triangular(str_lower,str_mode,str_upper))
                  
def Left_departure(): #departure event for the left lane
    global env, left_q

    while True:
        # If the queue is empty or light is red, do not schedule the next departure.
        if len(left_q) == 0 or light == 'red':
            return
        elif left_turn_boolean:
            car_number, t_arrival= left_q.popleft()
            print(Fore.BLUE + f"At time {env.now}, {car_number} turned left, leaving {len(left_q)} cars in the queue.")
            print(Style.RESET_ALL)
            l_w_stats.count += 1
            l_w_stats.waiting_time += env.now - t_arrival
            yield env.timeout(np.random.triangular(l_lower,l_mode,l_upper))
        else: #car in queue and car go straight and light is green     
            car_number, t_arrival= left_q.popleft()
            print(f"At time {env.now}, {car_number} departed straight ahead, leaving {len(left_q)} cars in the queue.")
            l_w_stats.count += 1
            l_w_stats.waiting_time += env.now - t_arrival
            yield env.timeout(np.random.triangular(str_lower,str_mode,str_upper))

def Pedestrian():
    
    global env, light, pedestrian, pedestrian_count
    
    while True:
        
        pedestrian_count += 1
        
        if light == 'red' and len(pedestrian): #assume red light for vehicles means green for pedestrians
            print(f'At time {env.now} pedestrian {pedestrian_count} arrived at the intersection and started to cross the road.')
            P_W_stats.count += 1
        else:
            pedestrian.append((pedestrian_count, env.now))
            print(f'At time{env.now}, pedestrian {pedestrian_count} arrived and started to wait.')
        
        yield env.timeout(np.random.exponential(p_interarrival_mean))
    
def pedestrian_cross():
    global env, pedestrian
    
    while True:
        
        pedestrian_idx, t_arrival = [i[0] for i in pedestrian], [i[1] for i in pedestrian]
        P_W_stats.count += len(pedestrian)
        P_W_stats.waiting_time += len(pedestrian)*env.now - sum(t_arrival)
        pedestrian = deque()
        print(f'Pedestrians {pedestrian_idx} crossed the road at time {env.now}.')
        
        if light == 'green' or len(pedestrian)==0: #assume green light for vehicles means red light for pedestrian
            return
        #schedule next crossing
        yield env.timeout(np.random.triangular(p_crossing_lower,p_crossing_mode,p_crossing_upper))

def light():
    
    global env, light

    while True:
        
        light = 'green'
        print(Back.GREEN + Style.BRIGHT + f"At time {env.now}, traffic light turned green.")
        print(Style.RESET_ALL)
        
        #right lane
        if len(right_q):
            if right_turn_boolean: #turn right
                start_delayed(env, Right_departure(), delay=np.random.triangular(r_t_lower,r_t_mode,r_t_upper))
            else: #go straight
                start_delayed(env, Right_departure(), delay=np.random.triangular(str_lower,str_mode,str_upper))
        
        #left lane
        if len(left_q):
            if left_turn_boolean: #turn left
                start_delayed(env, Left_departure(), delay=np.random.triangular(l_lower,l_mode,l_upper))
            else: #go straight
                start_delayed(env, Left_departure(), delay=np.random.triangular(str_lower,str_mode,str_upper))
             
        #schedule event that will turn the light red
        yield env.timeout(t_green)

        light = 'red'
        print(Back.RED + Style.BRIGHT +f"At time {env.now}, traffic light turned red.")
        print(Style.RESET_ALL)
        
        if len(pedestrian):
            start_delayed(env,pedestrian_cross(),delay=np.random.triangular(p_crossing_lower,p_crossing_mode,p_crossing_upper))
        
        if len(right_q) and right_turn_boolean:
            start_delayed(env, Right_departure(), delay=np.random.triangular(r_t_r_lower,r_t_r_mode,r_t_r_upper))

        #schedule event that will turn the light green:
        yield env.timeout(t_red)

#monitor the number of vehicles/pedestrians waiting per minute
def monitor(): 
    global env, r_q_stats, p_num_stats, l_q_stats
    while True:
                  
        r_q_stats.count += 1
        r_q_stats.cars_waiting += len(right_q)
                  
        p_num_stats.count += 1
        p_num_stats.pedestrian_waiting += len(pedestrian)
                  
        l_q_stats.count += 1
        l_q_stats.cars_waiting += len(left_q)
                  
        #check the number of vehicles on each lane and the number of pedestrians every min
        yield env.timeout(1) 


#schedule initial events and run the simulation

print("\nSimulation of vehicles & pedestrians arriving at intersection controlled by traffic light")
print('\nDouble lane model\n\n\n')

#initialize environment:
env= simpy.Environment()

#schedule the first change of the traffic light:
env.process(light())

#schedule first arrival of vehicle on each lane
start_delayed(env, Right_arrival(), delay=np.random.exponential(right_interarrival_mean))
start_delayed(env, Left_arrival(), delay=np.random.exponential(left_interarrival_mean))

#schedule first arrival of pedestrian
start_delayed(env, Pedestrian(), delay=np.random.exponential(p_interarrival_mean))

#schedule first statistical monitoring event:
env.process(monitor())

# Let the simulation run for specified time:
env.run(until=end_time)


# Report statistics.

print(f"\n\n      *** Statistical report(random seed={random_seed}) ***")
print('     ( double-lane with no distracted drivers)\n\n')
print('Right lane stats:')
print(f"Number of vehicles waiting in right lane per minute: {r_q_stats.cars_waiting / float(r_q_stats.count)}")
print(f"Average wait time for a vehicle on the right lane (minutes): {r_w_stats.waiting_time / float(r_w_stats.count)}")
print('\n\nLeft lane stats:')
print(f"Number of vehicles waiting in left lane per minute: {l_q_stats.cars_waiting / float(l_q_stats.count)}")
print(f"Average wait time for a vehicle on left lane (minutes): {l_w_stats.waiting_time / float(l_w_stats.count)}")
print('\n\nPedestrians stats:')
print(f"Number of pedestrians waiting to cross per minute: {p_num_stats.pedestrian_waiting / float(p_num_stats.count)}")
print(f"Average wait time for a pedestrian (minutes): {P_W_stats.waiting_time / float(P_W_stats.count)}")
# Out:
# Simulation of vehicles & pedestrians arriving at intersection controlled by traffic light
#
# Double lane model
#
#
#
# At time 0, traffic light turned green.
#
# At time 0.20984557865234, vehicle 1 arrived on the right lane and started to go straight.
# At time 0.3311470778353259, vehicle 1 arrived and started to turn left.
#
# At time 0.35513869747118665, vehicle 2 arrived and started to turn right.
#
# At time 0.43333333333333335, traffic light turned red.
#
# At time0.4616115729020344, pedestrian 1 arrived and started to wait.
# At time 0.4828923066827906, vehicle 2 arrived on the left lane and joined the queue at position 1.
# At time 0.6813473802306044, vehicle 3 arrived on the left lane and joined the queue at position 2.
# At time 0.703412623353161 pedestrian 2 arrived at the intersection and started to cross the road.
# At time 0.7402553008095849 pedestrian 3 arrived at the intersection and started to cross the road.
# At time 0.7858358153690852 pedestrian 4 arrived at the intersection and started to cross the road.
# At time 0.7960486087111976 pedestrian 5 arrived at the intersection and started to cross the road.
# At time 1.2291705428060422, vehicle 3 arrived and started to turn right.
#
# At time 1.3664203921489455, vehicle 4 arrived on the left lane and joined the queue at position 3.
# At time 1.6897924485186417 pedestrian 6 arrived at the intersection and started to cross the road.
# At time 1.7671334082153525, vehicle 4 arrived and started to turn right.
#
# At time 1.7896685558588006, vehicle 5 arrived on the left lane and joined the queue at position 4.
# At time 1.8003222948013389, vehicle 5 arrived and started to turn right.
#
# At time 1.8304656155379897, vehicle 6 arrived on the left lane and joined the queue at position 5.
# At time 1.911485201969506, vehicle 7 arrived on the left lane and joined the queue at position 6.
# At time 1.9333333333333333, traffic light turned green.
#
# At time 1.9948627538493546, vehicle 6 arrived on the right lane and started to go straight.
# At time1.999257177825126, pedestrian 7 arrived and started to wait.
# At time 2.0720799324014196, vehicle 8 arrived on the left lane and joined the queue at position 7.
# At time 2.248346858847066, vehicle 7 arrived and started to turn right.
#
# At time 2.3658152347638697, vehicle 8 arrived on the right lane and started to go straight.
# At time 2.3666666666666667, traffic light turned red.
#
# At time 2.472755516747015 pedestrian 8 arrived at the intersection and started to cross the road.
# Pedestrians [1, 7] crossed the road at time 2.61225503597581.
# At time 2.6811889916627014, vehicle 9 arrived and started to turn right.
#
# At time 2.743468826302435, vehicle 10 arrived on the right lane and joined the queue at position 1.
# At time 2.8308902081628027, vehicle 9 arrived on the left lane and joined the queue at position 8.
# At time 2.8433884647070857, vehicle 11 arrived on the right lane and joined the queue at position 2.
# At time3.022211756776035, pedestrian 9 arrived and started to wait.
# At time 3.053537666327759, vehicle 10 arrived on the left lane and joined the queue at position 9.
# At time 3.0760293130436804 pedestrian 10 arrived at the intersection and started to cross the road.
# At time 3.0999202065833495, vehicle 11 arrived on the left lane and joined the queue at position 10.
# At time 3.2654874701265784, vehicle 12 arrived on the left lane and joined the queue at position 11.
# At time 3.3111354085077807, vehicle 13 arrived on the left lane and joined the queue at position 12.
# At time 3.592750442551488, vehicle 14 arrived on the left lane and joined the queue at position 13.
# At time 3.605400675496888 pedestrian 11 arrived at the intersection and started to cross the road.
# At time 3.650461961464717, vehicle 15 arrived on the left lane and joined the queue at position 14.
# At time 3.677394163248607, vehicle 16 arrived on the left lane and joined the queue at position 15.
# At time 3.7040336676482544, vehicle 17 arrived on the left lane and joined the queue at position 16.
# At time 3.8354076582767482 pedestrian 12 arrived at the intersection and started to cross the road.
# At time 3.8666666666666667, traffic light turned green.
#
# At time 3.8707597518843597, vehicle 18 arrived on the left lane and joined the queue at position 17.
# At time 3.9003700225713085, 10 departed straight ahead, leaving 1 cars in the queue.
# At time 3.9320043526155852, 11 departed straight ahead, leaving 0 cars in the queue.
# At time 3.958405253227569, vehicle 19 arrived on the left lane and joined the queue at position 18.
# At time 4.017890940727673, vehicle 12 arrived on the right lane and started to go straight.
# At time 4.035371354269143, vehicle 13 arrived and started to turn right.
#
# At time 4.059310739100209, vehicle 20 arrived on the left lane and joined the queue at position 19.
# At time 4.254624182668765, vehicle 21 arrived on the left lane and joined the queue at position 20.
# At time 4.255822407028286, vehicle 14 arrived and started to turn right.
#
# At time 4.3, traffic light turned red.
#
# At time 4.3569544491816075, vehicle 15 arrived on the right lane and joined the queue at position 1.
# At time 4.480822666938926, vehicle 22 arrived on the left lane and joined the queue at position 21.
# At time 4.534175732103267, vehicle 23 arrived on the left lane and joined the queue at position 22.
# At time 4.5395314492328, vehicle 24 arrived on the left lane and joined the queue at position 23.
# At time 4.540772405514607, vehicle 25 arrived on the left lane and joined the queue at position 24.
# Pedestrians [9] crossed the road at time 4.615367898895803.
# At time 4.623754018401471, vehicle 26 arrived on the left lane and joined the queue at position 25.
# At time 4.689157002940375, vehicle 16 arrived on the right lane and joined the queue at position 2.
# At time 4.915486614541849, vehicle 17 arrived on the right lane and joined the queue at position 3.
# At time 5.139397837838267, vehicle 18 arrived on the right lane and joined the queue at position 4.
# At time 5.487300104330343, vehicle 27 arrived on the left lane and joined the queue at position 26.
# At time5.716371244336518, pedestrian 13 arrived and started to wait.
# At time 5.8, traffic light turned green.
#
# At time 5.83257093563105, 15 departed straight ahead, leaving 3 cars in the queue.
# At time 5.834632501916988, 2 departed straight ahead, leaving 25 cars in the queue.
# At time 5.865539308701519, 16 departed straight ahead, leaving 2 cars in the queue.
# At time 5.869673699059084, 3 departed straight ahead, leaving 24 cars in the queue.
# At time 5.899155557810742, 17 departed straight ahead, leaving 1 cars in the queue.
# At time 5.904719223205831, 4 departed straight ahead, leaving 23 cars in the queue.
# At time 5.933208294231284, 18 departed straight ahead, leaving 0 cars in the queue.
# At time 5.938914966877248, 5 departed straight ahead, leaving 22 cars in the queue.
# At time 5.944182780719513, vehicle 19 arrived and started to turn right.
#
# At time 5.974593747301287, 6 departed straight ahead, leaving 21 cars in the queue.
# At time 5.981269036903392, vehicle 28 arrived on the left lane and joined the queue at position 22.
# At time 6.008302912072126, 7 departed straight ahead, leaving 21 cars in the queue.
# At time 6.042221543228318, 8 departed straight ahead, leaving 20 cars in the queue.
# At time 6.074760473918416, 9 departed straight ahead, leaving 19 cars in the queue.
# At time 6.075906179655993, vehicle 29 arrived on the left lane and joined the queue at position 20.
# At time 6.089567525561512, vehicle 20 arrived on the right lane and started to go straight.
# At time 6.108513629640836, 10 departed straight ahead, leaving 19 cars in the queue.
# At time 6.1142891839782685, vehicle 30 arrived on the left lane and joined the queue at position 20.
# At time 6.142165048984859, 11 departed straight ahead, leaving 19 cars in the queue.
# At time 6.17605124115166, 12 departed straight ahead, leaving 18 cars in the queue.
# At time 6.20914754158007, 13 departed straight ahead, leaving 17 cars in the queue.
# At time 6.233333333333333, traffic light turned red.
#
# At time 6.312072785643984, vehicle 21 arrived on the right lane and joined the queue at position 1.
# At time 6.317490524364305 pedestrian 14 arrived at the intersection and started to cross the road.
# At time 6.393514661954987, vehicle 31 arrived on the left lane and joined the queue at position 18.
# At time 6.421361195875837, vehicle 32 arrived on the left lane and joined the queue at position 19.
# Pedestrians [13] crossed the road at time 6.521449464468864.
# At time 6.751632047688469, vehicle 33 arrived on the left lane and joined the queue at position 20.
# At time 6.794311793881244, vehicle 34 arrived on the left lane and joined the queue at position 21.
# At time 6.8410666382402265, vehicle 35 arrived on the left lane and joined the queue at position 22.
# At time 6.875919076477167, vehicle 36 arrived on the left lane and joined the queue at position 23.
# At time 6.898708609168086, vehicle 22 arrived on the right lane and joined the queue at position 2.
# At time 7.036572006900822, vehicle 23 arrived on the right lane and joined the queue at position 3.
# At time7.137939306230504, pedestrian 15 arrived and started to wait.
# At time 7.310104010682564, vehicle 37 arrived on the left lane and joined the queue at position 24.
# At time 7.35176930947481, vehicle 24 arrived on the right lane and joined the queue at position 4.
# At time 7.440088844378925 pedestrian 16 arrived at the intersection and started to cross the road.
# At time 7.445980461690085 pedestrian 17 arrived at the intersection and started to cross the road.
# At time 7.669106876171691 pedestrian 18 arrived at the intersection and started to cross the road.
# At time 7.733333333333333, traffic light turned green.
#
# At time 7.776431389944917, 21 turned right at green light, leaving 3 cars in the queue.
#
# At time 7.815259063211271, 22 turned right at green light, leaving 2 cars in the queue.
#
# At time 7.840805088655775, vehicle 38 arrived on the left lane and joined the queue at position 25.
# At time 7.85913323050108, 23 turned right at green light, leaving 1 cars in the queue.
#
# At time 7.862380173312836, vehicle 25 arrived on the right lane and joined the queue at position 2.
# At time 7.90362015538503, 24 departed straight ahead, leaving 1 cars in the queue.
# At time 7.937723900116455, 25 departed straight ahead, leaving 0 cars in the queue.
# At time 8.166666666666666, traffic light turned red.
#
# At time 8.25697991085754, vehicle 39 arrived on the left lane and joined the queue at position 26.
# At time 8.323756059476525 pedestrian 19 arrived at the intersection and started to cross the road.
# Pedestrians [15] crossed the road at time 8.431160301042448.
# At time8.459590098887638, pedestrian 20 arrived and started to wait.
# At time 8.483976778482479, vehicle 40 arrived on the left lane and joined the queue at position 27.
# At time 8.556408549695137, vehicle 26 arrived on the right lane and joined the queue at position 1.
# At time 8.686230117331055, vehicle 41 arrived on the left lane and joined the queue at position 28.
# At time 8.82013721908105, vehicle 42 arrived on the left lane and joined the queue at position 29.
# At time 8.874461002681945, vehicle 43 arrived on the left lane and joined the queue at position 30.
# At time 8.901755295764428, vehicle 27 arrived on the right lane and joined the queue at position 2.
# At time 8.969784660774947, vehicle 28 arrived on the right lane and joined the queue at position 3.
# At time 8.98554690739775, vehicle 29 arrived on the right lane and joined the queue at position 4.
# At time 9.084071178499356, vehicle 30 arrived on the right lane and joined the queue at position 5.
# At time 9.20915894124855, vehicle 31 arrived on the right lane and joined the queue at position 6.
# At time 9.21574753696802, vehicle 32 arrived on the right lane and joined the queue at position 7.
# At time 9.22918427437153, vehicle 44 arrived on the left lane and joined the queue at position 31.
# At time 9.431975529975022, vehicle 45 arrived on the left lane and joined the queue at position 32.
# At time 9.51567852107444, vehicle 33 arrived on the right lane and joined the queue at position 8.
# At time 9.666666666666666, traffic light turned green.
#
# At time 9.699085676458283, 26 departed straight ahead, leaving 7 cars in the queue.
# At time 9.733435154473138, 27 departed straight ahead, leaving 6 cars in the queue.
# At time 9.766101892600608, 28 departed straight ahead, leaving 5 cars in the queue.
# At time 9.799021039714146, 29 departed straight ahead, leaving 4 cars in the queue.
# At time 9.802522656373984, vehicle 34 arrived on the right lane and joined the queue at position 5.
# At time9.820264197738338, pedestrian 21 arrived and started to wait.
# At time 9.832663056221257, 30 turned right at green light, leaving 4 cars in the queue.
#
# At time 9.878323911492101, 31 turned right at green light, leaving 3 cars in the queue.
#
# At time 9.934398307232195, 32 turned right at green light, leaving 2 cars in the queue.
#
# At time 9.977886987933786, 33 turned right at green light, leaving 1 cars in the queue.
#
# At time 10.033871488719807, 14 turned left, leaving 31 cars in the queue.
#
# At time 10.039432438217814, 34 turned right at green light, leaving 0 cars in the queue.
#
# At time 10.063949284462527, vehicle 35 arrived and started to turn right.
#
# At time 10.1, traffic light turned red.
#
# Pedestrians [20, 21] crossed the road at time 10.376054942094264.
# At time 10.41001389608546, vehicle 36 arrived on the right lane and joined the queue at position 1.
# At time 10.60255059190066, vehicle 37 arrived on the right lane and joined the queue at position 2.
# At time 10.655297284373574, vehicle 46 arrived on the left lane and joined the queue at position 32.
# At time 10.663859687324003, vehicle 38 arrived on the right lane and joined the queue at position 3.
# At time 10.749608309962735, vehicle 39 arrived on the right lane and joined the queue at position 4.
# At time 10.778871649292892, vehicle 47 arrived on the left lane and joined the queue at position 33.
# At time10.850674809932778, pedestrian 22 arrived and started to wait.
# At time 10.921495825398525 pedestrian 23 arrived at the intersection and started to cross the road.
# At time 10.970959100313703, vehicle 48 arrived on the left lane and joined the queue at position 34.
# At time 11.190693165625053, vehicle 49 arrived on the left lane and joined the queue at position 35.
# At time 11.231950609431383, vehicle 50 arrived on the left lane and joined the queue at position 36.
# At time 11.27536998834228, vehicle 40 arrived on the right lane and joined the queue at position 5.
# At time 11.347820348544694, vehicle 51 arrived on the left lane and joined the queue at position 37.
# At time 11.552402164421274 pedestrian 24 arrived at the intersection and started to cross the road.
# At time 11.595956456428505 pedestrian 25 arrived at the intersection and started to cross the road.
# At time 11.6, traffic light turned green.
#
# At time 11.651473028907462, 36 turned right at green light, leaving 4 cars in the queue.
#
# At time 11.6575692659381, vehicle 41 arrived on the right lane and joined the queue at position 5.
# At time 11.68543545016254, vehicle 42 arrived on the right lane and joined the queue at position 6.
# At time 11.697546228078057, 37 departed straight ahead, leaving 5 cars in the queue.
# At time 11.731504539551338, 38 departed straight ahead, leaving 4 cars in the queue.
# At time 11.765986170810324, 39 departed straight ahead, leaving 3 cars in the queue.
# At time 11.798488303703827, 40 departed straight ahead, leaving 2 cars in the queue.
# At time 11.832123323096178, 41 departed straight ahead, leaving 1 cars in the queue.
# At time 11.863315475828013, 42 departed straight ahead, leaving 0 cars in the queue.
# At time 11.964930062782459, vehicle 52 arrived on the left lane and joined the queue at position 38.
# At time11.997652336049972, pedestrian 26 arrived and started to wait.
# At time 12.033333333333333, traffic light turned red.
#
# At time 12.204017266245305 pedestrian 27 arrived at the intersection and started to cross the road.
# At time 12.335805823287751 pedestrian 28 arrived at the intersection and started to cross the road.
# At time 12.384826707118853, vehicle 43 arrived and started to turn right.
#
# Pedestrians [22, 26] crossed the road at time 12.393563683015408.
# At time 12.516403818598464, vehicle 53 arrived on the left lane and joined the queue at position 39.
# At time 12.808132671181088, vehicle 44 arrived on the right lane and joined the queue at position 1.
# At time 13.063185584170084, vehicle 54 arrived on the left lane and joined the queue at position 40.
# At time 13.066699007316325, vehicle 55 arrived on the left lane and joined the queue at position 41.
# At time 13.108973763848983, vehicle 56 arrived on the left lane and joined the queue at position 42.
# At time 13.28056733003316, vehicle 57 arrived on the left lane and joined the queue at position 43.
# At time 13.306489487700135, vehicle 45 arrived on the right lane and joined the queue at position 2.
# At time 13.345307821805967, vehicle 46 arrived on the right lane and joined the queue at position 3.
# At time 13.400818431510505, vehicle 47 arrived on the right lane and joined the queue at position 4.
# At time 13.467792766627761, vehicle 48 arrived on the right lane and joined the queue at position 5.
# At time 13.533333333333333, traffic light turned green.
#
# At time 13.549556658826432, vehicle 58 arrived on the left lane and joined the queue at position 44.
# At time 13.569067079353893, 15 turned left, leaving 43 cars in the queue.
#
# At time 13.569224249310139, 44 departed straight ahead, leaving 4 cars in the queue.
# At time 13.600566729518874, 45 departed straight ahead, leaving 3 cars in the queue.
# At time 13.63357501870198, 46 departed straight ahead, leaving 2 cars in the queue.
# At time 13.66584674903697, 47 departed straight ahead, leaving 1 cars in the queue.
# At time 13.697562607324034, 48 departed straight ahead, leaving 0 cars in the queue.
# At time13.826906167346769, pedestrian 29 arrived and started to wait.
# At time 13.941742299841852, vehicle 59 arrived on the left lane and joined the queue at position 44.
# At time 13.966666666666667, traffic light turned red.
#
# At time 13.990351192899062, vehicle 49 arrived on the right lane and joined the queue at position 1.
# At time 14.015102782181298, vehicle 50 arrived on the right lane and joined the queue at position 2.
# At time 14.089331281782673, vehicle 51 arrived on the right lane and joined the queue at position 3.
# Pedestrians [29] crossed the road at time 14.228509938236323.
# At time 14.304224451212082, vehicle 52 arrived on the right lane and joined the queue at position 4.
# At time 14.329913462497455, vehicle 60 arrived on the left lane and joined the queue at position 45.
# At time 14.367081995744373, vehicle 61 arrived on the left lane and joined the queue at position 46.
# At time 14.461728130252787, vehicle 62 arrived on the left lane and joined the queue at position 47.
# At time14.473480089721836, pedestrian 30 arrived and started to wait.
# At time 14.622318126303604, vehicle 63 arrived on the left lane and joined the queue at position 48.
# At time 14.646581282695466, vehicle 53 arrived on the right lane and joined the queue at position 5.
# At time 14.699276525841446, vehicle 54 arrived on the right lane and joined the queue at position 6.
# At time 14.710225472492004, vehicle 64 arrived on the left lane and joined the queue at position 49.
# At time 14.714708382847917, vehicle 55 arrived on the right lane and joined the queue at position 7.
# At time 14.793894095244546, vehicle 56 arrived on the right lane and joined the queue at position 8.
# At time 15.02743965125189, vehicle 57 arrived on the right lane and joined the queue at position 9.
# At time 15.048350786222807 pedestrian 31 arrived at the intersection and started to cross the road.
# At time 15.1078915541527, vehicle 65 arrived on the left lane and joined the queue at position 50.
# At time 15.119924787621374, vehicle 66 arrived on the left lane and joined the queue at position 51.
# At time 15.1410389135048, vehicle 67 arrived on the left lane and joined the queue at position 52.
# At time 15.149620154816064, vehicle 58 arrived on the right lane and joined the queue at position 10.
# At time 15.158084868255006 pedestrian 32 arrived at the intersection and started to cross the road.
# At time 15.237659903819463, vehicle 68 arrived on the left lane and joined the queue at position 53.
# At time 15.38605814867765, vehicle 69 arrived on the left lane and joined the queue at position 54.
# At time 15.466666666666667, traffic light turned green.
#
# At time 15.499150374010904, 16 departed straight ahead, leaving 53 cars in the queue.
# At time 15.500672475120082, 49 departed straight ahead, leaving 9 cars in the queue.
# At time 15.530842582071834, 17 departed straight ahead, leaving 52 cars in the queue.
# At time 15.533626476837327, 50 departed straight ahead, leaving 8 cars in the queue.
# At time 15.565665708129046, 51 departed straight ahead, leaving 7 cars in the queue.
# At time 15.566524991802714, 18 departed straight ahead, leaving 51 cars in the queue.
# At time 15.588620943783637, vehicle 70 arrived on the left lane and joined the queue at position 52.
# At time 15.600007691517002, 19 departed straight ahead, leaving 51 cars in the queue.
# At time 15.600871659255136, 52 departed straight ahead, leaving 6 cars in the queue.
# At time 15.633200057277753, 20 departed straight ahead, leaving 50 cars in the queue.
# At time 15.635062521390887, 53 departed straight ahead, leaving 5 cars in the queue.
# At time 15.666177846620736, 21 departed straight ahead, leaving 49 cars in the queue.
# At time 15.670268932318164, 54 departed straight ahead, leaving 4 cars in the queue.
# At time15.676707419973553, pedestrian 33 arrived and started to wait.
# At time 15.700219949917118, 22 departed straight ahead, leaving 48 cars in the queue.
# At time 15.704351984179738, 55 departed straight ahead, leaving 3 cars in the queue.
# At time 15.734561768405884, 23 departed straight ahead, leaving 47 cars in the queue.
# At time 15.73817479218234, 56 departed straight ahead, leaving 2 cars in the queue.
# At time 15.766871267020926, 24 departed straight ahead, leaving 46 cars in the queue.
# At time 15.770063582638839, 57 departed straight ahead, leaving 1 cars in the queue.
# At time 15.8014108150027, 25 departed straight ahead, leaving 45 cars in the queue.
# At time 15.805777669218879, 58 departed straight ahead, leaving 0 cars in the queue.
# At time 15.834601561440135, 26 departed straight ahead, leaving 44 cars in the queue.
# At time 15.86949010577751, 27 departed straight ahead, leaving 43 cars in the queue.
# At time15.875247897913708, pedestrian 34 arrived and started to wait.
# At time 15.9, traffic light turned red.
#
# At time 15.994621395902419, vehicle 59 arrived and started to turn right.
#
# At time 16.152187785568824, vehicle 71 arrived on the left lane and joined the queue at position 44.
# At time 16.19797523259036, vehicle 72 arrived on the left lane and joined the queue at position 45.
# Pedestrians [30, 33, 34] crossed the road at time 16.20657172201883.
# At time 16.331975761912087, vehicle 73 arrived on the left lane and joined the queue at position 46.
# At time 16.477441614465455, vehicle 74 arrived on the left lane and joined the queue at position 47.
# At time 16.626150487078608, vehicle 60 arrived on the right lane and joined the queue at position 1.
# At time 16.975963872962748, vehicle 75 arrived on the left lane and joined the queue at position 48.
# At time 17.092281691633882, vehicle 76 arrived on the left lane and joined the queue at position 49.
# At time 17.146294406301443, vehicle 77 arrived on the left lane and joined the queue at position 50.
# At time17.392219205626308, pedestrian 35 arrived and started to wait.
# At time 17.4, traffic light turned green.
#
# At time 17.43496365319733, 28 departed straight ahead, leaving 49 cars in the queue.
# At time 17.435564159760453, 60 departed straight ahead, leaving 0 cars in the queue.
# At time17.444685581552363, pedestrian 36 arrived and started to wait.
# At time 17.468140522365086, 29 departed straight ahead, leaving 48 cars in the queue.
# At time 17.468239036918785, vehicle 61 arrived on the right lane and started to go straight.
# At time 17.47238628183185, vehicle 62 arrived on the right lane and started to go straight.
# At time 17.49097529491895, vehicle 63 arrived on the right lane and started to go straight.
# At time 17.501880168196983, 30 departed straight ahead, leaving 47 cars in the queue.
# At time 17.534252186529883, 31 departed straight ahead, leaving 46 cars in the queue.
# At time 17.556878994723636, vehicle 64 arrived on the right lane and started to go straight.
# At time 17.565958744021284, 32 departed straight ahead, leaving 45 cars in the queue.
# At time17.577153048488046, pedestrian 37 arrived and started to wait.
# At time 17.589234852930794, vehicle 65 arrived and started to turn right.
#
# At time 17.59971367298423, 33 departed straight ahead, leaving 44 cars in the queue.
# At time 17.631616620557786, 34 departed straight ahead, leaving 43 cars in the queue.
# At time 17.665449999998813, 35 departed straight ahead, leaving 42 cars in the queue.
# At time 17.698750859639535, 36 departed straight ahead, leaving 41 cars in the queue.
# At time 17.72793163992422, vehicle 66 arrived on the right lane and started to go straight.
# At time 17.734932409534107, 37 departed straight ahead, leaving 40 cars in the queue.
# At time 17.76746398127835, 38 departed straight ahead, leaving 39 cars in the queue.
# At time 17.79978019763783, 39 departed straight ahead, leaving 38 cars in the queue.
# At time 17.833333333333332, traffic light turned red.
#
# At time 17.84479705933478, vehicle 78 arrived on the left lane and joined the queue at position 39.
# At time 18.036845948294644, vehicle 79 arrived on the left lane and joined the queue at position 40.
# Pedestrians [35, 36, 37] crossed the road at time 18.108459765959037.
# At time 18.131061855405267, vehicle 67 arrived on the right lane and joined the queue at position 1.
# At time 18.250146926352244, vehicle 80 arrived on the left lane and joined the queue at position 41.
# At time 18.368042814484244, vehicle 81 arrived on the left lane and joined the queue at position 42.
# At time 18.454352047572605, vehicle 68 arrived on the right lane and joined the queue at position 2.
# At time 18.52416630772584, vehicle 69 arrived on the right lane and joined the queue at position 3.
# At time 18.969029526952387, vehicle 70 arrived on the right lane and joined the queue at position 4.
# At time 19.050893626558448, vehicle 82 arrived on the left lane and joined the queue at position 43.
# At time 19.143642960243987, vehicle 83 arrived on the left lane and joined the queue at position 44.
# At time 19.219291324348923, vehicle 84 arrived on the left lane and joined the queue at position 45.
# At time 19.333333333333332, traffic light turned green.
#
# At time 19.367374349879775, 40 departed straight ahead, leaving 44 cars in the queue.
# At time 19.37805428800321, 67 turned right at green light, leaving 3 cars in the queue.
#
# At time 19.39851312465002, 41 departed straight ahead, leaving 43 cars in the queue.
# At time19.406934026223624, pedestrian 38 arrived and started to wait.
# At time 19.432489599224127, 68 turned right at green light, leaving 2 cars in the queue.
#
# At time 19.43355854496714, 42 departed straight ahead, leaving 42 cars in the queue.
# At time 19.466442586049144, 43 departed straight ahead, leaving 41 cars in the queue.
# At time 19.480334554261717, 69 turned right at green light, leaving 1 cars in the queue.
#
# At time 19.50074652480812, 44 departed straight ahead, leaving 40 cars in the queue.
# At time 19.525162022392585, 70 turned right at green light, leaving 0 cars in the queue.
#
# At time 19.532700740189448, 45 departed straight ahead, leaving 39 cars in the queue.
# At time 19.565301886976613, 46 departed straight ahead, leaving 38 cars in the queue.
# At time19.565961297259015, pedestrian 39 arrived and started to wait.
# At time 19.6000781634558, 47 departed straight ahead, leaving 37 cars in the queue.
# At time 19.633419471186084, 48 departed straight ahead, leaving 36 cars in the queue.
# At time 19.66895657156133, 49 departed straight ahead, leaving 35 cars in the queue.
# At time19.701696282096954, pedestrian 40 arrived and started to wait.
# At time 19.70277132930684, 50 departed straight ahead, leaving 34 cars in the queue.
# At time 19.73828531493788, 51 departed straight ahead, leaving 33 cars in the queue.
# At time 19.766666666666666, traffic light turned red.
#
# At time 19.884705823266493, vehicle 71 arrived and started to turn right.
#
# At time 20.01423797321179, vehicle 85 arrived on the left lane and joined the queue at position 34.
# At time 20.0336191543001, vehicle 86 arrived on the left lane and joined the queue at position 35.
# At time 20.0772014127743, vehicle 87 arrived on the left lane and joined the queue at position 36.
# Pedestrians [38, 39, 40] crossed the road at time 20.08540457749972.
# At time 20.114311218197802, vehicle 88 arrived on the left lane and joined the queue at position 37.
# At time 20.24155021686655, vehicle 89 arrived on the left lane and joined the queue at position 38.
# At time20.711488533380763, pedestrian 41 arrived and started to wait.
# At time 21.10729308616679 pedestrian 42 arrived at the intersection and started to cross the road.
# At time 21.147409578235692, vehicle 90 arrived on the left lane and joined the queue at position 39.
# At time 21.25185168742016, vehicle 72 arrived on the right lane and joined the queue at position 1.
# At time 21.266666666666666, traffic light turned green.
#
# At time21.267963237079776, pedestrian 43 arrived and started to wait.
# At time 21.299123642077415, 72 departed straight ahead, leaving 0 cars in the queue.
# At time 21.299848015609943, 52 departed straight ahead, leaving 38 cars in the queue.
# At time 21.333200961252427, 53 departed straight ahead, leaving 37 cars in the queue.
# At time 21.36582724221387, 54 departed straight ahead, leaving 36 cars in the queue.
# At time 21.39870641981204, 55 departed straight ahead, leaving 35 cars in the queue.
# At time 21.43212405394665, 56 departed straight ahead, leaving 34 cars in the queue.
# At time 21.463612086818294, vehicle 73 arrived on the right lane and started to go straight.
# At time 21.46643650464536, 57 departed straight ahead, leaving 33 cars in the queue.
# At time 21.50135400355332, 58 departed straight ahead, leaving 32 cars in the queue.
# At time21.524806038033145, pedestrian 44 arrived and started to wait.
# At time 21.532394199004777, 59 departed straight ahead, leaving 31 cars in the queue.
# At time 21.565542868962638, 60 departed straight ahead, leaving 30 cars in the queue.
# At time 21.597067685080823, 61 departed straight ahead, leaving 29 cars in the queue.
# At time 21.62985047340684, 62 departed straight ahead, leaving 28 cars in the queue.
# At time 21.664113890077807, 63 departed straight ahead, leaving 27 cars in the queue.
# At time21.671081339807635, pedestrian 45 arrived and started to wait.
# At time 21.69811603461155, 64 departed straight ahead, leaving 26 cars in the queue.
# At time 21.7, traffic light turned red.
#
# At time 21.74612014732045, vehicle 91 arrived on the left lane and joined the queue at position 27.
# Pedestrians [41, 43, 44, 45] crossed the road at time 21.970016102641985.
# At time 22.043472984776937, vehicle 92 arrived on the left lane and joined the queue at position 28.
# At time 22.143638256211723, vehicle 74 arrived on the right lane and joined the queue at position 1.
# At time 22.151733289812974, vehicle 75 arrived on the right lane and joined the queue at position 2.
# At time 22.15382030307238, vehicle 76 arrived on the right lane and joined the queue at position 3.
# At time22.15802064363425, pedestrian 46 arrived and started to wait.
# At time 22.25033443369542, vehicle 93 arrived on the left lane and joined the queue at position 29.
# At time 22.353196137054518, vehicle 77 arrived on the right lane and joined the queue at position 4.
# At time 22.387646460644277, vehicle 94 arrived on the left lane and joined the queue at position 30.
# At time 22.463798852849436, vehicle 78 arrived on the right lane and joined the queue at position 5.
# At time 22.473920932890717, vehicle 95 arrived on the left lane and joined the queue at position 31.
# At time 22.496219982165073, vehicle 79 arrived on the right lane and joined the queue at position 6.
# At time 22.787243721335493, vehicle 96 arrived on the left lane and joined the queue at position 32.
# At time 23.061943380048664, vehicle 97 arrived on the left lane and joined the queue at position 33.
# At time 23.2, traffic light turned green.
#
# At time 23.262118792916844, 74 turned right at green light, leaving 5 cars in the queue.
#
# At time 23.280155895667253, vehicle 80 arrived on the right lane and joined the queue at position 6.
# At time 23.296218783967, vehicle 98 arrived on the left lane and joined the queue at position 34.
# At time 23.315800049623384, 75 turned right at green light, leaving 5 cars in the queue.
#
# At time 23.35648347462782, 76 turned right at green light, leaving 4 cars in the queue.
#
# At time 23.405487652044812, 77 turned right at green light, leaving 3 cars in the queue.
#
# At time23.434258879283153, pedestrian 47 arrived and started to wait.
# At time 23.455823576988017, 78 turned right at green light, leaving 2 cars in the queue.
#
# At time 23.468138756596687, vehicle 81 arrived on the right lane and joined the queue at position 3.
# At time 23.496262687784185, 79 departed straight ahead, leaving 2 cars in the queue.
# At time 23.530036046743668, 80 departed straight ahead, leaving 1 cars in the queue.
# At time 23.563948936989384, 65 departed straight ahead, leaving 33 cars in the queue.
# At time 23.56511778986656, 81 departed straight ahead, leaving 0 cars in the queue.
# At time 23.597705186229867, 66 departed straight ahead, leaving 32 cars in the queue.
# At time 23.607392723529884, vehicle 82 arrived and started to turn right.
#
# At time 23.633333333333333, traffic light turned red.
#
# At time 23.708766560998814, vehicle 99 arrived on the left lane and joined the queue at position 33.
# At time 23.79159119600731, vehicle 83 arrived and started to turn right.
#
# Pedestrians [46, 47] crossed the road at time 23.983826139070043.
# At time24.026272748907246, pedestrian 48 arrived and started to wait.
# At time 24.3858448124676, vehicle 100 arrived on the left lane and joined the queue at position 34.
# At time 24.43649401168014, vehicle 101 arrived on the left lane and joined the queue at position 35.
# At time 24.70150749739546, vehicle 84 arrived on the right lane and joined the queue at position 1.
# At time 24.747625502901304, vehicle 85 arrived on the right lane and joined the queue at position 2.
# At time 24.903532337764254, vehicle 86 arrived on the right lane and joined the queue at position 3.
# At time 24.949575864917612, vehicle 87 arrived on the right lane and joined the queue at position 4.
# At time 25.10257888771016, vehicle 88 arrived on the right lane and joined the queue at position 5.
# At time 25.133333333333333, traffic light turned green.
#
# At time 25.16427160032423, 67 departed straight ahead, leaving 34 cars in the queue.
# At time 25.165678061488812, 84 departed straight ahead, leaving 4 cars in the queue.
# At time 25.19542576474781, 68 departed straight ahead, leaving 33 cars in the queue.
# At time 25.196843094030722, 85 departed straight ahead, leaving 3 cars in the queue.
# At time 25.230660517058602, 69 departed straight ahead, leaving 32 cars in the queue.
# At time 25.231105523316934, 86 departed straight ahead, leaving 2 cars in the queue.
# At time 25.237917165311046, vehicle 102 arrived on the left lane and joined the queue at position 33.
# At time 25.26507479334279, 87 departed straight ahead, leaving 1 cars in the queue.
# At time 25.26582209869418, 70 departed straight ahead, leaving 32 cars in the queue.
# At time25.28778147772002, pedestrian 49 arrived and started to wait.
# At time 25.2986591122215, 71 departed straight ahead, leaving 31 cars in the queue.
# At time 25.301528661269312, 88 departed straight ahead, leaving 0 cars in the queue.
# At time 25.33155832734488, 72 departed straight ahead, leaving 30 cars in the queue.
# At time 25.333640597846127, vehicle 103 arrived on the left lane and joined the queue at position 31.
# At time 25.36352842821875, 73 departed straight ahead, leaving 30 cars in the queue.
# At time 25.394713592233078, 74 departed straight ahead, leaving 29 cars in the queue.
# At time 25.41693606203433, vehicle 89 arrived on the right lane and started to go straight.
# At time 25.42842597528292, 75 departed straight ahead, leaving 28 cars in the queue.
# At time 25.460727729594183, 76 departed straight ahead, leaving 27 cars in the queue.
# At time 25.494109794960163, 77 departed straight ahead, leaving 26 cars in the queue.
# At time 25.505020524679985, vehicle 90 arrived on the right lane and started to go straight.
# At time 25.526969194977017, 78 departed straight ahead, leaving 25 cars in the queue.
# At time 25.56282611125136, 79 departed straight ahead, leaving 24 cars in the queue.
# At time 25.566666666666666, traffic light turned red.
#
# At time 25.605833205292498 pedestrian 50 arrived at the intersection and started to cross the road.
# At time 25.613572244529422, vehicle 91 arrived on the right lane and joined the queue at position 1.
# At time 25.63435888007339, vehicle 104 arrived on the left lane and joined the queue at position 25.
# At time 25.81616704377511 pedestrian 51 arrived at the intersection and started to cross the road.
# Pedestrians [48, 49] crossed the road at time 25.82000074870038.
# At time 25.897380526093855, vehicle 92 arrived on the right lane and joined the queue at position 2.
# At time26.033016777240352, pedestrian 52 arrived and started to wait.
# At time 26.164991370181177, vehicle 93 arrived on the right lane and joined the queue at position 3.
# At time 26.746482053029464, vehicle 94 arrived on the right lane and joined the queue at position 4.
# At time 26.87148414842793 pedestrian 53 arrived at the intersection and started to cross the road.
# At time 27.062394632107154, vehicle 95 arrived on the right lane and joined the queue at position 5.
# At time 27.066666666666666, traffic light turned green.
#
# At time27.075842971625207, pedestrian 54 arrived and started to wait.
# At time 27.07944954172683, vehicle 96 arrived on the right lane and joined the queue at position 6.
# At time 27.0989851992687, 91 turned right at green light, leaving 5 cars in the queue.
#
# At time 27.09976606259771, 80 departed straight ahead, leaving 24 cars in the queue.
# At time 27.131308096897616, 81 departed straight ahead, leaving 23 cars in the queue.
# At time 27.14039182466031, 92 turned right at green light, leaving 4 cars in the queue.
#
# At time 27.164955178320554, 82 departed straight ahead, leaving 22 cars in the queue.
# At time 27.195165404491604, 93 turned right at green light, leaving 3 cars in the queue.
#
# At time 27.199784881190002, 83 departed straight ahead, leaving 21 cars in the queue.
# At time 27.235844665884997, 84 departed straight ahead, leaving 20 cars in the queue.
# At time 27.255861405841575, 94 turned right at green light, leaving 2 cars in the queue.
#
# At time 27.268825350713932, 85 departed straight ahead, leaving 19 cars in the queue.
# At time 27.300637707538606, 86 departed straight ahead, leaving 18 cars in the queue.
# At time 27.303730808938845, 95 turned right at green light, leaving 1 cars in the queue.
#
# At time 27.334658347576884, 87 departed straight ahead, leaving 17 cars in the queue.
# At time 27.356588500232, 96 turned right at green light, leaving 0 cars in the queue.
#
# At time 27.369574221380944, 88 departed straight ahead, leaving 16 cars in the queue.
# At time 27.402900136151768, 89 departed straight ahead, leaving 15 cars in the queue.
# At time 27.4365156898327, 90 departed straight ahead, leaving 14 cars in the queue.
# At time27.444911347009153, pedestrian 55 arrived and started to wait.
# At time 27.468832570110813, 91 departed straight ahead, leaving 13 cars in the queue.
# At time 27.5, traffic light turned red.
#
# At time 27.537489375785817 pedestrian 56 arrived at the intersection and started to cross the road.
# At time 27.54158564935322, vehicle 105 arrived on the left lane and joined the queue at position 14.
# At time 27.702621168405962, vehicle 106 arrived on the left lane and joined the queue at position 15.
# Pedestrians [52, 54, 55] crossed the road at time 27.745179559032216.
# At time 27.847937873280596, vehicle 107 arrived on the left lane and joined the queue at position 16.
# At time27.855514613798206, pedestrian 57 arrived and started to wait.
# At time 27.8808401826108, vehicle 108 arrived on the left lane and joined the queue at position 17.
# At time 27.919988327509042, vehicle 97 arrived and started to turn right.
#
# At time 28.01372830933845 pedestrian 58 arrived at the intersection and started to cross the road.
# At time 28.015445330969, vehicle 109 arrived on the left lane and joined the queue at position 18.
# At time 28.031437537062764, vehicle 98 arrived on the right lane and joined the queue at position 1.
# At time 28.149764647827112, vehicle 110 arrived on the left lane and joined the queue at position 19.
# At time 28.28278726398168, vehicle 99 arrived on the right lane and joined the queue at position 2.
# At time 28.605449040412317, vehicle 111 arrived on the left lane and joined the queue at position 20.
# At time 28.624467050367276, vehicle 100 arrived on the right lane and joined the queue at position 3.
# At time 28.63631650756345, vehicle 112 arrived on the left lane and joined the queue at position 21.
# At time 28.639202636735128 pedestrian 59 arrived at the intersection and started to cross the road.
# At time 28.644334082866727, vehicle 113 arrived on the left lane and joined the queue at position 22.
# At time 28.761526768801275, vehicle 101 arrived on the right lane and joined the queue at position 4.
# At time 28.89012065310817, vehicle 114 arrived on the left lane and joined the queue at position 23.
# At time 28.918868721137937, vehicle 115 arrived on the left lane and joined the queue at position 24.
# At time 28.92667977924839, vehicle 116 arrived on the left lane and joined the queue at position 25.
# At time 29.0, traffic light turned green.
#
# At time 29.02711099877949, vehicle 102 arrived on the right lane and joined the queue at position 5.
# At time 29.032201902461896, vehicle 103 arrived on the right lane and joined the queue at position 6.
# At time 29.03284839087931, 92 departed straight ahead, leaving 24 cars in the queue.
# At time 29.050408059722, 98 departed straight ahead, leaving 5 cars in the queue.
# At time 29.063238929006886, vehicle 117 arrived on the left lane and joined the queue at position 25.
# At time 29.065728267249128, 93 departed straight ahead, leaving 24 cars in the queue.
# At time 29.082633487611016, 99 departed straight ahead, leaving 4 cars in the queue.
# At time 29.08675036994342, vehicle 118 arrived on the left lane and joined the queue at position 25.
# At time 29.09794635674884, 94 departed straight ahead, leaving 24 cars in the queue.
# At time 29.104795420575243, vehicle 119 arrived on the left lane and joined the queue at position 25.
# At time 29.114124304396253, 100 departed straight ahead, leaving 3 cars in the queue.
# At time 29.12915378622421, 95 turned left, leaving 24 cars in the queue.
#
# At time 29.14766289890484, 101 departed straight ahead, leaving 2 cars in the queue.
# At time 29.151432964613935, vehicle 120 arrived on the left lane and joined the queue at position 25.
# At time 29.180847617854027, 102 departed straight ahead, leaving 1 cars in the queue.
# At time 29.21013540973671, vehicle 121 arrived on the left lane and joined the queue at position 26.
# At time 29.213949531980933, 103 departed straight ahead, leaving 0 cars in the queue.
# At time29.307486844859998, pedestrian 60 arrived and started to wait.
# At time 29.323491562467243, vehicle 122 arrived on the left lane and joined the queue at position 27.
# At time 29.331238074298824, vehicle 123 arrived on the left lane and joined the queue at position 28.
# At time 29.433333333333334, traffic light turned red.
#
# At time 29.462680216529545, vehicle 124 arrived on the left lane and joined the queue at position 29.
# At time 29.52000876168529, vehicle 104 arrived and started to turn right.
#
# At time 29.63955876483011, vehicle 105 arrived on the right lane and joined the queue at position 1.
# At time 29.764069745591033, vehicle 106 arrived on the right lane and joined the queue at position 2.
# Pedestrians [57, 60] crossed the road at time 29.775565925827845.
# At time 29.84378359767603, vehicle 107 arrived on the right lane and joined the queue at position 3.
# At time30.002681509607797, pedestrian 61 arrived and started to wait.
# At time 30.145651991027453, vehicle 108 arrived on the right lane and joined the queue at position 4.
# At time 30.165089912433512 pedestrian 62 arrived at the intersection and started to cross the road.
# At time 30.1785736365611, vehicle 109 arrived on the right lane and joined the queue at position 5.
# At time 30.252174523327422 pedestrian 63 arrived at the intersection and started to cross the road.
# At time 30.254108434276873 pedestrian 64 arrived at the intersection and started to cross the road.
# At time 30.35246877937506 pedestrian 65 arrived at the intersection and started to cross the road.
# At time 30.61490350071885, vehicle 125 arrived on the left lane and joined the queue at position 30.
# At time 30.82696194838568 pedestrian 66 arrived at the intersection and started to cross the road.
# At time 30.933333333333334, traffic light turned green.
#
# At time 30.966692216409204, 96 departed straight ahead, leaving 29 cars in the queue.
# At time 30.96913577229644, 105 departed straight ahead, leaving 4 cars in the queue.
# At time 30.9992759418984, 97 departed straight ahead, leaving 28 cars in the queue.
# At time 31.00263840698123, 106 departed straight ahead, leaving 3 cars in the queue.
# At time 31.034702704601923, 98 departed straight ahead, leaving 27 cars in the queue.
# At time 31.036041678814435, 107 departed straight ahead, leaving 2 cars in the queue.
# At time 31.06713949224991, 99 departed straight ahead, leaving 26 cars in the queue.
# At time 31.071057748209903, 108 departed straight ahead, leaving 1 cars in the queue.
# At time 31.10001435939085, 100 departed straight ahead, leaving 25 cars in the queue.
# At time 31.10123307964202, 109 departed straight ahead, leaving 0 cars in the queue.
# At time 31.1096443044889, vehicle 110 arrived and started to turn right.
#
# At time 31.132360443705394, 101 departed straight ahead, leaving 24 cars in the queue.
# At time 31.16550364549766, 102 departed straight ahead, leaving 23 cars in the queue.
# At time 31.17814663795591, vehicle 126 arrived on the left lane and joined the queue at position 24.
# At time 31.19823658151106, 103 turned left, leaving 23 cars in the queue.
#
# At time 31.271382199971736, vehicle 111 arrived on the right lane and started to go straight.
# At time 31.366666666666667, traffic light turned red.
#
# At time 31.462766956385856 pedestrian 67 arrived at the intersection and started to cross the road.
# Pedestrians [61] crossed the road at time 31.696236057316227.
# At time 31.94301966162874, vehicle 127 arrived on the left lane and joined the queue at position 24.
# At time 32.007335784561576, vehicle 128 arrived on the left lane and joined the queue at position 25.
# At time32.025793357530254, pedestrian 68 arrived and started to wait.
# At time 32.1640891964262, vehicle 112 arrived on the right lane and joined the queue at position 1.
# At time 32.19991767469519 pedestrian 69 arrived at the intersection and started to cross the road.
# At time 32.34368186554963, vehicle 113 arrived on the right lane and joined the queue at position 2.
# At time 32.38316468754251, vehicle 114 arrived on the right lane and joined the queue at position 3.
# At time 32.682531785720116, vehicle 129 arrived on the left lane and joined the queue at position 26.
# ...
# At time 50.33151956815899, 174 departed straight ahead, leaving 27 cars in the queue.
# At time 50.3346069174881, 168 departed straight ahead, leaving 0 cars in the queue.
# At time 50.363462186684885, 175 departed straight ahead, leaving 26 cars in the queue.
# At time 50.39788415157015, 176 departed straight ahead, leaving 25 cars in the queue.
# At time 50.431451329923625, 177 departed straight ahead, leaving 24 cars in the queue.
# At time 50.46750334465476, 178 departed straight ahead, leaving 23 cars in the queue.
# At time 50.503541923876845, 179 departed straight ahead, leaving 22 cars in the queue.
# At time 50.508967632439614, vehicle 202 arrived on the left lane and joined the queue at position 23.
# At time 50.53980491282454, 180 departed straight ahead, leaving 22 cars in the queue.
# At time 50.57213619577615, 181 departed straight ahead, leaving 21 cars in the queue.
# At time 50.60532719791675, 182 departed straight ahead, leaving 20 cars in the queue.
# At time 50.618458133882825, vehicle 169 arrived on the right lane and started to go straight.
# At time 50.63967201932023, 183 departed straight ahead, leaving 19 cars in the queue.
# At time 50.67170407765396, 184 departed straight ahead, leaving 18 cars in the queue.
# At time 50.69999999999997, traffic light turned red.
#
# At time 50.83873291036037, vehicle 170 arrived on the right lane and joined the queue at position 1.
# At time 50.839963101068065, vehicle 171 arrived on the right lane and joined the queue at position 2.
# At time 50.930318920064565 pedestrian 106 arrived at the intersection and started to cross the road.
# Pedestrians [104] crossed the road at time 50.95690184551646.
# At time 51.12768431857167, vehicle 172 arrived on the right lane and joined the queue at position 3.
# At time 51.144754097057465, vehicle 173 arrived on the right lane and joined the queue at position 4.
# At time51.18714053564934, pedestrian 107 arrived and started to wait.
# At time 51.19366474812758, vehicle 174 arrived on the right lane and joined the queue at position 5.
# At time 51.24321620168088, vehicle 203 arrived on the left lane and joined the queue at position 19.
# At time 51.46530609384108, vehicle 204 arrived on the left lane and joined the queue at position 20.
# At time 51.62532136094562, vehicle 175 arrived on the right lane and joined the queue at position 6.
# At time 52.0342081611239, vehicle 176 arrived on the right lane and joined the queue at position 7.
# At time 52.16698403802008, vehicle 177 arrived on the right lane and joined the queue at position 8.
# At time 52.19999999999997, traffic light turned green.
#
# At time 52.2330460874759, 185 departed straight ahead, leaving 19 cars in the queue.
# At time 52.24146136924974, 170 turned right at green light, leaving 7 cars in the queue.
#
# At time 52.26750963376799, 186 departed straight ahead, leaving 18 cars in the queue.
# At time 52.29508424265506, 171 turned right at green light, leaving 6 cars in the queue.
#
# At time 52.30281281087423, 187 departed straight ahead, leaving 17 cars in the queue.
# At time 52.337161402268194, 188 departed straight ahead, leaving 16 cars in the queue.
# At time 52.340421681400514, 172 turned right at green light, leaving 5 cars in the queue.
#
# At time 52.370358189570034, 189 departed straight ahead, leaving 15 cars in the queue.
# At time 52.3916973288057, 173 turned right at green light, leaving 4 cars in the queue.
#
# At time 52.40583799939836, vehicle 205 arrived on the left lane and joined the queue at position 16.
# At time 52.40602537504913, 190 turned left, leaving 15 cars in the queue.
#
# At time 52.407471634304805, vehicle 178 arrived on the right lane and joined the queue at position 5.
# At time 52.45497171010612, 174 turned right at green light, leaving 4 cars in the queue.
# At time 52.49276116797021, 175 turned right at green light, leaving 3 cars in the queue.
#
# At time 52.52313731322925, vehicle 206 arrived on the left lane and joined the queue at position 16.
# At time 52.548127100250504, 176 turned right at green light, leaving 2 cars in the queue.
#
# At time 52.55568216646119, vehicle 179 arrived on the right lane and joined the queue at position 3.
# At time 52.60296214261202, 177 turned right at green light, leaving 2 cars in the queue.
#
# At time 52.6333333333333, traffic light turned red.
#
# At time 52.64997084393786, vehicle 180 arrived on the right lane and joined the queue at position 3.
# At time 52.655663428479556, vehicle 181 arrived on the right lane and joined the queue at position 4.
# At time 52.74677653860117, vehicle 182 arrived on the right lane and joined the queue at position 5.
# At time 52.78646557727121, vehicle 183 arrived on the right lane and joined the queue at position 6.
# At time 52.80028234297356, vehicle 184 arrived on the right lane and joined the queue at position 7.
# At time 52.86470274878762 pedestrian 108 arrived at the intersection and started to cross the road.
# At time 52.90209523010578, vehicle 185 arrived on the right lane and joined the queue at position 8.
# At time 52.92988546262323, vehicle 207 arrived on the left lane and joined the queue at position 17.
# Pedestrians [107] crossed the road at time 52.937508450316415.
# At time 53.02931550086672, vehicle 186 arrived on the right lane and joined the queue at position 9.
# At time 53.072900800870144, vehicle 187 arrived on the right lane and joined the queue at position 10.
# At time 53.10074925422203, vehicle 188 arrived on the right lane and joined the queue at position 11.
# At time 53.192641600365654, vehicle 189 arrived on the right lane and joined the queue at position 12.
# At time 53.3986955238915, vehicle 208 arrived on the left lane and joined the queue at position 18.
# At time 53.61107394096063, vehicle 190 arrived on the right lane and joined the queue at position 13.
# At time 53.63821323456189, vehicle 191 arrived on the right lane and joined the queue at position 14.
# At time 54.02475148498619, vehicle 192 arrived on the right lane and joined the queue at position 15.
# At time 54.03931408163744, vehicle 193 arrived on the right lane and joined the queue at position 16.
# At time 54.08762967110019, vehicle 194 arrived on the right lane and joined the queue at position 17.
# At time 54.13127642299169, vehicle 209 arrived on the left lane and joined the queue at position 19.
# At time 54.1333333333333, traffic light turned green.
#
# At time 54.188813391294126, 178 turned right at green light, leaving 16 cars in the queue.
#
# At time 54.24085074731675, 179 turned right at green light, leaving 15 cars in the queue.
#
# At time 54.27872583776792, 180 turned right at green light, leaving 14 cars in the queue.
#
# At time 54.31487297784957, 181 turned right at green light, leaving 13 cars in the queue.
#
# At time54.331618590742664, pedestrian 109 arrived and started to wait.
# At time 54.361992453081434, 182 turned right at green light, leaving 12 cars in the queue.
#
# At time 54.405542177707545, vehicle 195 arrived on the right lane and joined the queue at position 13.
# At time 54.42003533823432, 183 turned right at green light, leaving 12 cars in the queue.
#
# At time 54.42329714063297, vehicle 196 arrived on the right lane and joined the queue at position 13.
# At time 54.45834478735474, 184 turned right at green light, leaving 12 cars in the queue.
#
# At time 54.509341018315375, 185 turned right at green light, leaving 11 cars in the queue.
#
# At time 54.5192482427673, vehicle 197 arrived on the right lane and joined the queue at position 12.
# At time 54.56666666666663, traffic light turned red.
#
# At time 54.8082873748218, vehicle 198 arrived on the right lane and joined the queue at position 13.
# Pedestrians [109] crossed the road at time 54.85795083608641.
# At time 55.006082746844655, vehicle 199 arrived on the right lane and joined the queue at position 14.
# At time 55.02733555457414, vehicle 210 arrived on the left lane and joined the queue at position 20.
# At time 55.089533649500495, vehicle 200 arrived on the right lane and joined the queue at position 15.
# At time55.19875568250895, pedestrian 110 arrived and started to wait.
# At time 55.227714754070696, vehicle 211 arrived on the left lane and joined the queue at position 21.
# At time 55.276502731847835, vehicle 212 arrived on the left lane and joined the queue at position 22.
# At time 55.4173166858651, vehicle 213 arrived on the left lane and joined the queue at position 23.
# At time 55.509817146575585, vehicle 214 arrived on the left lane and joined the queue at position 24.
# At time 55.62580001258379, vehicle 215 arrived on the left lane and joined the queue at position 25.
# At time 55.79098356115434 pedestrian 111 arrived at the intersection and started to cross the road.
# At time 55.83011423534867 pedestrian 112 arrived at the intersection and started to cross the road.
# At time 55.85302243153805, vehicle 216 arrived on the left lane and joined the queue at position 26.
# At time 55.87085274057809 pedestrian 113 arrived at the intersection and started to cross the road.
# At time 55.8756381499987, vehicle 201 arrived on the right lane and joined the queue at position 16.
# At time 56.06666666666663, traffic light turned green.
#
# At time 56.10016493479615, 191 departed straight ahead, leaving 25 cars in the queue.
# At time 56.112630490288815, 186 turned right at green light, leaving 15 cars in the queue.
#
# At time 56.13364605298507, 192 departed straight ahead, leaving 24 cars in the queue.
# At time 56.16727016188374, 187 turned right at green light, leaving 14 cars in the queue.
#
# At time 56.16933372435162, 193 departed straight ahead, leaving 23 cars in the queue.
# At time 56.203857089684966, 194 departed straight ahead, leaving 22 cars in the queue.
# At time 56.21303083838526, 188 turned right at green light, leaving 13 cars in the queue.
#
# At time 56.236647732895904, vehicle 217 arrived on the left lane and joined the queue at position 23.
# At time 56.237774900219925, 195 turned left, leaving 22 cars in the queue.
#
# At time 56.25996364108898, vehicle 202 arrived on the right lane and joined the queue at position 14.
# At time 56.26442657898787, 189 departed straight ahead, leaving 13 cars in the queue.
# At time 56.295791141212426, 190 departed straight ahead, leaving 12 cars in the queue.
# At time 56.32917866063473, 191 departed straight ahead, leaving 11 cars in the queue.
# At time 56.36138904409388, 192 departed straight ahead, leaving 10 cars in the queue.
# At time 56.39385794265101, 193 departed straight ahead, leaving 9 cars in the queue.
# At time 56.42795055278262, 194 departed straight ahead, leaving 8 cars in the queue.
# At time56.454325222199614, pedestrian 114 arrived and started to wait.
# At time 56.458769668474744, 195 departed straight ahead, leaving 7 cars in the queue.
# At time 56.49191248729213, 196 departed straight ahead, leaving 6 cars in the queue.
# At time 56.49999999999996, traffic light turned red.
#
# At time 56.63219899308368, vehicle 203 arrived on the right lane and joined the queue at position 7.
# At time 56.74370392056152, vehicle 204 arrived on the right lane and joined the queue at position 8.
# Pedestrians [110, 114] crossed the road at time 56.80340697518733.
# At time 56.84476245000229, vehicle 205 arrived on the right lane and joined the queue at position 9.
# At time 56.99679438609147, vehicle 218 arrived on the left lane and joined the queue at position 23.
# At time 57.05892061525979, vehicle 206 arrived on the right lane and joined the queue at position 10.
# At time 57.314127628101126, vehicle 207 arrived on the right lane and joined the queue at position 11.
# At time57.487368492816294, pedestrian 115 arrived and started to wait.
# At time 57.83306237144245, vehicle 219 arrived on the left lane and joined the queue at position 24.
# At time 57.93227514251458, vehicle 220 arrived on the left lane and joined the queue at position 25.
# At time 57.99152849465969, vehicle 221 arrived on the left lane and joined the queue at position 26.
# At time 57.99999999999996, traffic light turned green.
#
# At time 58.03162172359622, 196 departed straight ahead, leaving 25 cars in the queue.
# At time 58.05968060725486, 197 turned right at green light, leaving 10 cars in the queue.
#
# At time 58.062369910876555, 197 departed straight ahead, leaving 24 cars in the queue.
# At time 58.095829537121304, 198 departed straight ahead, leaving 23 cars in the queue.
# At time 58.11884311464551, 198 turned right at green light, leaving 9 cars in the queue.
#
# At time 58.12793872278938, 199 departed straight ahead, leaving 22 cars in the queue.
# At time 58.16179360148368, 200 departed straight ahead, leaving 21 cars in the queue.
# At time 58.17204487362145, 199 turned right at green light, leaving 8 cars in the queue.
#
# At time 58.19344072427366, 201 departed straight ahead, leaving 20 cars in the queue.
# At time 58.21738746804542, 200 turned right at green light, leaving 7 cars in the queue.
#
# At time 58.224596174780444, 202 departed straight ahead, leaving 19 cars in the queue.
# At time 58.256310854373794, 203 departed straight ahead, leaving 18 cars in the queue.
# At time 58.26151844705502, 201 turned right at green light, leaving 6 cars in the queue.
#
# At time 58.28838308501558, 204 departed straight ahead, leaving 17 cars in the queue.
# At time 58.314966169947965, 202 turned right at green light, leaving 5 cars in the queue.
#
# At time 58.319431891154444, 205 departed straight ahead, leaving 16 cars in the queue.
# At time 58.35115863271059, 206 departed straight ahead, leaving 15 cars in the queue.
# At time 58.35582186310785, 203 turned right at green light, leaving 4 cars in the queue.
#
# At time 58.383810848224535, 207 departed straight ahead, leaving 14 cars in the queue.
# At time 58.40203822383841, 204 turned right at green light, leaving 3 cars in the queue.
#
# At time 58.41619162207313, 208 departed straight ahead, leaving 13 cars in the queue.
# At time 58.42818960060266, vehicle 208 arrived on the right lane and joined the queue at position 4.
# At time 58.43333333333329, traffic light turned red.
#
# At time 58.5788066768622 pedestrian 116 arrived at the intersection and started to cross the road.
# At time 58.63521325617858 pedestrian 117 arrived at the intersection and started to cross the road.
# Pedestrians [115] crossed the road at time 58.72421909309283.
# At time58.89799157794422, pedestrian 118 arrived and started to wait.
# At time 59.07357079575634 pedestrian 119 arrived at the intersection and started to cross the road.
# At time 59.189139541956926, vehicle 209 arrived on the right lane and joined the queue at position 5.
# At time 59.215658632385086, vehicle 222 arrived on the left lane and joined the queue at position 14.
# At time 59.352120578875585, vehicle 210 arrived on the right lane and joined the queue at position 6.
# At time 59.4135944380951 pedestrian 120 arrived at the intersection and started to cross the road.
# At time 59.484196115493965 pedestrian 121 arrived at the intersection and started to cross the road.
# At time 59.529496244804754, vehicle 211 arrived on the right lane and joined the queue at position 7.
# At time 59.61790701035502, vehicle 212 arrived on the right lane and joined the queue at position 8.
# At time 59.737126489069624 pedestrian 122 arrived at the intersection and started to cross the road.
# At time 59.78538434916551, vehicle 223 arrived on the left lane and joined the queue at position 15.
# At time 59.93333333333329, traffic light turned green.
#
# At time 59.9680888981513, 205 departed straight ahead, leaving 7 cars in the queue.
#
#
#       *** Statistical report(random seed=0) ***
#      ( double-lane with no distracted drivers)
#
#
# Right lane stats:
# Number of vehicles waiting in right lane per minute: 2.75
# Average wait time for a vehicle on the right lane (minutes): 0.8370137583941529
#
#
# Left lane stats:
# Number of vehicles waiting in left lane per minute: 27.1
# Average wait time for a vehicle on left lane (minutes): 7.648598889921294
#
#
# Pedestrians stats:
# Number of pedestrians waiting to cross per minute: 0.95
# Average wait time for a pedestrian (minutes): 0.46734376771099223

# %%
# Import all necessary packages
# double-ended queue
from collections import deque 
import numpy as np
import simpy
from simpy.util import start_delayed
#print right turn in red, left turn in blue
from colorama import Fore, Back, Style 

#define a utility class to keep track of the statistics
class Stats(object): 
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)

#set a random seed to get reproducible results
random_seed = 0
np.random.seed(random_seed)

#pre-define some useful variables
#total number of minutes to be simulated:
end_time = 60

#cars arrive at the traffic light according to a Poisson process with an
#1 cars per 7.91 seconds
right_interarrival_mean = 15.82/60

p_interarrival_mean = 30/60 #interarrival time for pedestrian set to be 30 seconds

left_interarrival_mean = 15.82/60 #interarrival time for left-turning vehicles set to be 30 seconds

# Traffic light green and red durations:
t_green= 26/60
t_red= 90/60

# The time for a vehicle at the head of the queue to clear the intersection
#(including turn right at red light, turn right at green light, go straight, and turn left) 
#is modeled as four triangular distributions with specified lower bound, mode and upper bound.
#considering normal distribution has negative values which can't be used to model time in simulation,

#turn right at red light
r_t_r_mode = 10/60 
r_t_r_lower = 5/60 
r_t_r_upper = 15/60

#turn right at green light
r_t_mode = 3/60
r_t_lower = 2/60
r_t_upper = 4/60

#go straight 
str_mode = 2/60 
str_lower = 1.8/60
str_upper = 2.2/60

#turn left
l_mode = 30/60
l_lower = 20/60
l_upper = 40/60

#the time for a group of pedestrians to clear the intersection is modeled as a normal distribution
p_crossing_mode = 18/60 
p_crossing_lower = 13/60
p_crossing_upper = 23/60

# Initialize queues for the right-most lane, middle lane, traffic island and for the pedestrians
right_q = deque() 
left_q = deque()
pedestrian = deque()

# initialize the number of vehicles on different lanes and the number of pedestrians
pedestrian_count = r_arrival_count = l_arrival_count = departure_count = 0

#stats for the right lane
r_q_stats = Stats(count=0, cars_waiting=0)
r_w_stats = Stats(count=0, waiting_time=0.0)

#stats for the pedestrians
P_W_stats = Stats(count=0, waiting_time=0.0)
p_num_stats = Stats(count=0, pedestrian_waiting=0)

#stats for the left lane
l_w_stats = Stats(count=0, waiting_time=0)
l_q_stats = Stats(count=0, cars_waiting=0)

distracted_p = 0.2

def Right_arrival(): #arrival event for the right lane 
    global r_arrival_count, env, light, right_q, right_turn_boolean, distracted_boolean
    distracted_boolean = np.random.choice([True,False],p=[distracted_p,1-distracted_p])

    while True:
        
        r_arrival_count+= 1
        right_turn_boolean = np.random.choice([False,True], 1, p=[0.6,0.4])    

        if len(right_q):
            right_q.append((r_arrival_count, env.now))
            print(f"At time {env.now}, vehicle {r_arrival_count} arrived on the right lane and joined the queue at position {len(right_q)}.")
        elif light == 'red':   
            #assume vehicles on the right lane turn right with a 40% chance
            if right_turn_boolean:
                print(Fore.RED + f'At time {env.now}, vehicle {r_arrival_count} arrived and started to turn right.')
                print(Style.RESET_ALL)
                r_w_stats.count += 1
            else:
                right_q.append((r_arrival_count, env.now))
                print(f"At time {env.now}, vehicle {r_arrival_count} arrived on the right lane and joined the queue at position {len(right_q)}.")
        elif right_turn_boolean:
            print(Fore.RED + f'At time {env.now}, vehicle {r_arrival_count} arrived and started to turn right.')
            print(Style.RESET_ALL)
            r_w_stats.count += 1
        else:
            print(f"At time {env.now}, vehicle {r_arrival_count} arrived on the right lane and started to go straight.")
            r_w_stats.count += 1

      # Schedule next arrival:
        if distracted_boolean:
            print(Fore.YELLOW + 'Watch out! Distracted driver!')
            print(Style.RESET_ALL)
            yield env.timeout(np.random.exponential(right_interarrival_mean) + 1)
        else:
            yield env.timeout(np.random.exponential(right_interarrival_mean))

def Left_arrival(): #arrival event for the left lane 
    global l_arrival_count, env, light, left_q, left_turn_boolean, distracted_boolean
    distracted_boolean = np.random.choice([True,False],p=[distracted_p,1-distracted_p])

    while True:
        
        l_arrival_count+= 1
        left_turn_boolean = np.random.choice([False,True], 1, p=[0.6,0.4])    

        if len(left_q) or light == 'red':   
            left_q.append((l_arrival_count, env.now))
            print(f"At time {env.now}, vehicle {l_arrival_count} arrived on the left lane and joined the queue at position {len(left_q)}.")
        elif left_turn_boolean:
            print(Fore.BLUE + f'At time {env.now}, vehicle {l_arrival_count} arrived and started to turn left.')
            print(Style.RESET_ALL)
            l_w_stats.count += 1
        else:
            print(f"At time {env.now}, vehicle {l_arrival_count} arrived on the left lane and started to go straight.")
            l_w_stats.count += 1

      # Schedule next arrival:
        if distracted_boolean:
            print(Fore.YELLOW + 'Watch out! Distracted driver!')
            print(Style.RESET_ALL)
            yield env.timeout(np.random.exponential(left_interarrival_mean) + 1)
        else:
            yield env.timeout(np.random.exponential(left_interarrival_mean))

def Right_departure(): #departure event for the right lane
    global env, right_q, distracted_boolean
    distracted_boolean = np.random.choice([True,False],p=[distracted_p,1-distracted_p])

    while True:
        # If the queue is empty, do not schedule the next departure.
        if len(right_q) == 0:
            return
        elif right_turn_boolean:
            if light == 'red':
                car_number, t_arrival= right_q.popleft()
                print(Fore.RED + f"At time {env.now}, {car_number} turned right at red light, leaving {len(right_q)} cars in the queue.")
                print(Style.RESET_ALL)
                r_w_stats.count += 1
                r_w_stats.waiting_time += env.now - t_arrival
                if distracted_boolean:
                    print(Fore.YELLOW + 'Watch out! Distracted driver!')
                    print(Style.RESET_ALL)
                    yield env.timeout(np.random.triangular(r_t_r_lower,r_t_r_mode,r_t_r_upper) + 1)
                else:
                    yield env.timeout(np.random.triangular(r_t_r_lower,r_t_r_mode,r_t_r_upper))
            else:
                car_number, t_arrival= right_q.popleft()
                print(Fore.RED +f"At time {env.now}, {car_number} turned right at green light, leaving {len(right_q)} cars in the queue.")
                print(Style.RESET_ALL)
                r_w_stats.count += 1
                r_w_stats.waiting_time += env.now - t_arrival
                if distracted_boolean:
                    print(Fore.YELLOW + 'Watch out! Distracted driver!')
                    print(Style.RESET_ALL)
                    yield env.timeout(np.random.triangular(r_t_lower,r_t_mode,r_t_upper) + 1)
                else:
                    yield env.timeout(np.random.triangular(r_t_lower,r_t_mode,r_t_upper))
        elif light == 'red':
            return
        else: #car in queue and car go straight and light is green     
            car_number, t_arrival= right_q.popleft()
            print(f"At time {env.now}, {car_number} departed straight ahead, leaving {len(right_q)} cars in the queue.")
            r_w_stats.count += 1
            r_w_stats.waiting_time += env.now - t_arrival
            if distracted_boolean:
                print(Fore.YELLOW + 'Watch out! Distracted driver!')
                print(Style.RESET_ALL)
                yield env.timeout(np.random.triangular(str_lower,str_mode,str_upper) + 1)
            else:
                yield env.timeout(np.random.triangular(str_lower,str_mode,str_upper))
                  
def Left_departure(): #departure event for the left lane
    global env, left_q, distracted_boolean
    distracted_boolean = np.random.choice([True,False],p=[distracted_p,1-distracted_p])

    while True:
        # If the queue is empty or light is red, do not schedule the next departure.
        if len(left_q) == 0 or light == 'red':
            return
        elif left_turn_boolean:
            car_number, t_arrival= left_q.popleft()
            print(Fore.BLUE + f"At time {env.now}, {car_number} turned left, leaving {len(left_q)} cars in the queue.")
            print(Style.RESET_ALL)
            l_w_stats.count += 1
            l_w_stats.waiting_time += env.now - t_arrival
            if distracted_boolean:
                print(Fore.YELLOW + 'Watch out! Distracted driver!')
                print(Style.RESET_ALL)
                yield env.timeout(np.random.triangular(l_lower,l_mode,l_upper) + 1)
            else:
                yield env.timeout(np.random.triangular(l_lower,l_mode,l_upper))
        else: #car in queue and car go straight and light is green     
            car_number, t_arrival= left_q.popleft()
            print(f"At time {env.now}, {car_number} departed straight ahead, leaving {len(left_q)} cars in the queue.")
            l_w_stats.count += 1
            l_w_stats.waiting_time += env.now - t_arrival
            if distracted_boolean:
                print(Fore.YELLOW + 'Watch out! Distracted driver!')
                print(Style.RESET_ALL)
                yield env.timeout(np.random.triangular(str_lower,str_mode,str_upper) + 1)
            else:
                yield env.timeout(np.random.triangular(str_lower,str_mode,str_upper))

def Pedestrian():
    
    global env, light, pedestrian, pedestrian_count
    
    while True:
        
        pedestrian_count += 1
        
        if light == 'red' and len(pedestrian): #assume red light for vehicles means green for pedestrians
            print(f'At time {env.now} pedestrian {pedestrian_count} arrived at the intersection and started to cross the road.')
            P_W_stats.count += 1
        else:
            pedestrian.append((pedestrian_count, env.now))
            print(f'At time{env.now}, pedestrian {pedestrian_count} arrived and started to wait.')
        
        yield env.timeout(np.random.exponential(p_interarrival_mean))
    
def pedestrian_cross():
    global env, pedestrian
    
    while True:
        
        pedestrian_idx, t_arrival = [i[0] for i in pedestrian], [i[1] for i in pedestrian]
        P_W_stats.count += len(pedestrian)
        P_W_stats.waiting_time += len(pedestrian)*env.now - sum(t_arrival)
        pedestrian = deque()
        print(f'Pedestrians {pedestrian_idx} crossed the road at time {env.now}.')
        
        if light == 'green' or len(pedestrian)==0: #assume green light for vehicles means red light for pedestrian
            return
        #schedule next crossing
        yield env.timeout(np.random.triangular(p_crossing_lower,p_crossing_mode,p_crossing_upper))

def light():
    
    global env, light

    while True:
        
        light = 'green'
        print(Back.GREEN + Style.BRIGHT + f"At time {env.now}, traffic light turned green.")
        print(Style.RESET_ALL)
        
        #right lane
        if len(right_q):
            if right_turn_boolean: #turn right
                if distracted_boolean:
                    start_delayed(env, Right_departure(), delay=np.random.triangular(r_t_lower,r_t_mode,r_t_upper) + 1)
                else:
                    start_delayed(env, Right_departure(), delay=np.random.triangular(r_t_lower,r_t_mode,r_t_upper))
            else: #go straight
                if distracted_boolean:
                    start_delayed(env, Right_departure(), delay=np.random.triangular(str_lower,str_mode,str_upper) + 1)
                else:
                    start_delayed(env, Right_departure(), delay=np.random.triangular(str_lower,str_mode,str_upper))
        
        #left lane
        if len(left_q):
            if left_turn_boolean: #turn left
                if distracted_boolean:
                    start_delayed(env, Left_departure(), delay=np.random.triangular(l_lower,l_mode,l_upper) + 1)
                else:
                    start_delayed(env, Left_departure(), delay=np.random.triangular(l_lower,l_mode,l_upper))
            else: #go straight
                if distracted_boolean:
                    start_delayed(env, Left_departure(), delay=np.random.triangular(str_lower,str_mode,str_upper) + 1)
                else:
                    start_delayed(env, Left_departure(), delay=np.random.triangular(str_lower,str_mode,str_upper))
             
        #schedule event that will turn the light red
        yield env.timeout(t_green)

        light = 'red'
        print(Back.RED + Style.BRIGHT +f"At time {env.now}, traffic light turned red.")
        print(Style.RESET_ALL)
        
        if len(pedestrian):
            start_delayed(env,pedestrian_cross(),delay=np.random.triangular(p_crossing_lower,p_crossing_mode,p_crossing_upper))
        
        if len(right_q) and right_turn_boolean:
            if distracted_boolean:
                start_delayed(env, Right_departure(), delay=np.random.triangular(r_t_r_lower,r_t_r_mode,r_t_r_upper) + 1)
            else:
                start_delayed(env, Right_departure(), delay=np.random.triangular(r_t_r_lower,r_t_r_mode,r_t_r_upper))

        #schedule event that will turn the light green:
        yield env.timeout(t_red)

#monitor the number of vehicles/pedestrians waiting per minute
def monitor(): 
    global env, r_q_stats, p_num_stats, l_q_stats
    while True:
                  
        r_q_stats.count += 1
        r_q_stats.cars_waiting += len(right_q)
                  
        p_num_stats.count += 1
        p_num_stats.pedestrian_waiting += len(pedestrian)
                  
        l_q_stats.count += 1
        l_q_stats.cars_waiting += len(left_q)
                  
        #check the number of vehicles on each lane and the number of pedestrians every min
        yield env.timeout(1) 


#schedule initial events and run the simulation

print("\nSimulation of vehicles & pedestrians arriving at intersection controlled by traffic light")
print('\nDouble lane model\n\n\n')

#initialize environment:
env= simpy.Environment()

#schedule the first change of the traffic light:
env.process(light())

#schedule first arrival of vehicle on each lane
start_delayed(env, Right_arrival(), delay=np.random.exponential(right_interarrival_mean))
start_delayed(env, Left_arrival(), delay=np.random.exponential(left_interarrival_mean))

#schedule first arrival of pedestrian
start_delayed(env, Pedestrian(), delay=np.random.exponential(p_interarrival_mean))

#schedule first statistical monitoring event:
env.process(monitor())

# Let the simulation run for specified time:
env.run(until=end_time)


# Report statistics.

print(f"\n\n      *** Statistical report(random seed={random_seed}) ***")
print(f'     ( double-lane with {distracted_p*100}% distracted drivers)\n\n')
print('Right lane stats:')
print(f"Number of vehicles waiting in right lane per minute: {r_q_stats.cars_waiting / float(r_q_stats.count)}")
print(f"Average wait time for a vehicle on the right lane (minutes): {r_w_stats.waiting_time / float(r_w_stats.count)}")
print('\n\nLeft lane stats:')
print(f"Number of vehicles waiting in left lane per minute: {l_q_stats.cars_waiting / float(l_q_stats.count)}")
print(f"Average wait time for a vehicle on left lane (minutes): {l_w_stats.waiting_time / float(l_w_stats.count)}")
print('\n\nPedestrians stats:')
print(f"Number of pedestrians waiting to cross per minute: {p_num_stats.pedestrian_waiting / float(p_num_stats.count)}")
print(f"Average wait time for a pedestrian (minutes): {P_W_stats.waiting_time / float(P_W_stats.count)}")
# Out:
# Simulation of vehicles & pedestrians arriving at intersection controlled by traffic light
#
# Double lane model
#
#
#
# At time 0, traffic light turned green.
#
# At time 0.20984557865234, vehicle 1 arrived on the right lane and started to go straight.
# At time 0.3311470778353259, vehicle 1 arrived and started to turn left.
#
# At time 0.43333333333333335, traffic light turned red.
#
# At time0.4616115729020344, pedestrian 1 arrived and started to wait.
# At time 0.4835735794191383, vehicle 2 arrived and started to turn right.
#
# At time 0.6820286529669521, vehicle 3 arrived on the right lane and joined the queue at position 1.
# At time 0.703412623353161 pedestrian 2 arrived at the intersection and started to cross the road.
# At time 0.7402553008095849 pedestrian 3 arrived at the intersection and started to cross the road.
# At time 0.7858358153690852 pedestrian 4 arrived at the intersection and started to cross the road.
# At time 0.7960486087111976 pedestrian 5 arrived at the intersection and started to cross the road.
# At time 1.2051789231701815, vehicle 2 arrived on the left lane and joined the queue at position 1.
# At time 1.3671016648852934, vehicle 4 arrived on the right lane and joined the queue at position 2.
# At time 1.6897924485186417 pedestrian 6 arrived at the intersection and started to cross the road.
# At time 1.7431417885794918, vehicle 3 arrived on the left lane and joined the queue at position 2.
# At time 1.7763306751654782, vehicle 4 arrived on the left lane and joined the queue at position 3.
# At time 1.7903498285951485, vehicle 5 arrived on the right lane and joined the queue at position 3.
# At time 1.8171277348446673, vehicle 5 arrived on the left lane and joined the queue at position 4.
# At time 1.8981473212761837, vehicle 6 arrived on the left lane and joined the queue at position 5.
# At time 1.9333333333333333, traffic light turned green.
#
# At time 1.9845158494809954, 3 turned right at green light, leaving 2 cars in the queue.
#
# At time 1.9848902876431642, vehicle 6 arrived on the right lane and joined the queue at position 3.
# At time1.999257177825126, pedestrian 7 arrived and started to wait.
# At time 2.0365025169560638, 4 turned right at green light, leaving 2 cars in the queue.
#
# At time 2.058742051708097, vehicle 7 arrived on the left lane and joined the queue at position 6.
# At time 2.083968316862147, 5 turned right at green light, leaving 1 cars in the queue.
#
# At time 2.1230859907239754, 6 turned right at green light, leaving 0 cars in the queue.
#
# At time 2.2989757644878646, 2 departed straight ahead, leaving 5 cars in the queue.
# At time 2.33113797817385, 3 departed straight ahead, leaving 4 cars in the queue.
# At time 2.362830617780138, 4 departed straight ahead, leaving 3 cars in the queue.
# At time 2.3666666666666667, traffic light turned red.
#
# At time 2.3741158086069287, vehicle 8 arrived on the left lane and joined the queue at position 4.
# At time 2.5263369852553654, vehicle 9 arrived on the left lane and joined the queue at position 5.
# At time 2.5547167765938372, vehicle 10 arrived on the left lane and joined the queue at position 6.
# At time 2.5718266571503143 pedestrian 8 arrived at the intersection and started to cross the road.
# At time 2.6010993168494276, vehicle 11 arrived on the left lane and joined the queue at position 7.
# Pedestrians [1, 7] crossed the road at time 2.654407509271674.
# At time 2.7437005634045475, vehicle 7 arrived on the right lane and joined the queue at position 1.
# At time 2.7666665803926564, vehicle 12 arrived on the left lane and joined the queue at position 8.
# At time 2.78934850178575, vehicle 8 arrived on the right lane and joined the queue at position 2.
# At time 2.847060020698979, vehicle 9 arrived on the right lane and joined the queue at position 3.
# At time 3.048281614436364, vehicle 13 arrived on the left lane and joined the queue at position 9.
# At time3.101198019603522, pedestrian 9 arrived and started to wait.
# At time 3.15171541100614 pedestrian 10 arrived at the intersection and started to cross the road.
# At time 3.3006541328844565, vehicle 10 arrived on the right lane and joined the queue at position 4.
# At time 3.5281072041685144, vehicle 14 arrived on the left lane and joined the queue at position 10.
# At time 3.8666666666666667, traffic light turned green.
#
# At time 3.8825398722909124, vehicle 15 arrived on the left lane and joined the queue at position 11.
# At time 3.897599854658378, 7 departed straight ahead, leaving 3 cars in the queue.
# Watch out! Distracted driver!
#
# At time 3.9751333005272627, vehicle 16 arrived on the left lane and joined the queue at position 12.
# Watch out! Distracted driver!
#
# At time 4.292548930599975, vehicle 11 arrived on the right lane and joined the queue at position 4.
# Watch out! Distracted driver!
#
# At time 4.3, traffic light turned red.
#
# Pedestrians [9] crossed the road at time 4.577378816619841.
# At time 4.9302581046231895, 8 turned right at red light, leaving 3 cars in the queue.
#
# Watch out! Distracted driver!
#
# At time 4.992613714068733, vehicle 17 arrived on the left lane and joined the queue at position 13.
# Watch out! Distracted driver!
#
# At time5.026231136358435, pedestrian 11 arrived and started to wait.
# At time 5.468627063387373, 9 turned right at red light, leaving 2 cars in the queue.
#
# Watch out! Distracted driver!
#
# At time 5.5129999833591175, vehicle 12 arrived on the right lane and joined the queue at position 3.
# Watch out! Distracted driver!
#
# At time 5.576654096988515 pedestrian 12 arrived at the intersection and started to cross the road.
# At time 5.8, traffic light turned green.
#
# At time6.018218620133317, pedestrian 13 arrived and started to wait.
# At time6.020571887418666, pedestrian 14 arrived and started to wait.
# At time 6.093745756222055, vehicle 18 arrived on the left lane and joined the queue at position 14.
# Watch out! Distracted driver!
#
# At time 6.1035141667116894, 10 departed straight ahead, leaving 2 cars in the queue.
# Watch out! Distracted driver!
#
# At time 6.233333333333333, traffic light turned red.
#
# Pedestrians [11, 13, 14] crossed the road at time 6.508778437977804.
# At time 6.5663530485234585, vehicle 13 arrived on the right lane and joined the queue at position 3.
# Watch out! Distracted driver!
#
# At time6.586888954512563, pedestrian 15 arrived and started to wait.
# At time 7.011499365314872 pedestrian 16 arrived at the intersection and started to cross the road.
# At time 7.444094917277295, vehicle 19 arrived on the left lane and joined the queue at position 15.
# At time 7.733333333333333, traffic light turned green.
#
# At time 7.761085150945282, vehicle 20 arrived on the left lane and joined the queue at position 16.
# At time 7.765904268964383, 11 departed straight ahead, leaving 2 cars in the queue.
# At time 7.80094979311113, 12 departed straight ahead, leaving 1 cars in the queue.
# At time 7.802754177898251, vehicle 14 arrived on the right lane and joined the queue at position 2.
# At time 7.835002529531672, 13 turned right at green light, leaving 1 cars in the queue.
#
# At time 7.896729764985201, 14 turned right at green light, leaving 0 cars in the queue.
#
# At time 7.986213301814516, vehicle 15 arrived on the right lane and started to go straight.
# At time 8.166666666666666, traffic light turned red.
#
# At time 8.232056859440645, vehicle 16 arrived on the right lane and joined the queue at position 1.
# At time 8.322563150110614, vehicle 21 arrived on the left lane and joined the queue at position 17.
# Pedestrians [15] crossed the road at time 8.399660372217978.
# At time 8.470206220006684, vehicle 22 arrived on the left lane and joined the queue at position 18.
# At time 8.516637617802546, vehicle 17 arrived on the right lane and joined the queue at position 2.
# At time8.537640217807752, pedestrian 17 arrived and started to wait.
# At time 8.563603315504997, vehicle 23 arrived on the left lane and joined the queue at position 19.
# At time 8.752284183680779, vehicle 18 arrived on the right lane and joined the queue at position 3.
# At time 8.841995659016867, vehicle 24 arrived on the left lane and joined the queue at position 20.
# At time 8.964680077445522 pedestrian 18 arrived at the intersection and started to cross the road.
# At time 8.992934690850584, vehicle 25 arrived on the left lane and joined the queue at position 21.
# At time 9.313822162657862, vehicle 26 arrived on the left lane and joined the queue at position 22.
# At time 9.350447340202086, vehicle 19 arrived on the right lane and joined the queue at position 4.
# At time 9.666666666666666, traffic light turned green.
#
# At time 9.701621453647583, 5 departed straight ahead, leaving 21 cars in the queue.
# Watch out! Distracted driver!
#
# At time 9.709111906272625, 16 turned right at green light, leaving 3 cars in the queue.
#
# Watch out! Distracted driver!
#
# At time 9.978072886786023, vehicle 27 arrived on the left lane and joined the queue at position 22.
# Watch out! Distracted driver!
#
# At time10.077137391334464, pedestrian 19 arrived and started to wait.
# At time 10.1, traffic light turned red.
#
# At time 10.338572405998312 pedestrian 20 arrived at the intersection and started to cross the road.
# Pedestrians [17, 19] crossed the road at time 10.347661064783983.
# At time10.640721944146733, pedestrian 21 arrived and started to wait.
# At time 10.766589455865342, 17 turned right at red light, leaving 2 cars in the queue.
#
# Watch out! Distracted driver!
#
# At time 11.134256154743893, vehicle 20 arrived on the right lane and joined the queue at position 3.
# Watch out! Distracted driver!
#
# At time 11.200048830202569, vehicle 28 arrived on the left lane and joined the queue at position 23.
# Watch out! Distracted driver!
#
# At time 11.280889035841014 pedestrian 22 arrived at the intersection and started to cross the road.
# At time 11.285174247780917, 18 turned right at red light, leaving 2 cars in the queue.
#
# Watch out! Distracted driver!
#
# At time 11.6, traffic light turned green.
#
# At time11.935538219145847, pedestrian 23 arrived and started to wait.
# At time11.944885954530871, pedestrian 24 arrived and started to wait.
# At time 11.973510446722036, 19 turned right at green light, leaving 1 cars in the queue.
#
# Watch out! Distracted driver!
#
# At time 12.033333333333333, traffic light turned red.
#
# At time 12.31771082610587, vehicle 29 arrived on the left lane and joined the queue at position 24.
# Watch out! Distracted driver!
#
# Pedestrians [21, 23, 24] crossed the road at time 12.319257137688401.
# At time 12.45361280248796, 20 turned right at red light, leaving 0 cars in the queue.
#
# Watch out! Distracted driver!
#
# At time 12.64486701858192, vehicle 21 arrived on the right lane and joined the queue at position 1.
# At time12.734092317745345, pedestrian 25 arrived and started to wait.
# At time 13.210007175958788 pedestrian 26 arrived at the intersection and started to cross the road.
# At time 13.326242238457338, vehicle 30 arrived on the left lane and joined the queue at position 25.
# At time 13.36239582670919, vehicle 22 arrived on the right lane and joined the queue at position 2.
# At time 13.42449580420047, vehicle 23 arrived on the right lane and joined the queue at position 3.
# At time 13.424823644520213, vehicle 31 arrived on the left lane and joined the queue at position 26.
# At time 13.533333333333333, traffic light turned green.
#
# At time 13.565581367674577, 21 departed straight ahead, leaving 2 cars in the queue.
# Watch out! Distracted driver!
#
# At time 13.58477310353041, 22 departed straight ahead, leaving 1 cars in the queue.
# Watch out! Distracted driver!
#
# At time13.59354700942638, pedestrian 27 arrived and started to wait.
# At time 13.602599466213963, vehicle 32 arrived on the left lane and joined the queue at position 27.
# Watch out! Distracted driver!
#
# At time 13.966666666666667, traffic light turned red.
#
# At time 14.186248742135756, vehicle 24 arrived on the right lane and joined the queue at position 2.
# Watch out! Distracted driver!
#
# At time 14.189476066331641 pedestrian 28 arrived at the intersection and started to cross the road.
# Pedestrians [25, 27] crossed the road at time 14.201847115133557.
# At time14.574035969498821, pedestrian 29 arrived and started to wait.
# At time 14.598688408515985, 23 turned right at red light, leaving 1 cars in the queue.
#
# Watch out! Distracted driver!
#
# At time 14.617405364417488, 24 turned right at red light, leaving 0 cars in the queue.
#
# Watch out! Distracted driver!
#
# At time 14.654796959123955, vehicle 33 arrived on the left lane and joined the queue at position 28.
# Watch out! Distracted driver!
#
# At time 15.345656659138223, vehicle 25 arrived on the right lane and joined the queue at position 1.
# Watch out! Distracted driver!
#
# At time 15.466666666666667, traffic light turned green.
#
# At time15.708955990764556, pedestrian 30 arrived and started to wait.
# At time 15.735374784434914, vehicle 34 arrived on the left lane and joined the queue at position 29.
# Watch out! Distracted driver!
#
# At time 15.75562456220284, 25 departed straight ahead, leaving 0 cars in the queue.
# Watch out! Distracted driver!
#
# At time 15.9, traffic light turned red.
#
# At time 16.152706950309405 pedestrian 31 arrived at the intersection and started to cross the road.
# Pedestrians [29, 30] crossed the road at time 16.17830427635422.
# At time 16.720164432346976, vehicle 26 arrived and started to turn right.
#
# Watch out! Distracted driver!
#
# At time16.952566680066823, pedestrian 32 arrived and started to wait.
# At time 16.996801412523457, vehicle 35 arrived on the left lane and joined the queue at position 30.
# At time 17.074042946093474, vehicle 36 arrived on the left lane and joined the queue at position 31.
# At time 17.266579641908674, vehicle 37 arrived on the left lane and joined the queue at position 32.
# At time 17.327888737332017, vehicle 38 arrived on the left lane and joined the queue at position 33.
# At time 17.4, traffic light turned green.
#
# At time 17.433209622422808, 6 departed straight ahead, leaving 32 cars in the queue.
# At time 17.451463102251335, vehicle 39 arrived on the left lane and joined the queue at position 33.
# At time 17.46684601351146, 7 turned left, leaving 32 cars in the queue.
#
# At time 17.4844300280156, vehicle 40 arrived on the left lane and joined the queue at position 33.
# At time 17.817127970793596, vehicle 41 arrived on the left lane and joined the queue at position 34.
# At time 17.833333333333332, traffic light turned red.
#
# At time 18.026838637782227, vehicle 27 arrived on the right lane and joined the queue at position 1.
# At time 18.036862036104946, vehicle 42 arrived on the left lane and joined the queue at position 35.
# Pedestrians [32] crossed the road at time 18.100453476399064.
# At time 18.203374171533408, vehicle 28 arrived on the right lane and joined the queue at position 2.
# At time18.424806779719592, pedestrian 33 arrived and started to wait.
# At time 18.567488102863482, vehicle 29 arrived on the right lane and joined the queue at position 3.
# At time 18.779315730050538, vehicle 30 arrived on the right lane and joined the queue at position 4.
# At time 18.78056968665174, vehicle 43 arrived on the left lane and joined the queue at position 36.
# At time 18.853217220328055, vehicle 44 arrived on the left lane and joined the queue at position 37.
# At time 18.85758514677329, vehicle 45 arrived on the left lane and joined the queue at position 38.
# At time 19.149835855437626, vehicle 46 arrived on the left lane and joined the queue at position 39.
# At time 19.23708576133096, vehicle 47 arrived on the left lane and joined the queue at position 40.
# At time 19.25451202157538, vehicle 48 arrived on the left lane and joined the queue at position 41.
# At time 19.333333333333332, traffic light turned green.
#
# At time 19.366074618319274, 8 departed straight ahead, leaving 40 cars in the queue.
# At time 19.368343398695565, 27 departed straight ahead, leaving 3 cars in the queue.
# At time 19.3983437426069, 9 departed straight ahead, leaving 39 cars in the queue.
# At time 19.40386869878081, 28 departed straight ahead, leaving 2 cars in the queue.
# At time 19.43289802561393, 10 departed straight ahead, leaving 38 cars in the queue.
# At time 19.437669659937548, 29 departed straight ahead, leaving 1 cars in the queue.
# At time 19.467893285465465, 11 departed straight ahead, leaving 37 cars in the queue.
# At time 19.470221436157743, 30 departed straight ahead, leaving 0 cars in the queue.
# At time 19.502727792236833, 12 departed straight ahead, leaving 36 cars in the queue.
# At time 19.533270150416122, 13 departed straight ahead, leaving 35 cars in the queue.
# At time 19.56604797337637, 14 departed straight ahead, leaving 34 cars in the queue.
# At time19.595052761207135, pedestrian 34 arrived and started to wait.
# At time 19.597862365597525, 15 departed straight ahead, leaving 33 cars in the queue.
# At time 19.631122802879172, 16 departed straight ahead, leaving 32 cars in the queue.
# At time 19.641109246703245, vehicle 31 arrived and started to turn right.
#
# At time 19.66444742939286, 17 departed straight ahead, leaving 31 cars in the queue.
# At time 19.696191627850514, 18 departed straight ahead, leaving 30 cars in the queue.
# At time 19.73087009451156, 19 departed straight ahead, leaving 29 cars in the queue.
# At time 19.762340892100593, vehicle 32 arrived on the right lane and started to go straight.
# At time 19.762924076616333, 20 departed straight ahead, leaving 28 cars in the queue.
# At time 19.766666666666666, traffic light turned red.
#
# At time 19.82931522721785, vehicle 33 arrived and started to turn right.
#
# Pedestrians [33, 34] crossed the road at time 20.10625063769063.
# At time 20.25486967809441, vehicle 49 arrived on the left lane and joined the queue at position 29.
# At time 20.64705531910983, vehicle 50 arrived on the left lane and joined the queue at position 30.
# At time 20.66935611108016, vehicle 51 arrived on the left lane and joined the queue at position 31.
# At time 20.683585486718123, vehicle 34 arrived on the right lane and joined the queue at position 1.
# At time 20.698062731813376, vehicle 35 arrived on the right lane and joined the queue at position 2.
# At time 20.701093119720916, vehicle 36 arrived on the right lane and joined the queue at position 3.
# At time 20.73903542366828, vehicle 52 arrived on the left lane and joined the queue at position 32.
# At time 20.742998502593124, vehicle 37 arrived on the right lane and joined the queue at position 4.
# At time 20.763787012950516, vehicle 53 arrived on the left lane and joined the queue at position 33.
# At time 20.8172270021945, vehicle 38 arrived on the right lane and joined the queue at position 5.
# At time 20.978680182379925, vehicle 54 arrived on the left lane and joined the queue at position 34.
# At time 21.01584871562684, vehicle 55 arrived on the left lane and joined the queue at position 35.
# At time 21.110494850135254, vehicle 56 arrived on the left lane and joined the queue at position 36.
# At time 21.159583833677885, vehicle 39 arrived on the right lane and joined the queue at position 6.
# At time 21.266666666666666, traffic light turned green.
#
# At time 21.27108484618607, vehicle 57 arrived on the left lane and joined the queue at position 37.
# At time 21.299572319991174, 21 departed straight ahead, leaving 36 cars in the queue.
# Watch out! Distracted driver!
#
# At time 21.312550317538747, 34 turned right at green light, leaving 5 cars in the queue.
#
# At time 21.36809662154768, 35 turned right at green light, leaving 4 cars in the queue.
#
# At time 21.413435105727984, 36 turned right at green light, leaving 3 cars in the queue.
#
# At time 21.461179336518384, 37 turned right at green light, leaving 2 cars in the queue.
#
# At time 21.473214344732135, vehicle 40 arrived on the right lane and joined the queue at position 3.
# At time 21.512709579770657, 38 departed straight ahead, leaving 2 cars in the queue.
# At time 21.54480218197942, 39 departed straight ahead, leaving 1 cars in the queue.
# At time 21.57799890211716, 40 departed straight ahead, leaving 0 cars in the queue.
# At time 21.59539484829631, vehicle 41 arrived and started to turn right.
#
# At time21.59902766886396, pedestrian 35 arrived and started to wait.
# At time 21.616508974179737, vehicle 42 arrived on the right lane and started to go straight.
# At time 21.680755740873842, vehicle 58 arrived on the left lane and joined the queue at position 37.
# At time 21.7, traffic light turned red.
#
# At time 21.843701969409775, vehicle 43 arrived on the right lane and joined the queue at position 1.
# Pedestrians [35] crossed the road at time 21.938828456780474.
# At time 21.95424269981342, vehicle 59 arrived on the left lane and joined the queue at position 38.
# At time21.964800339699714, pedestrian 36 arrived and started to wait.
# At time 22.03179762482161, vehicle 44 arrived on the right lane and joined the queue at position 2.
# At time 22.127385777241212 pedestrian 37 arrived at the intersection and started to cross the road.
# At time 22.16328616787015, vehicle 45 arrived on the right lane and joined the queue at position 3.
# At time 22.25582341357648, vehicle 60 arrived on the left lane and joined the queue at position 39.
# At time 22.4167873902767, vehicle 61 arrived on the left lane and joined the queue at position 40.
# At time 22.57857436947578, vehicle 62 arrived on the left lane and joined the queue at position 41.
# At time 22.712834089495793, vehicle 63 arrived on the left lane and joined the queue at position 42.
# At time 22.781120438725083, vehicle 46 arrived on the right lane and joined the queue at position 4.
# At time 22.885817450758857, vehicle 47 arrived on the right lane and joined the queue at position 5.
# At time 23.02165728375849, vehicle 64 arrived on the left lane and joined the queue at position 43.
# At time 23.067797644828207, vehicle 65 arrived on the left lane and joined the queue at position 44.
# At time 23.152323585987535, vehicle 48 arrived on the right lane and joined the queue at position 6.
# At time 23.2, traffic light turned green.
#
# At time 23.234888544337377, 43 departed straight ahead, leaving 5 cars in the queue.
# At time 23.26848474655146, 44 departed straight ahead, leaving 4 cars in the queue.
# At time 23.303155679550198, 45 departed straight ahead, leaving 3 cars in the queue.
# At time 23.338399077041206, 46 departed straight ahead, leaving 2 cars in the queue.
# At time 23.373041028741753, 47 departed straight ahead, leaving 1 cars in the queue.
# At time 23.388041957256238, vehicle 49 arrived on the right lane and joined the queue at position 2.
# At time 23.404923193355224, 48 turned right at green light, leaving 1 cars in the queue.
#
# At time 23.444159113316626, 49 turned right at green light, leaving 0 cars in the queue.
#
# At time 23.522042486577966, vehicle 50 arrived on the right lane and started to go straight.
# At time 23.633333333333333, traffic light turned red.
#
# At time 23.693800474256157 pedestrian 38 arrived at the intersection and started to cross the road.
# Pedestrians [36] crossed the road at time 23.87150730707441.
# At time 23.91107087438233, vehicle 66 arrived on the left lane and joined the queue at position 45.
# At time23.91333896618395, pedestrian 39 arrived and started to wait.
# At time 23.915411693032492, vehicle 67 arrived on the left lane and joined the queue at position 46.
# At time 24.015765100193228 pedestrian 40 arrived at the intersection and started to cross the road.
# At time 24.02056474507526, vehicle 51 arrived and started to turn right.
#
# At time 24.068231476119283 pedestrian 41 arrived at the intersection and started to cross the road.
# At time 24.370948364975277 pedestrian 42 arrived at the intersection and started to cross the road.
# At time 24.55746764058589, vehicle 52 arrived on the right lane and joined the queue at position 1.
# At time 24.568731161501983 pedestrian 43 arrived at the intersection and started to cross the road.
# At time 24.585548123252202 pedestrian 44 arrived at the intersection and started to cross the road.
# At time 24.593412683770023 pedestrian 45 arrived at the intersection and started to cross the road.
# At time 24.61391434606583, vehicle 68 arrived on the left lane and joined the queue at position 47.
# At time 24.690449768871733, vehicle 69 arrived on the left lane and joined the queue at position 48.
# At time 24.767426217410595, vehicle 70 arrived on the left lane and joined the queue at position 49.
# At time 24.770619021611854, vehicle 71 arrived on the left lane and joined the queue at position 50.
# At time 24.808774282994555, vehicle 53 arrived on the right lane and joined the queue at position 2.
# At time 24.873416873450658 pedestrian 46 arrived at the intersection and started to cross the road.
# At time 25.02468629294288, vehicle 72 arrived on the left lane and joined the queue at position 51.
# At time 25.133333333333333, traffic light turned green.
#
# At time25.136432272300386, pedestrian 47 arrived and started to wait.
# At time 25.169514883227905, 22 departed straight ahead, leaving 50 cars in the queue.
# At time25.170199351238132, pedestrian 48 arrived and started to wait.
# At time 25.18317096487028, 52 turned right at green light, leaving 1 cars in the queue.
#
# At time 25.202046454972148, 23 departed straight ahead, leaving 49 cars in the queue.
# At time 25.22819625139542, 53 turned right at green light, leaving 0 cars in the queue.
#
# At time 25.235988171557963, 24 departed straight ahead, leaving 48 cars in the queue.
# At time 25.269058057507475, 25 departed straight ahead, leaving 47 cars in the queue.
# At time 25.293156329897855, vehicle 73 arrived on the left lane and joined the queue at position 48.
# At time 25.302578960916332, 26 departed straight ahead, leaving 47 cars in the queue.
# At time25.308351948910328, pedestrian 49 arrived and started to wait.
# At time 25.335615248376495, 27 departed straight ahead, leaving 46 cars in the queue.
# At time 25.370330601608323, 28 departed straight ahead, leaving 45 cars in the queue.
# At time 25.405705989081092, 29 departed straight ahead, leaving 44 cars in the queue.
# At time 25.43671711948138, 30 departed straight ahead, leaving 43 cars in the queue.
# At time 25.468990770450535, 31 departed straight ahead, leaving 42 cars in the queue.
# At time 25.501773731980563, 32 departed straight ahead, leaving 41 cars in the queue.
# At time25.531921901120192, pedestrian 50 arrived and started to wait.
# At time 25.53641262745353, 33 departed straight ahead, leaving 40 cars in the queue.
# At time 25.566666666666666, traffic light turned red.
#
# At time 25.616446522065193, vehicle 74 arrived on the left lane and joined the queue at position 41.
# Pedestrians [39, 47, 48, 49, 50] crossed the road at time 25.913665968192863.
# At time 26.03226131769187, vehicle 54 arrived on the right lane and joined the queue at position 1.
# At time 26.061777360653828, vehicle 55 arrived on the right lane and joined the queue at position 2.
# At time 26.131864324036094, vehicle 56 arrived on the right lane and joined the queue at position 3.
# At time 26.147718172609196, vehicle 57 arrived on the right lane and joined the queue at position 4.
# At time 26.710568033252738, vehicle 58 arrived on the right lane and joined the queue at position 5.
# At time 26.836209371478994, vehicle 59 arrived on the right lane and joined the queue at position 6.
# At time 26.88988273564728, vehicle 75 arrived on the left lane and joined the queue at position 42.
# At time 26.939600967802566, vehicle 76 arrived on the left lane and joined the queue at position 43.
# At time 27.03533275642124, vehicle 77 arrived on the left lane and joined the queue at position 44.
# At time 27.066666666666666, traffic light turned green.
#
# At time 27.10000797439695, 54 departed straight ahead, leaving 5 cars in the queue.
# At time 27.10691033842578, vehicle 78 arrived on the left lane and joined the queue at position 45.
# At time 27.134957339598216, 55 departed straight ahead, leaving 4 cars in the queue.
# At time 27.16904018936487, 56 departed straight ahead, leaving 3 cars in the queue.
# At time 27.200454087517436, vehicle 60 arrived on the right lane and joined the queue at position 4.
# At time 27.204863128410985, 57 turned right at green light, leaving 3 cars in the queue.
#
# At time 27.244471180781154, 58 turned right at green light, leaving 2 cars in the queue.
#
# At time 27.29055846843463, 59 turned right at green light, leaving 1 cars in the queue.
#
# At time 27.33309188346107, 60 turned right at green light, leaving 0 cars in the queue.
#
# At time 27.35895852980593, vehicle 61 arrived on the right lane and started to go straight.
# At time 27.47323786248878, vehicle 79 arrived on the left lane and joined the queue at position 46.
# At time 27.5, traffic light turned red.
#
# At time 27.603282239851612, vehicle 62 arrived and started to turn right.
#
# At time27.64842970473507, pedestrian 51 arrived and started to wait.
# At time 27.809099855648054 pedestrian 52 arrived at the intersection and started to cross the road.
# At time 27.812003174020777, vehicle 63 arrived on the right lane and joined the queue at position 1.
# At time 28.02376357341891, vehicle 64 arrived on the right lane and joined the queue at position 2.
# At time 28.06845924199779, vehicle 80 arrived on the left lane and joined the queue at position 47.
# At time 28.14375424903814, vehicle 81 arrived on the left lane and joined the queue at position 48.
# At time 28.18401615769464, vehicle 65 arrived on the right lane and joined the queue at position 3.
# At time 28.241736936562557, vehicle 82 arrived on the left lane and joined the queue at position 49.
# At time 28.348713448450056, vehicle 83 arrived on the left lane and joined the queue at position 50.
# At time 28.38028388962459, vehicle 66 arrived on the right lane and joined the queue at position 4.
# At time 28.457419732093673, vehicle 67 arrived on the right lane and joined the queue at position 5.
# At time 28.486559085878273, vehicle 68 arrived on the right lane and joined the queue at position 6.
# At time 28.84183642392454, vehicle 69 arrived on the right lane and joined the queue at position 7.
# At time 28.871515030062035, vehicle 84 arrived on the left lane and joined the queue at position 51.
# At time 28.931978325912706, vehicle 85 arrived on the left lane and joined the queue at position 52.
# At time 28.944454917123576 pedestrian 53 arrived at the intersection and started to cross the road.
# At time 29.0, traffic light turned green.
#
# At time 29.032506434612245, 34 departed straight ahead, leaving 51 cars in the queue.
# Watch out! Distracted driver!
#
# At time 29.05074460045911, 63 turned right at green light, leaving 6 cars in the queue.
#
# Watch out! Distracted driver!
#
# At time 29.09861575014244, vehicle 70 arrived on the right lane and joined the queue at position 7.
# Watch out! Distracted driver!
#
# At time 29.229331163369192, vehicle 86 arrived on the left lane and joined the queue at position 52.
# Watch out! Distracted driver!
#
# At time 29.433333333333334, traffic light turned red.
#
# Pedestrians [51] crossed the road at time 29.66837616198524.
# At time30.001408321290718, pedestrian 54 arrived and started to wait.
# At time 30.211147984618627 pedestrian 55 arrived at the intersection and started to cross the road.
# At time 30.366643190318047, vehicle 87 arrived on the left lane and joined the queue at position 53.
# Watch out! Distracted driver!
#
# At time 30.697884253135726 pedestrian 56 arrived at the intersection and started to cross the road.
# At time 30.759365535023786 pedestrian 57 arrived at the intersection and started to cross the road.
# At time 30.771618713074627, vehicle 71 arrived on the right lane and joined the queue at position 8.
# Watch out! Distracted driver!
#
# At time 30.933333333333334, traffic light turned green.
#
# At time31.189722885552193, pedestrian 58 arrived and started to wait.
# At time 31.366666666666667, traffic light turned red.
#
# At time 31.42871186984005, vehicle 88 arrived on the left lane and joined the queue at position 54.
# Watch out! Distracted driver!
#
# Pedestrians [54, 58] crossed the road at time 31.67550095424713.
# At time31.710645120785763, pedestrian 59 arrived and started to wait.
# At time 31.9946698457767, 64 turned right at red light, leaving 7 cars in the queue.
#
# At time 32.06550448276911, vehicle 72 arrived on the right lane and joined the queue at position 8.
# At time 32.092478052726364, vehicle 73 arrived on the right lane and joined the queue at position 9.
# At time 32.285975098940774, vehicle 74 arrived on the right lane and joined the queue at position 10.
# At time 32.30680301138614 pedestrian 60 arrived at the intersection and started to cross the road.
# At time 32.311098441583354, vehicle 75 arrived on the right lane and joined the queue at position 11.
# At time 32.43319832202769, vehicle 89 arrived on the left lane and joined the queue at position 55.
# At time 32.43603263686929 pedestrian 61 arrived at the intersection and started to cross the road.
# At time 32.50765698969454 pedestrian 62 arrived at the intersection and started to cross the road.
# At time 32.56851410503669, vehicle 76 arrived on the right lane and joined the queue at position 12.
# At time 32.6875047578437, vehicle 90 arrived on the left lane and joined the queue at position 56.
# At time 32.86666666666667, traffic light turned green.
#
# At time 32.9013890960856, 65 departed straight ahead, leaving 11 cars in the queue.
# At time 32.90249384155975, 35 departed straight ahead, leaving 55 cars in the queue.
# Watch out! Distracted driver!
#
# At time 32.93228394327837, 66 departed straight ahead, leaving 10 cars in the queue.
# Watch out! Distracted driver!
#
# At time 33.24231894880637, vehicle 77 arrived on the right lane and joined the queue at position 11.
# Watch out! Distracted driver!
#
# At time 33.3, traffic light turned red.
#
# At time 33.36458300931248, vehicle 91 arrived on the left lane and joined the queue at position 56.
# Watch out! Distracted driver!
#
# Pedestrians [59] crossed the road at time 33.64359541869367.
# At time 34.28843695431221, vehicle 78 arrived on the right lane and joined the queue at position 12.
# Watch out! Distracted driver!
#
# At time34.47838631659378, pedestrian 63 arrived and started to wait.
# At time 34.76853111329266 pedestrian 64 arrived at the intersection and started to cross the road.
# At time 34.8, traffic light turned green.
#
# At time34.8083161895234, pedestrian 65 arrived and started to wait.
# At time34.82852697821585, pedestrian 66 arrived and started to wait.
# At time34.85943505236206, pedestrian 67 arrived and started to wait.
# At time34.890946773522344, pedestrian 68 arrived and started to wait.
# At time 34.993326597865725, vehicle 92 arrived on the left lane and joined the queue at position 57.
# Watch out! Distracted driver!
#
# At time 35.23333333333333, traffic light turned red.
#
# Pedestrians [63, 65, 66, 67, 68] crossed the road at time 35.5492317506464.
# At time 35.573751148242295, vehicle 79 arrived on the right lane and joined the queue at position 13.
# Watch out! Distracted driver!
#
# At time36.082480908729714, pedestrian 69 arrived and started to wait.
# At time 36.400532636302195 pedestrian 70 arrived at the intersection and started to cross the road.
# At time 36.59538148197296, vehicle 93 arrived on the left lane and joined the queue at position 58.
# At time 36.63813735422809 pedestrian 71 arrived at the intersection and started to cross the road.
# At time 36.645994381618195, vehicle 94 arrived on the left lane and joined the queue at position 59.
# At time 36.66321012722955, vehicle 95 arrived on the left lane and joined the queue at position 60.
# At time 36.669474580777376, vehicle 80 arrived on the right lane and joined the queue at position 14.
# At time 36.73333333333333, traffic light turned green.
#
# At time 36.74128452276788, vehicle 81 arrived on the right lane and joined the queue at position 15.
# At time 36.766715398699304, 67 departed straight ahead, leaving 14 cars in the queue.
# At time 36.79843740935707, 68 departed straight ahead, leaving 13 cars in the queue.
# At time 36.82990410597175, 69 departed straight ahead, leaving 12 cars in the queue.
# At time 36.834438087791874, vehicle 96 arrived on the left lane and joined the queue at position 61.
# At time36.83687689564152, pedestrian 72 arrived and started to wait.
# At time 36.849836242617314, vehicle 82 arrived on the right lane and joined the queue at position 13.
# At time 36.86266651928378, 70 turned right at green light, leaving 12 cars in the queue.
#
# At time 36.916892363093595, 71 turned right at green light, leaving 11 cars in the queue.
#
# At time 36.964188335397985, vehicle 83 arrived on the right lane and joined the queue at position 12.
# At time 36.969369493211, 72 turned right at green light, leaving 11 cars in the queue.
#
# At time 37.02821147161428, 73 turned right at green light, leaving 10 cars in the queue.
#
# At time 37.083441403470054, 74 turned right at green light, leaving 9 cars in the queue.
#
# At time37.09000887362045, pedestrian 73 arrived and started to wait.
# At time 37.11824636935631, vehicle 97 arrived on the left lane and joined the queue at position 62.
# At time 37.13530127897598, vehicle 98 arrived on the left lane and joined the queue at position 63.
# At time 37.13716049374013, 75 turned right at green light, leaving 8 cars in the queue.
#
# At time 37.16666666666666, traffic light turned red.
#
# At time 37.18753122147217, 76 turned right at red light, leaving 7 cars in the queue.
#
# At time 37.284570769944764, vehicle 99 arrived on the left lane and joined the queue at position 64.
# Watch out! Distracted driver!
#
# At time 37.29436769681772 pedestrian 74 arrived at the intersection and started to cross the road.
# At time 37.31123101509689, 77 turned right at red light, leaving 6 cars in the queue.
#
# Watch out! Distracted driver!
#
# At time 37.39272835562922, 78 turned right at red light, leaving 5 cars in the queue.
#
# Pedestrians [69, 72, 73] crossed the road at time 37.49386073295104.
# At time 37.55057880968589, 79 turned right at red light, leaving 4 cars in the queue.
#
# At time 37.7065924918389, 80 turned right at red light, leaving 3 cars in the queue.
#
# At time 37.83523474578906, 81 turned right at red light, leaving 2 cars in the queue.
#
# At time 37.95007717672553, vehicle 84 arrived on the right lane and joined the queue at position 3.
# At time 38.01908408007934, 82 turned right at red light, leaving 2 cars in the queue.
#
# At time 38.13917071915735, 83 turned right at red light, leaving 1 cars in the queue.
#
# At time38.236799992941776, pedestrian 75 arrived and started to wait.
# At time 38.30565192176128, 84 turned right at red light, leaving 0 cars in the queue.
#
# At time 38.47238905481706, vehicle 85 arrived on the right lane and joined the queue at position 1.
# At time 38.64528101529392, vehicle 100 arrived on the left lane and joined the queue at position 65.
# At time 38.66666666666666, traffic light turned green.
#
# At time38.671839950136714, pedestrian 76 arrived and started to wait.
# At time 38.69827106341241, 85 departed straight ahead, leaving 0 cars in the queue.
# At time 38.69985364977972, 36 departed straight ahead, leaving 64 cars in the queue.
# Watch out! Distracted driver!
#
# At time 38.81298632413912, vehicle 101 arrived on the left lane and joined the queue at position 65.
# Watch out! Distracted driver!
#
# At time 38.989999232629685, vehicle 86 arrived and started to turn right.
#
# Watch out! Distracted driver!
#
# At time 39.09999999999999, traffic light turned red.
#
# Pedestrians [75, 76] crossed the road at time 39.42028208306045.
# At time 39.94759147249732, vehicle 102 arrived on the left lane and joined the queue at position 66.
# Watch out! Distracted driver!
#
# At time 40.101448442183404, vehicle 87 arrived on the right lane and joined the queue at position 1.
# Watch out! Distracted driver!
#
# At time 40.59999999999999, traffic light turned green.
#
# At time40.62691049736143, pedestrian 77 arrived and started to wait.
# At time 41.03333333333332, traffic light turned red.
#
# At time 41.08191078935543, vehicle 103 arrived on the left lane and joined the queue at position 67.
# Watch out! Distracted driver!
#
# At time 41.156732975851156 pedestrian 78 arrived at the intersection and started to cross the road.
# At time 41.35279816910232, vehicle 88 arrived on the right lane and joined the queue at position 2.
# Watch out! Distracted driver!
#
# Pedestrians [77] crossed the road at time 41.355016045377745.
# At time41.416359840605374, pedestrian 79 arrived and started to wait.
# At time 41.43156383928416 pedestrian 80 arrived at the intersection and started to cross the road.
# At time 42.099848047409026 pedestrian 81 arrived at the intersection and started to cross the road.
# At time 42.112778256506566, vehicle 104 arrived on the left lane and joined the queue at position 68.
# Watch out! Distracted driver!
#
# At time 42.45488923461758, vehicle 89 arrived on the right lane and joined the queue at position 3.
# At time 42.53333333333332, traffic light turned green.
#
# At time 42.56413873502535, 87 departed straight ahead, leaving 2 cars in the queue.
# At time42.56594141701986, pedestrian 82 arrived and started to wait.
# At time 42.597553680303086, 88 departed straight ahead, leaving 1 cars in the queue.
# At time 42.62961154821235, 89 departed straight ahead, leaving 0 cars in the queue.
# At time42.793085206604346, pedestrian 83 arrived and started to wait.
# At time 42.96666666666665, traffic light turned red.
#
# At time 42.987143583719146, vehicle 90 arrived on the right lane and joined the queue at position 1.
# At time 43.053624412041565, vehicle 91 arrived on the right lane and joined the queue at position 2.
# Watch out! Distracted driver!
#
# At time 43.15814622172399 pedestrian 84 arrived at the intersection and started to cross the road.
# At time 43.21083429123701 pedestrian 85 arrived at the intersection and started to cross the road.
# Pedestrians [79, 82, 83] crossed the road at time 43.303270408893994.
# At time43.36480368754112, pedestrian 86 arrived and started to wait.
# At time 43.37836248648478, vehicle 105 arrived on the left lane and joined the queue at position 69.
# Watch out! Distracted driver!
#
# At time 43.39902312616026 pedestrian 87 arrived at the intersection and started to cross the road.
# At time 43.487463475159046 pedestrian 88 arrived at the intersection and started to cross the road.
# At time 43.897592978908555 pedestrian 89 arrived at the intersection and started to cross the road.
# At time 44.11960786009322, vehicle 92 arrived on the right lane and joined the queue at position 3.
# Watch out! Distracted driver!
#
# At time 44.46666666666665, traffic light turned green.
#
# At time44.64000001969337, pedestrian 90 arrived and started to wait.
# At time 44.88983936394787, vehicle 106 arrived on the left lane and joined the queue at position 70.
# Watch out! Distracted driver!
#
# At time 44.89999999999998, traffic light turned red.
#
# At time 45.015636203728725 pedestrian 91 arrived at the intersection and started to cross the road.
# At time 45.163505773587175, vehicle 93 arrived on the right lane and joined the queue at position 4.
# Watch out! Distracted driver!
#
# Pedestrians [86, 90] crossed the road at time 45.22452829396786.
# At time 46.29084364450553, vehicle 107 arrived on the left lane and joined the queue at position 71.
# At time46.325736966791105, pedestrian 92 arrived and started to wait.
# At time 46.39999999999998, traffic light turned green.
#
# At time 46.43284622411076, 90 departed straight ahead, leaving 3 cars in the queue.
# At time 46.46569388137799, 91 departed straight ahead, leaving 2 cars in the queue.
# At time 46.49810175964817, 92 departed straight ahead, leaving 1 cars in the queue.
# At time 46.53142163345894, 93 departed straight ahead, leaving 0 cars in the queue.
# At time 46.75949801843988, vehicle 94 arrived on the right lane and started to go straight.
# At time 46.83333333333331, traffic light turned red.
#
# At time 46.95543812229384, vehicle 95 arrived on the right lane and joined the queue at position 1.
# Watch out! Distracted driver!
#
# At time 47.037802482612875 pedestrian 93 arrived at the intersection and started to cross the road.
# At time 47.03973639356233 pedestrian 94 arrived at the intersection and started to cross the road.
# Pedestrians [92] crossed the road at time 47.09037674904543.
# At time47.138096738660515, pedestrian 95 arrived and started to wait.
# At time 47.44306692869483, vehicle 108 arrived on the left lane and joined the queue at position 72.
# Watch out! Distracted driver!
#
# At time 47.612589907671136 pedestrian 96 arrived at the intersection and started to cross the road.
# At time 48.24839491567131 pedestrian 97 arrived at the intersection and started to cross the road.
# At time 48.33333333333331, traffic light turned green.
#
# At time 48.76666666666664, traffic light turned red.
#
# At time 48.88650879022164, vehicle 96 arrived on the right lane and joined the queue at position 2.
# Watch out! Distracted driver!
#
# At time 49.00631006593189, vehicle 109 arrived on the left lane and joined the queue at position 73.
# Watch out! Distracted driver!
#
# Pedestrians [95] crossed the road at time 49.0708992004531.
# At time 49.36669221640918, 95 turned right at red light, leaving 1 cars in the queue.
#
# Watch out! Distracted driver!
#
# At time49.94486030938916, pedestrian 98 arrived and started to wait.
# At time 50.08045058985958, vehicle 97 arrived on the right lane and joined the queue at position 2.
# Watch out! Distracted driver!
#
# At time 50.13639434368405 pedestrian 99 arrived at the intersection and started to cross the road.
# At time 50.26666666666664, traffic light turned green.
#
# At time50.43041625169554, pedestrian 100 arrived and started to wait.
# At time 50.508677657606064, 96 turned right at green light, leaving 1 cars in the queue.
#
# Watch out! Distracted driver!
#
# At time 50.55969851194016, vehicle 110 arrived on the left lane and joined the queue at position 74.
# Watch out! Distracted driver!
#
# At time 50.69999999999997, traffic light turned red.
#
# Pedestrians [98, 100] crossed the road at time 51.02956939064953.
# At time 51.24218848534242, vehicle 98 arrived on the right lane and joined the queue at position 2.
# Watch out! Distracted driver!
#
# At time51.88087078457702, pedestrian 101 arrived and started to wait.
# At time 52.05499510174196 pedestrian 102 arrived at the intersection and started to cross the road.
# At time 52.19999999999997, traffic light turned green.
#
# At time 52.234446414405944, 97 departed straight ahead, leaving 1 cars in the queue.
# Watch out! Distracted driver!
#
# At time 52.23480617068469, 37 departed straight ahead, leaving 73 cars in the queue.
# At time 52.26946194095509, 38 departed straight ahead, leaving 72 cars in the queue.
# At time 52.30097053675879, 39 departed straight ahead, leaving 71 cars in the queue.
# At time 52.306504608275254, vehicle 99 arrived on the right lane and joined the queue at position 2.
# At time 52.32716283877637, vehicle 100 arrived on the right lane and joined the queue at position 3.
# At time 52.33283472170949, 40 departed straight ahead, leaving 70 cars in the queue.
# At time 52.357184098552366, vehicle 101 arrived on the right lane and joined the queue at position 4.
# At time 52.366403782109195, 41 departed straight ahead, leaving 69 cars in the queue.
# At time52.395562742304726, pedestrian 103 arrived and started to wait.
# At time 52.39801985170962, 42 departed straight ahead, leaving 68 cars in the queue.
# At time 52.433462328883486, 43 departed straight ahead, leaving 67 cars in the queue.
# At time 52.45240550839463, vehicle 111 arrived on the left lane and joined the queue at position 68.
# At time 52.46641302348557, 44 departed straight ahead, leaving 67 cars in the queue.
# At time 52.49969053451684, 45 departed straight ahead, leaving 66 cars in the queue.
# At time 52.5283977126168, vehicle 112 arrived on the left lane and joined the queue at position 67.
# At time 52.53063325872419, 46 turned left, leaving 66 cars in the queue.
#
# At time 52.596438638432275, vehicle 102 arrived on the right lane and joined the queue at position 5.
# At time 52.6333333333333, traffic light turned red.
#
# At time 52.66675954982677, vehicle 113 arrived on the left lane and joined the queue at position 67.
# At time 52.78658092372639, 98 turned right at red light, leaving 4 cars in the queue.
#
# At time 52.92194934361519, vehicle 103 arrived on the right lane and joined the queue at position 5.
# Pedestrians [101, 103] crossed the road at time 52.99148229524326.
# At time 53.054226499693435, vehicle 114 arrived on the left lane and joined the queue at position 68.
# At time 53.11719235694854, vehicle 115 arrived on the left lane and joined the queue at position 69.
# At time 53.25321317089136, vehicle 116 arrived on the left lane and joined the queue at position 70.
# At time 53.450558242610335, vehicle 117 arrived on the left lane and joined the queue at position 71.
# At time 53.45070223466573, vehicle 118 arrived on the left lane and joined the queue at position 72.
# At time 53.468015426411874, vehicle 119 arrived on the left lane and joined the queue at position 73.
# At time 53.468966017112, vehicle 104 arrived on the right lane and joined the queue at position 6.
# At time 53.984252101289265, vehicle 105 arrived on the right lane and joined the queue at position 7.
# At time 54.02995542705878, vehicle 106 arrived on the right lane and joined the queue at position 8.
# At time 54.062364224119385, vehicle 107 arrived on the right lane and joined the queue at position 9.
# At time 54.1333333333333, traffic light turned green.
#
# At time 54.16659722517991, 47 departed straight ahead, leaving 72 cars in the queue.
# At time 54.17834862405433, vehicle 120 arrived on the left lane and joined the queue at position 73.
# At time 54.18977852374463, 99 turned right at green light, leaving 8 cars in the queue.
#
# At time 54.19764443254331, 48 departed straight ahead, leaving 72 cars in the queue.
# At time 54.22918795481705, 49 departed straight ahead, leaving 71 cars in the queue.
# At time 54.232914106090625, 100 turned right at green light, leaving 7 cars in the queue.
#
# At time54.257999893394896, pedestrian 104 arrived and started to wait.
# At time 54.26383989300166, 50 departed straight ahead, leaving 70 cars in the queue.
# At time 54.282460311170155, 101 turned right at green light, leaving 6 cars in the queue.
#
# At time 54.298072035458894, 51 departed straight ahead, leaving 69 cars in the queue.
# At time 54.32988747659102, vehicle 108 arrived on the right lane and joined the queue at position 7.
# At time 54.33088091297047, 102 departed straight ahead, leaving 6 cars in the queue.
# At time 54.33095304999531, 52 departed straight ahead, leaving 68 cars in the queue.
# At time 54.361291443726174, 53 departed straight ahead, leaving 67 cars in the queue.
# At time 54.36513133176407, 103 departed straight ahead, leaving 5 cars in the queue.
# At time 54.39535110210904, 54 departed straight ahead, leaving 66 cars in the queue.
# At time 54.40046056645453, 104 departed straight ahead, leaving 4 cars in the queue.
# At time 54.42948117332995, 55 departed straight ahead, leaving 65 cars in the queue.
# At time 54.43244386214923, 105 departed straight ahead, leaving 3 cars in the queue.
# At time 54.4627591067149, 56 departed straight ahead, leaving 64 cars in the queue.
# At time 54.46420968596026, 106 departed straight ahead, leaving 2 cars in the queue.
# At time 54.495583584162496, 57 departed straight ahead, leaving 63 cars in the queue.
# At time 54.49969423627564, 107 departed straight ahead, leaving 1 cars in the queue.
# At time 54.5093691169175, vehicle 121 arrived on the left lane and joined the queue at position 64.
# At time 54.530944752265896, 58 departed straight ahead, leaving 63 cars in the queue.
# At time 54.532201279031895, 108 departed straight ahead, leaving 0 cars in the queue.
# At time 54.56666666666663, traffic light turned red.
#
# At time 54.751104792814004, vehicle 122 arrived on the left lane and joined the queue at position 64.
# Pedestrians [104] crossed the road at time 54.84306847138345.
# At time 54.90962860520722, vehicle 109 arrived and started to turn right.
#
# At time 54.92962339743821, vehicle 123 arrived on the left lane and joined the queue at position 65.
# At time 54.96373375001634, vehicle 110 arrived on the right lane and joined the queue at position 1.
# At time 55.03375203396236, vehicle 124 arrived on the left lane and joined the queue at position 66.
# At time 55.119870509271664, vehicle 111 arrived on the right lane and joined the queue at position 2.
# At time 55.1503322957263, vehicle 125 arrived on the left lane and joined the queue at position 67.
# At time 55.24060343432127, vehicle 126 arrived on the left lane and joined the queue at position 68.
# At time55.327738667433266, pedestrian 105 arrived and started to wait.
# At time 55.466806859081096, vehicle 112 arrived on the right lane and joined the queue at position 3.
# At time 55.63884683922379, vehicle 127 arrived on the left lane and joined the queue at position 69.
# At time 55.679076084969466, vehicle 128 arrived on the left lane and joined the queue at position 70.
# At time 55.83257782236607, vehicle 129 arrived on the left lane and joined the queue at position 71.
# At time 55.8553138341554, vehicle 113 arrived on the right lane and joined the queue at position 4.
# At time 55.9894268626042, vehicle 130 arrived on the left lane and joined the queue at position 72.
# At time 56.06666666666663, traffic light turned green.
#
# At time 56.09965340754854, 59 departed straight ahead, leaving 71 cars in the queue.
# At time 56.10045712732999, 110 departed straight ahead, leaving 3 cars in the queue.
# At time 56.111246033375544, vehicle 114 arrived on the right lane and joined the queue at position 4.
# At time56.12155331799959, pedestrian 106 arrived and started to wait.
# At time 56.13262484397703, 111 departed straight ahead, leaving 3 cars in the queue.
# At time 56.134269809273675, 60 departed straight ahead, leaving 70 cars in the queue.
# At time 56.164258654670284, 112 departed straight ahead, leaving 2 cars in the queue.
# At time 56.16699611626501, 61 departed straight ahead, leaving 69 cars in the queue.
# At time 56.196232776525775, 113 departed straight ahead, leaving 1 cars in the queue.
# At time 56.19860095941294, 62 departed straight ahead, leaving 68 cars in the queue.
# At time 56.22972520987086, 63 departed straight ahead, leaving 67 cars in the queue.
# At time 56.231407738299076, 114 departed straight ahead, leaving 0 cars in the queue.
# At time 56.265733354007224, 64 departed straight ahead, leaving 66 cars in the queue.
# At time 56.30065818670549, 65 departed straight ahead, leaving 65 cars in the queue.
# At time 56.33422111407536, 66 departed straight ahead, leaving 64 cars in the queue.
# At time 56.36708047487347, 67 departed straight ahead, leaving 63 cars in the queue.
# At time 56.39983866420153, 68 departed straight ahead, leaving 62 cars in the queue.
# At time 56.43418328264991, 69 departed straight ahead, leaving 61 cars in the queue.
# At time 56.46682724136115, 70 departed straight ahead, leaving 60 cars in the queue.
# At time 56.49999999999996, traffic light turned red.
#
# At time 56.52093074686685, vehicle 131 arrived on the left lane and joined the queue at position 61.
# At time 56.66170036323421, vehicle 115 arrived on the right lane and joined the queue at position 1.
# Pedestrians [105, 106] crossed the road at time 56.80145656986764.
# At time 57.124083110347705, vehicle 116 arrived on the right lane and joined the queue at position 2.
# At time 57.131127884780796, vehicle 132 arrived on the left lane and joined the queue at position 62.
# At time 57.134450550654655, vehicle 117 arrived on the right lane and joined the queue at position 3.
# At time 57.14601831263014, vehicle 118 arrived on the right lane and joined the queue at position 4.
# At time 57.173720143627634, vehicle 119 arrived on the right lane and joined the queue at position 5.
# At time 57.19558301758966, vehicle 133 arrived on the left lane and joined the queue at position 63.
# At time 57.238724003080534, vehicle 134 arrived on the left lane and joined the queue at position 64.
# At time57.375414505237714, pedestrian 107 arrived and started to wait.
# At time 57.45104923123073 pedestrian 108 arrived at the intersection and started to cross the road.
# At time 57.5800218445379 pedestrian 109 arrived at the intersection and started to cross the road.
# At time 57.61569034821615 pedestrian 110 arrived at the intersection and started to cross the road.
# At time 57.62588819561061, vehicle 120 arrived on the right lane and joined the queue at position 6.
# At time 57.682043753711135, vehicle 135 arrived on the left lane and joined the queue at position 65.
# At time 57.724046491907664, vehicle 121 arrived on the right lane and joined the queue at position 7.
# At time 57.78999925133314, vehicle 136 arrived on the left lane and joined the queue at position 66.
# At time 57.99999999999996, traffic light turned green.
#
# At time 58.03254226891946, 71 departed straight ahead, leaving 65 cars in the queue.
# Watch out! Distracted driver!
#
# At time 58.04283064137039, 115 turned right at green light, leaving 6 cars in the queue.
#
# At time 58.09320443074191, 116 turned right at green light, leaving 5 cars in the queue.
#
# At time 58.15085278401293, 117 turned right at green light, leaving 4 cars in the queue.
#
# At time 58.16924181774364, vehicle 122 arrived on the right lane and joined the queue at position 5.
# At time 58.209682497927695, 118 departed straight ahead, leaving 4 cars in the queue.
# At time58.22728522458122, pedestrian 111 arrived and started to wait.
# At time 58.241256565957414, 119 departed straight ahead, leaving 3 cars in the queue.
# At time 58.2739329380377, 120 departed straight ahead, leaving 2 cars in the queue.
# At time 58.30658498439834, 121 departed straight ahead, leaving 1 cars in the queue.
# At time 58.33985975068928, 122 departed straight ahead, leaving 0 cars in the queue.
# At time 58.4263772104077, vehicle 123 arrived on the right lane and started to go straight.
# At time 58.43333333333329, traffic light turned red.
#
# At time 58.53442536977068 pedestrian 112 arrived at the intersection and started to cross the road.
# At time 58.63152086340815 pedestrian 113 arrived at the intersection and started to cross the road.
# At time 58.75046038691437, vehicle 137 arrived on the left lane and joined the queue at position 66.
# Pedestrians [107, 111] crossed the road at time 58.75597777131483.
# At time 58.983609896384934, vehicle 124 arrived on the right lane and joined the queue at position 1.
# At time 59.18545212698766, vehicle 125 arrived on the right lane and joined the queue at position 2.
# At time 59.281072165628665, vehicle 126 arrived on the right lane and joined the queue at position 3.
# At time 59.93333333333329, traffic light turned green.
#
# At time 59.95275013627951, vehicle 127 arrived on the right lane and joined the queue at position 4.
# At time 59.96752318034789, 72 departed straight ahead, leaving 65 cars in the queue.
# At time 59.96791974283412, 124 departed straight ahead, leaving 3 cars in the queue.
#
#
#       *** Statistical report(random seed=0) ***
#      ( double-lane with 20.0% distracted drivers)
#
#
# Right lane stats:
# Number of vehicles waiting in right lane per minute: 3.1666666666666665
# Average wait time for a vehicle on the right lane (minutes): 1.5095925501850678
#
#
# Left lane stats:
# Number of vehicles waiting in left lane per minute: 45.916666666666664
# Average wait time for a vehicle on left lane (minutes): 23.448533952648308
#
#
# Pedestrians stats:
# Number of pedestrians waiting to cross per minute: 0.9833333333333333
# Average wait time for a pedestrian (minutes): 0.5203556996364929
