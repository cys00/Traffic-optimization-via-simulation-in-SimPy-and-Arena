# %%
#Baseline model overview
#Vehicles arrive on a go-straight-only, single lane according to a Poisson process 
#with an average interarrival time equal to ? minutes, 
#while pedestrians from both sides of the road arrive according to a Poisson process 
#with an average interarrival time equal to minutes. 
#Assume pedestrians cross the road only when the traffic light is green( which means red for the vehicles) 
#and clear the intersection as a group according to a triangular distribution 
#with lower bound, mode and upper bound equal to ? minutes, ? minutes, and ? minutes respectively. 
#Pedestrians' positions are not taken into account.
#baseline model was inspired by Dr. Phillip M. Feldman, link can be found here: http://phillipmfeldman.org/Python/discrete_event_simulation/traffic_sim.py

# Import all necessary packages
# double-ended queue
from collections import deque 
import numpy as np
import simpy
from simpy.util import start_delayed

#define a utility class to keep track of the stats
class Struct(object): 
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)

random_seed = 0
np.random.seed(random_seed)

end_time= 60

# Cars cars arrive at the traffic light according to a Poisson process 
t_interarrival_mean = 7.91/60

p_interarrival_mean = 30/60 #interarrival time for pedestrian set to be 30 seconds

# Traffic light green and red durations:
t_green= 26/60
t_red= 90/60

# The time for a car at the head of the queue to depart (clear the intersection)
# is modeled as a triangular distribution with specified minimum, maximum, and
# mode.
t_depart_left= 1.8/60
t_depart_mode= 2/60 
t_depart_right= 2.2/60

#the time for a group of pedestrians to cross the road is modeled as a normal distribution
p_crossing_mode = 18/60 
p_crossing_lower = 13/60
p_crossing_upper = 23/60

#initially, no cars are waiting at the light:
queue= deque()
pedestrian = deque()

pedestrian_count = arrival_count= departure_count= 0

Q_stats= Struct(count=0, cars_waiting=0)
W_stats= Struct(count=0, waiting_time=0.0)
P_W_stats = Struct(count=0, waiting_time=0.0)
p_num_stats = Struct(count=0, pedestrian_waiting=0)

def arrival():
    global arrival_count, env, light, queue

    while True:
        
        arrival_count+= 1

        if light == 'red' or len(queue):
            queue.append((arrival_count, env.now))
            print(f"Car {arrival_count} arrived and joined the queue at position {len(queue)} at time {env.now}")

        else:
            print("Car #%d arrived to a green light with no cars waiting at time "
           "%.3f." % (arrival_count, env.now))
            W_stats.count+= 1

      #schedule next arrival:
        yield env.timeout( np.random.exponential(t_interarrival_mean))

def departure():
    global env, queue

    while True:
        
        car_number, t_arrival= queue.popleft()
        print(f"Car {car_number} departed at time {env.now}, leaving {len(queue)} cars in the queue.")

        W_stats.count += 1
        W_stats.waiting_time += env.now - t_arrival

        if light == 'red' or len(queue) == 0:
            return

        delay = np.random.triangular(left=t_depart_left, mode=t_depart_mode,
        right=t_depart_right)

      #schedule next departure:
        yield env.timeout(delay)


def Pedestrian():
    
    global env, light, pedestrian, pedestrian_count
    
    while True:
        
        pedestrian_count += 1
        
        if light == 'red' and len(pedestrian): #assume red light for vehicles means green for pedestrians
            print(f'At time {env.now} pedestrian {pedestrian_count} arrived at the intersection and started to cross the road.')
            P_W_stats.count += 1
        else:
            pedestrian.append((pedestrian_count, env.now))
            print(f'At time {env.now}, pedestrian {pedestrian_count} arrived and started to wait.')
        
        yield env.timeout(np.random.exponential(p_interarrival_mean))
    
def pedestrian_cross():
    global env, pedestrian
    
    while True:
        
        pedestrian_idx, t_arrival = [i[0] for i in pedestrian], [i[1] for i in pedestrian]
        P_W_stats.count += len(pedestrian)
        P_W_stats.waiting_time += len(pedestrian)*env.now - sum(t_arrival)
        pedestrian = deque()
        print(f'Pedestrians {pedestrian_idx} crossed the road at time {env.now}.')
        
        if light == 'green' or len(pedestrian)==0: #assume green light for vehicles means red light for pedestrian
            return
        #schedule next crossing
        yield env.timeout(np.random.triangular(p_crossing_lower,p_crossing_mode,p_crossing_upper))

def light():
    
    global env, light

    while True:
        
        light = 'green'
        print(f"The light turned green at time {env.now}.")

        if len(queue):
            delay= np.random.triangular(left=t_depart_left, mode=t_depart_mode,
            right=t_depart_right)

            start_delayed(env, departure(), delay=delay)

      # Schedule event that will turn the light red:
        yield env.timeout(t_green)

        light= 'red'
        print(f"The light turned red at time {env.now}.")
        
        if len(pedestrian):
            start_delayed(env,pedestrian_cross(),delay=np.random.triangular(p_crossing_lower,p_crossing_mode,p_crossing_upper))

      # Schedule event that will turn the light green:
        yield env.timeout(t_red)


def monitor():
    global env, Q_stats, p_num_stats 
    while True:
        Q_stats.count += 1
        Q_stats.cars_waiting += len(queue)
        p_num_stats.count += 1
        p_num_stats.pedestrian_waiting += len(pedestrian)
        #check the number of vehicles and the number of pedestrians every 1/60 min
        yield env.timeout(1) 

print("\nSimulation of Cars Arriving at Intersection Controlled by a Traffic "
  "Light\n\n")

#initialize environment:
env= simpy.Environment()

#schedule first change of the traffic light:
env.process(light())

#schedule first arrival of a car:
t_first_arrival = np.random.exponential(t_interarrival_mean)
start_delayed(env, arrival(), delay=t_first_arrival)

p_t_first_arrival = np.random.exponential(p_interarrival_mean)
start_delayed(env, Pedestrian(), delay=p_t_first_arrival)

#schedule first statistical monitoring event:
env.process(monitor())

env.run(until=end_time)


#report statistics.

print(f"\n\n      *** Statistics( random seed={random_seed}) ***")
print(' ( Baseline model with no distracted driver)\n\n')
print('Vehicle stats:\n')
print(f"Number of vehicles waiting in queue per minute: {Q_stats.cars_waiting / float(Q_stats.count)}")
print(f"Average waiting time for a vehicle (minutes): {W_stats.waiting_time / float(W_stats.count)}")

print('\n\nPedestrian stats:\n')
print(f"Number of pedestrians waiting to cross per minute: {p_num_stats.pedestrian_waiting / float(p_num_stats.count)}")
print(f"Average waiting time for a pedestrian (minutes): {P_W_stats.waiting_time / float(P_W_stats.count)}")
# Out:
# Simulation of Cars Arriving at Intersection Controlled by a Traffic Light
#
#
# The light turned green at time 0.
# Car #1 arrived to a green light with no cars waiting at time 0.105.
# Car #2 arrived to a green light with no cars waiting at time 0.227.
# Car #3 arrived to a green light with no cars waiting at time 0.330.
# Car #4 arrived to a green light with no cars waiting at time 0.403.
# The light turned red at time 0.43333333333333335.
# Car 5 arrived and joined the queue at position 1 at time 0.5399242857546558
# Car 6 arrived and joined the queue at position 2 at time 0.6157969001783882
# At time 0.6279653814829189, pedestrian 1 arrived and started to wait.
# Car 7 arrived and joined the queue at position 3 at time 0.9089315352965268
# Car 8 arrived and joined the queue at position 4 at time 0.9726864122654739
# Car 9 arrived and joined the queue at position 5 at time 1.1795192200514093
# Car 10 arrived and joined the queue at position 6 at time 1.2787467568253161
# Car 11 arrived and joined the queue at position 7 at time 1.3894119871203843
# Car 12 arrived and joined the queue at position 8 at time 1.7319484930795548
# Car 13 arrived and joined the queue at position 9 at time 1.7416626790355652
# Car 14 arrived and joined the queue at position 10 at time 1.75368074137442
# Car 15 arrived and joined the queue at position 11 at time 1.7563735145522903
# The light turned green at time 1.9333333333333333.
# Car 5 departed at time 1.967779673452194, leaving 10 cars in the queue.
# Car 16 arrived and joined the queue at position 11 at time 1.9920239736481864
# Car 6 departed at time 2.002746746365092, leaving 10 cars in the queue.
# Car 7 departed at time 2.0373007978236797, leaving 9 cars in the queue.
# Car 8 departed at time 2.070503155851595, leaving 8 cars in the queue.
# Car 9 departed at time 2.104961400136593, leaving 7 cars in the queue.
# Car 10 departed at time 2.136582609738978, leaving 6 cars in the queue.
# Car 11 departed at time 2.170420539040386, leaving 5 cars in the queue.
# Car 12 departed at time 2.202205371976291, leaving 4 cars in the queue.
# Car 13 departed at time 2.237763174529948, leaving 3 cars in the queue.
# Car 14 departed at time 2.2711701490562435, leaving 2 cars in the queue.
# At time 2.285421472509826, pedestrian 2 arrived and started to wait.
# Car 15 departed at time 2.304205723100402, leaving 1 cars in the queue.
# Car 16 departed at time 2.3386325171984423, leaving 0 cars in the queue.
# The light turned red at time 2.3666666666666667.
# At time 2.439061649055053 pedestrian 3 arrived at the intersection and started to cross the road.
# Car 17 arrived and joined the queue at position 1 at time 2.4989523859798495
# Car 18 arrived and joined the queue at position 2 at time 2.501453076010674
# Car 19 arrived and joined the queue at position 3 at time 2.6281951285095295
# Pedestrians [1, 2] crossed the road at time 2.6629286930020064.
# Car 20 arrived and joined the queue at position 4 at time 2.7530408572052676
# At time 2.859229002488859, pedestrian 4 arrived and started to wait.
# Car 21 arrived and joined the queue at position 5 at time 2.879541264943405
# Car 22 arrived and joined the queue at position 6 at time 3.0305087509921464
# Car 23 arrived and joined the queue at position 7 at time 3.089242938950548
# Car 24 arrived and joined the queue at position 8 at time 3.164985461505076
# Car 25 arrived and joined the queue at position 9 at time 3.322672339954492
# Car 26 arrived and joined the queue at position 10 at time 3.3308612064673127
# Car 27 arrived and joined the queue at position 11 at time 3.4757345017549643
# Car 28 arrived and joined the queue at position 12 at time 3.622148263377607
# Car 29 arrived and joined the queue at position 13 at time 3.6532881806974737
# Car 30 arrived and joined the queue at position 14 at time 3.671484962683685
# Car 31 arrived and joined the queue at position 15 at time 3.7214447818860106
# Car 32 arrived and joined the queue at position 16 at time 3.781046902981009
# The light turned green at time 3.8666666666666667.
# Car 33 arrived and joined the queue at position 17 at time 3.8923706320634874
# Car 17 departed at time 3.8997886372461505, leaving 16 cars in the queue.
# Car 18 departed at time 3.9312945132241337, leaving 15 cars in the queue.
# Car 19 departed at time 3.9634489750341912, leaving 14 cars in the queue.
# Car 20 departed at time 3.995342293801066, leaving 13 cars in the queue.
# Car 21 departed at time 4.029232505195529, leaving 12 cars in the queue.
# Car 22 departed at time 4.061604993821142, leaving 11 cars in the queue.
# Car 23 departed at time 4.094824071580226, leaving 10 cars in the queue.
# Car 24 departed at time 4.127154668032265, leaving 9 cars in the queue.
# Car 25 departed at time 4.159034204521494, leaving 8 cars in the queue.
# Car 26 departed at time 4.190600340184444, leaving 7 cars in the queue.
# Car 27 departed at time 4.22450347283936, leaving 6 cars in the queue.
# Car 28 departed at time 4.256255823332895, leaving 5 cars in the queue.
# Car 29 departed at time 4.288345918289164, leaving 4 cars in the queue.
# At time 4.298186541859371, pedestrian 5 arrived and started to wait.
# The light turned red at time 4.3.
# Car 30 departed at time 4.321208415919094, leaving 3 cars in the queue.
# Car 34 arrived and joined the queue at position 4 at time 4.479621870073781
# Pedestrians [4, 5] crossed the road at time 4.553390348814011.
# Car 35 arrived and joined the queue at position 5 at time 4.719534664939856
# Car 36 arrived and joined the queue at position 6 at time 4.73285441713968
# At time 5.158352367748393, pedestrian 6 arrived and started to wait.
# Car 37 arrived and joined the queue at position 7 at time 5.227101730057568
# At time 5.474520669081084 pedestrian 7 arrived at the intersection and started to cross the road.
# Car 38 arrived and joined the queue at position 8 at time 5.723049128915328
# The light turned green at time 5.8.
# Car 31 departed at time 5.830933187991711, leaving 7 cars in the queue.
# Car 32 departed at time 5.863440098274981, leaving 6 cars in the queue.
# Car 33 departed at time 5.8950744283192575, leaving 5 cars in the queue.
# Car 39 arrived and joined the queue at position 6 at time 5.9002654629765265
# Car 40 arrived and joined the queue at position 7 at time 5.916927698909828
# Car 34 departed at time 5.927639753499087, leaving 6 cars in the queue.
# At time 5.938759919722802, pedestrian 8 arrived and started to wait.
# Car 35 departed at time 5.9606738669317965, leaving 5 cars in the queue.
# Car 41 arrived and joined the queue at position 6 at time 5.967380441846148
# At time 5.971908617968322, pedestrian 9 arrived and started to wait.
# Car 36 departed at time 5.994726350570653, leaving 5 cars in the queue.
# Car 37 departed at time 6.028138099772815, leaving 4 cars in the queue.
# Car 38 departed at time 6.059582941253996, leaving 3 cars in the queue.
# Car 42 arrived and joined the queue at position 4 at time 6.077605968225718
# Car 39 departed at time 6.093179850404203, leaving 3 cars in the queue.
# Car 40 departed at time 6.125840547691471, leaving 2 cars in the queue.
# At time 6.126116037904243, pedestrian 10 arrived and started to wait.
# Car 41 departed at time 6.159788596980636, leaving 1 cars in the queue.
# Car 42 departed at time 6.193944518756145, leaving 0 cars in the queue.
# At time 6.196781394913857, pedestrian 11 arrived and started to wait.
# The light turned red at time 6.233333333333333.
# At time 6.367608479814757 pedestrian 12 arrived at the intersection and started to cross the road.
# Car 43 arrived and joined the queue at position 1 at time 6.426866207673026
# Car 44 arrived and joined the queue at position 2 at time 6.429544066237792
# Pedestrians [6, 8, 9, 10, 11] crossed the road at time 6.5004412972902275.
# Car 45 arrived and joined the queue at position 3 at time 6.662327598305526
# Car 46 arrived and joined the queue at position 4 at time 6.66294807644643
# At time 6.809173002959559, pedestrian 13 arrived and started to wait.
# Car 47 arrived and joined the queue at position 5 at time 6.812267009803521
# At time 6.966533836499757 pedestrian 14 arrived at the intersection and started to cross the road.
# Car 48 arrived and joined the queue at position 6 at time 6.987441590331141
# Car 49 arrived and joined the queue at position 7 at time 7.025148689201842
# Car 50 arrived and joined the queue at position 8 at time 7.138313495002579
# Car 51 arrived and joined the queue at position 9 at time 7.256514059689975
# Car 52 arrived and joined the queue at position 10 at time 7.368469671338183
# Car 53 arrived and joined the queue at position 11 at time 7.401747040737993
# The light turned green at time 7.733333333333333.
# Car 43 departed at time 7.766485494421355, leaving 10 cars in the queue.
# Car 44 departed at time 7.801304692384159, leaving 9 cars in the queue.
# Car 54 arrived and joined the queue at position 10 at time 7.804139512178615
# Car 45 departed at time 7.835387130282648, leaving 9 cars in the queue.
# Car 55 arrived and joined the queue at position 10 at time 7.850679332930967
# Car 46 departed at time 7.870019632199636, leaving 9 cars in the queue.
# Car 47 departed at time 7.905060829341732, leaving 8 cars in the queue.
# Car 56 arrived and joined the queue at position 9 at time 7.917257638281417
# Car 48 departed at time 7.938677078450955, leaving 8 cars in the queue.
# Car 49 departed at time 7.972729814871498, leaving 7 cars in the queue.
# Car 50 departed at time 8.006925558542914, leaving 6 cars in the queue.
# Car 51 departed at time 8.04026330940986, leaving 5 cars in the queue.
# Car 52 departed at time 8.0759420898339, leaving 4 cars in the queue.
# Car 53 departed at time 8.109796048036113, leaving 3 cars in the queue.
# Car 54 departed at time 8.14286508714943, leaving 2 cars in the queue.
# The light turned red at time 8.166666666666666.
# Car 55 departed at time 8.176574251920268, leaving 1 cars in the queue.
# Car 57 arrived and joined the queue at position 2 at time 8.198699455171953
# Car 58 arrived and joined the queue at position 3 at time 8.246018026548255
# Car 59 arrived and joined the queue at position 4 at time 8.388308405729205
# Pedestrians [13] crossed the road at time 8.399660372217978.
# Car 60 arrived and joined the queue at position 5 at time 8.433474455744769
# Car 61 arrived and joined the queue at position 6 at time 8.560347567984985
# At time 8.604105428021004, pedestrian 15 arrived and started to wait.
# Car 62 arrived and joined the queue at position 7 at time 8.63416910293302
# At time 8.676892414725698 pedestrian 16 arrived at the intersection and started to cross the road.
# Car 63 arrived and joined the queue at position 8 at time 8.680867650682178
# Car 64 arrived and joined the queue at position 9 at time 8.798690933621293
# Car 65 arrived and joined the queue at position 10 at time 8.911287109945786
# Car 66 arrived and joined the queue at position 11 at time 9.050899848934145
# At time 9.098836650027478 pedestrian 17 arrived at the intersection and started to cross the road.
# Car 67 arrived and joined the queue at position 12 at time 9.19009602069008
# At time 9.381141901423323 pedestrian 18 arrived at the intersection and started to cross the road.
# Car 68 arrived and joined the queue at position 13 at time 9.489177598950734
# Car 69 arrived and joined the queue at position 14 at time 9.564647114867592
# At time 9.610228342134585 pedestrian 19 arrived at the intersection and started to cross the road.
# The light turned green at time 9.666666666666666.
# Car 56 departed at time 9.70076813281503, leaving 13 cars in the queue.
# Car 57 departed at time 9.732260534960062, leaving 12 cars in the queue.
# Car 58 departed at time 9.767589563689873, leaving 11 cars in the queue.
# Car 59 departed at time 9.801736271360175, leaving 10 cars in the queue.
# Car 60 departed at time 9.838242869053365, leaving 9 cars in the queue.
# Car 70 arrived and joined the queue at position 10 at time 9.857965026629643
# Car 61 departed at time 9.87006525030789, leaving 9 cars in the queue.
# Car 62 departed at time 9.901965501371281, leaving 8 cars in the queue.
# Car 63 departed at time 9.935709306290672, leaving 7 cars in the queue.
# Car 64 departed at time 9.96736808752231, leaving 6 cars in the queue.
# Car 65 departed at time 10.002196930774186, leaving 5 cars in the queue.
# Car 66 departed at time 10.036794346146973, leaving 4 cars in the queue.
# Car 67 departed at time 10.070366576008356, leaving 3 cars in the queue.
# The light turned red at time 10.1.
# Car 68 departed at time 10.10337465142565, leaving 2 cars in the queue.
# Car 71 arrived and joined the queue at position 3 at time 10.125047335806126
# Car 72 arrived and joined the queue at position 4 at time 10.28264598709312
# Pedestrians [15] crossed the road at time 10.347661064783983.
# Car 73 arrived and joined the queue at position 5 at time 10.362312748651588
# At time 10.430677124000784, pedestrian 20 arrived and started to wait.
# Car 74 arrived and joined the queue at position 6 at time 10.531103471828313
# Car 75 arrived and joined the queue at position 7 at time 11.02019990498902
# Car 76 arrived and joined the queue at position 8 at time 11.275505336908033
# Car 77 arrived and joined the queue at position 9 at time 11.277058760005742
# Car 78 arrived and joined the queue at position 10 at time 11.335889757957393
# At time 11.437063491838732 pedestrian 21 arrived at the intersection and started to cross the road.
# Car 79 arrived and joined the queue at position 11 at time 11.508498925955434
# At time 11.53121097928821 pedestrian 22 arrived at the intersection and started to cross the road.
# At time 11.559146006944744 pedestrian 23 arrived at the intersection and started to cross the road.
# The light turned green at time 11.6.
# Car 80 arrived and joined the queue at position 12 at time 11.60554554351277
# Car 69 departed at time 11.630641557037572, leaving 11 cars in the queue.
# Car 70 departed at time 11.662872275347695, leaving 10 cars in the queue.
# At time 11.670715610666816, pedestrian 24 arrived and started to wait.
# Car 71 departed at time 11.695642560855232, leaving 9 cars in the queue.
# Car 72 departed at time 11.729746305586657, leaving 8 cars in the queue.
# Car 73 departed at time 11.760587454662245, leaving 7 cars in the queue.
# Car 74 departed at time 11.79250053337061, leaving 6 cars in the queue.
# Car 81 arrived and joined the queue at position 7 at time 11.813632954613652
# Car 75 departed at time 11.826266925726495, leaving 6 cars in the queue.
# Car 76 departed at time 11.858566166284083, leaving 5 cars in the queue.
# Car 77 departed at time 11.894023737769539, leaving 4 cars in the queue.
# Car 82 arrived and joined the queue at position 5 at time 11.92713138842612
# Car 78 departed at time 11.927761490932554, leaving 4 cars in the queue.
# Car 79 departed at time 11.961409364523078, leaving 3 cars in the queue.
# Car 80 departed at time 11.995627095046649, leaving 2 cars in the queue.
# Car 83 arrived and joined the queue at position 3 at time 12.02825805785041
# Car 81 departed at time 12.028259985285656, leaving 2 cars in the queue.
# The light turned red at time 12.033333333333333.
# Car 82 departed at time 12.060419428367025, leaving 1 cars in the queue.
# Car 84 arrived and joined the queue at position 2 at time 12.095211608725407
# Pedestrians [20, 24] crossed the road at time 12.300852865903115.
# Car 85 arrived and joined the queue at position 3 at time 12.476088077693051
# Car 86 arrived and joined the queue at position 4 at time 12.653449713537844
# Car 87 arrived and joined the queue at position 5 at time 12.742337624384719
# Car 88 arrived and joined the queue at position 6 at time 12.776352306889978
# Car 89 arrived and joined the queue at position 7 at time 12.815046398826063
# Car 90 arrived and joined the queue at position 8 at time 12.822927522137464
# Car 91 arrived and joined the queue at position 9 at time 12.898059017049448
# Car 92 arrived and joined the queue at position 10 at time 12.947321152600251
# At time 12.98682504754855, pedestrian 25 arrived and started to wait.
# Car 93 arrived and joined the queue at position 11 at time 13.104447780604271
# Car 94 arrived and joined the queue at position 12 at time 13.130546527059268
# Car 95 arrived and joined the queue at position 13 at time 13.133840824919004
# Car 96 arrived and joined the queue at position 14 at time 13.14301875464777
# At time 13.22403319435486 pedestrian 26 arrived at the intersection and started to cross the road.
# Car 97 arrived and joined the queue at position 15 at time 13.29298424670098
# Car 98 arrived and joined the queue at position 16 at time 13.394379874502727
# At time 13.526323808139562 pedestrian 27 arrived at the intersection and started to cross the road.
# The light turned green at time 13.533333333333333.
# Car 83 departed at time 13.565528767911413, leaving 15 cars in the queue.
# Car 84 departed at time 13.599459168684161, leaving 14 cars in the queue.
# Car 85 departed at time 13.631878178475779, leaving 13 cars in the queue.
# Car 86 departed at time 13.662555608250175, leaving 12 cars in the queue.
# Car 99 arrived and joined the queue at position 13 at time 13.693620453443126
# Car 87 departed at time 13.69690508626503, leaving 12 cars in the queue.
# Car 88 departed at time 13.729824233378569, leaving 11 cars in the queue.
# Car 100 arrived and joined the queue at position 12 at time 13.744466948945774
# Car 89 departed at time 13.76346624988568, leaving 11 cars in the queue.
# Car 90 departed at time 13.797261532231119, leaving 10 cars in the queue.
# Car 91 departed at time 13.832245942842809, leaving 9 cars in the queue.
# Car 92 departed at time 13.864711447230311, leaving 8 cars in the queue.
# Car 93 departed at time 13.899259659711664, leaving 7 cars in the queue.
# Car 94 departed at time 13.931290729185315, leaving 6 cars in the queue.
# The light turned red at time 13.966666666666667.
# Car 95 departed at time 13.966933152575454, leaving 5 cars in the queue.
# Car 101 arrived and joined the queue at position 6 at time 13.978885510301192
# Car 102 arrived and joined the queue at position 7 at time 14.010883898275585
# Pedestrians [25] crossed the road at time 14.284117979647519.
# Car 103 arrived and joined the queue at position 8 at time 14.399064537884032
# Car 104 arrived and joined the queue at position 9 at time 14.572096843695498
# Car 105 arrived and joined the queue at position 10 at time 14.610717610480506
# Car 106 arrived and joined the queue at position 11 at time 14.642347528207944
# Car 107 arrived and joined the queue at position 12 at time 14.738615876115544
# Car 108 arrived and joined the queue at position 13 at time 14.742043246146345
# Car 109 arrived and joined the queue at position 14 at time 14.772697793858017
# Car 110 arrived and joined the queue at position 15 at time 14.845580319875873
# Car 111 arrived and joined the queue at position 16 at time 14.907367502335532
# Car 112 arrived and joined the queue at position 17 at time 14.989477166732998
# Car 113 arrived and joined the queue at position 18 at time 15.032351478052364
# Car 114 arrived and joined the queue at position 19 at time 15.14886388739909
# Car 115 arrived and joined the queue at position 20 at time 15.411744726588863
# Car 116 arrived and joined the queue at position 21 at time 15.428228189470994
# The light turned green at time 15.466666666666667.
# Car 96 departed at time 15.49837980612616, leaving 20 cars in the queue.
# Car 117 arrived and joined the queue at position 21 at time 15.5242719149814
# Car 97 departed at time 15.532538085445424, leaving 20 cars in the queue.
# Car 98 departed at time 15.566097131771553, leaving 19 cars in the queue.
# Car 118 arrived and joined the queue at position 20 at time 15.590752819302649
# Car 99 departed at time 15.598115270827515, leaving 19 cars in the queue.
# Car 119 arrived and joined the queue at position 20 at time 15.611381541205814
# Car 100 departed at time 15.631408551126173, leaving 19 cars in the queue.
# Car 101 departed at time 15.666924681157205, leaving 18 cars in the queue.
# Car 120 arrived and joined the queue at position 19 at time 15.66931641076247
# Car 102 departed at time 15.701307711609445, leaving 18 cars in the queue.
# Car 103 departed at time 15.736511654331213, leaving 17 cars in the queue.
# Car 104 departed at time 15.767873209287398, leaving 16 cars in the queue.
# Car 105 departed at time 15.801385311254116, leaving 15 cars in the queue.
# Car 106 departed at time 15.835013250368942, leaving 14 cars in the queue.
# At time 15.846150143914315, pedestrian 28 arrived and started to wait.
# Car 121 arrived and joined the queue at position 15 at time 15.851373376427507
# Car 107 departed at time 15.870760211509635, leaving 14 cars in the queue.
# Car 122 arrived and joined the queue at position 15 at time 15.887697143265664
# Car 123 arrived and joined the queue at position 16 at time 15.88988110648828
# The light turned red at time 15.9.
# Car 108 departed at time 15.90225311280328, leaving 15 cars in the queue.
# At time 16.018909933002625 pedestrian 29 arrived at the intersection and started to cross the road.
# Pedestrians [28] crossed the road at time 16.21562445349871.
# Car 124 arrived and joined the queue at position 16 at time 16.239576734966437
# Car 125 arrived and joined the queue at position 17 at time 16.283201687913103
# Car 126 arrived and joined the queue at position 18 at time 16.39959477188856
# Car 127 arrived and joined the queue at position 19 at time 16.40830790201077
# Car 128 arrived and joined the queue at position 20 at time 16.495951724290997
# At time 16.787824294304002, pedestrian 30 arrived and started to wait.
# Car 129 arrived and joined the queue at position 21 at time 16.99613055255051
# Car 130 arrived and joined the queue at position 22 at time 17.050542105812013
# The light turned green at time 17.4.
# Car 109 departed at time 17.432269124287625, leaving 21 cars in the queue.
# Car 110 departed at time 17.467874542448634, leaving 20 cars in the queue.
# Car 131 arrived and joined the queue at position 21 at time 17.480176510573656
# Car 111 departed at time 17.503399842533877, leaving 20 cars in the queue.
# Car 112 departed at time 17.537200803690617, leaving 19 cars in the queue.
# Car 113 departed at time 17.57219606354215, leaving 18 cars in the queue.
# Car 114 departed at time 17.604747839762346, leaving 17 cars in the queue.
# Car 115 departed at time 17.639582346533714, leaving 16 cars in the queue.
# Car 116 departed at time 17.673334973209492, leaving 15 cars in the queue.
# Car 132 arrived and joined the queue at position 16 at time 17.691829492604775
# Car 117 departed at time 17.70387733138878, leaving 15 cars in the queue.
# Car 118 departed at time 17.735691723609936, leaving 14 cars in the queue.
# Car 133 arrived and joined the queue at position 15 at time 17.748061131742105
# Car 119 departed at time 17.771722944498134, leaving 14 cars in the queue.
# Car 120 departed at time 17.805047571011823, leaving 13 cars in the queue.
# The light turned red at time 17.833333333333332.
# At time 17.833602592311596 pedestrian 31 arrived at the intersection and started to cross the road.
# Car 134 arrived and joined the queue at position 14 at time 17.833857914834194
# Car 121 departed at time 17.83888373916095, leaving 13 cars in the queue.
# At time 17.907215109579294 pedestrian 32 arrived at the intersection and started to cross the road.
# At time 18.012481752508254 pedestrian 33 arrived at the intersection and started to cross the road.
# Car 135 arrived and joined the queue at position 14 at time 18.061485747441374
# Car 136 arrived and joined the queue at position 15 at time 18.094972915000003
# Car 137 arrived and joined the queue at position 16 at time 18.10854757737868
# Pedestrians [30] crossed the road at time 18.1215487990164.
# Car 138 arrived and joined the queue at position 17 at time 18.36982679051433
# At time 18.37050441171019, pedestrian 34 arrived and started to wait.
# Car 139 arrived and joined the queue at position 18 at time 18.845605507332127
# Car 140 arrived and joined the queue at position 19 at time 19.158101605072662
# The light turned green at time 19.333333333333332.
# Car 141 arrived and joined the queue at position 20 at time 19.354194425580374
# Car 142 arrived and joined the queue at position 21 at time 19.36534482156554
# Car 122 departed at time 19.366054220247673, leaving 20 cars in the queue.
# Car 123 departed at time 19.398325950582663, leaving 19 cars in the queue.
# Car 124 departed at time 19.430041808869728, leaving 18 cars in the queue.
# Car 143 arrived and joined the queue at position 19 at time 19.434289391391026
# Car 125 departed at time 19.461131428393404, leaving 18 cars in the queue.
# Car 126 departed at time 19.491635356488473, leaving 17 cars in the queue.
# Car 127 departed at time 19.526044102521276, leaving 16 cars in the queue.
# Car 128 departed at time 19.557851166717395, leaving 15 cars in the queue.
# Car 129 departed at time 19.589180511439736, leaving 14 cars in the queue.
# Car 144 arrived and joined the queue at position 15 at time 19.604769382257253
# Car 130 departed at time 19.620591602697818, leaving 14 cars in the queue.
# Car 131 departed at time 19.652926683994774, leaving 13 cars in the queue.
# Car 132 departed at time 19.685983695849803, leaving 12 cars in the queue.
# Car 133 departed at time 19.719514083019728, leaving 11 cars in the queue.
# Car 145 arrived and joined the queue at position 12 at time 19.751748709150757
# Car 134 departed at time 19.75442039097187, leaving 11 cars in the queue.
# The light turned red at time 19.766666666666666.
# Car 135 departed at time 19.786871367671694, leaving 10 cars in the queue.
# Car 146 arrived and joined the queue at position 11 at time 19.92292712489245
# Car 147 arrived and joined the queue at position 12 at time 19.930437213251448
# Car 148 arrived and joined the queue at position 13 at time 19.977760280505656
# At time 19.990485940471764 pedestrian 35 arrived at the intersection and started to cross the road.
# Car 149 arrived and joined the queue at position 14 at time 20.017833864633296
# Pedestrians [34] crossed the road at time 20.02606680955695.
# Car 150 arrived and joined the queue at position 15 at time 20.169408104944054
# At time 20.295018170656626, pedestrian 36 arrived and started to wait.
# Car 151 arrived and joined the queue at position 16 at time 20.32622336047118
# Car 152 arrived and joined the queue at position 17 at time 20.389228882788032
# Car 153 arrived and joined the queue at position 18 at time 20.41557650436102
# At time 20.461719838523376 pedestrian 37 arrived at the intersection and started to cross the road.
# At time 20.49098378986308 pedestrian 38 arrived at the intersection and started to cross the road.
# Car 154 arrived and joined the queue at position 19 at time 20.620411951704906
# Car 155 arrived and joined the queue at position 20 at time 20.819244992535253
# Car 156 arrived and joined the queue at position 21 at time 21.017313081489938
# Car 157 arrived and joined the queue at position 22 at time 21.056905937688253
# At time 21.08799047501125 pedestrian 39 arrived at the intersection and started to cross the road.
# Car 158 arrived and joined the queue at position 23 at time 21.11861797144146
# Car 159 arrived and joined the queue at position 24 at time 21.160617943047395
# Car 160 arrived and joined the queue at position 25 at time 21.221708194829482
# Car 161 arrived and joined the queue at position 26 at time 21.250641414458638
# The light turned green at time 21.266666666666666.
# Car 136 departed at time 21.297662349584222, leaving 25 cars in the queue.
# Car 162 arrived and joined the queue at position 26 at time 21.331840107931946
# Car 137 departed at time 21.33221975563568, leaving 25 cars in the queue.
# Car 163 arrived and joined the queue at position 26 at time 21.34239717087366
# Car 138 departed at time 21.36561647547584, leaving 25 cars in the queue.
# Car 164 arrived and joined the queue at position 26 at time 21.39070766603099
# Car 139 departed at time 21.399219168501887, leaving 25 cars in the queue.
# Car 140 departed at time 21.433079375336334, leaving 24 cars in the queue.
# Car 141 departed at time 21.463965846940887, leaving 23 cars in the queue.
# Car 142 departed at time 21.497058499306696, leaving 22 cars in the queue.
# Car 143 departed at time 21.53042539107302, leaving 21 cars in the queue.
# At time 21.530870796137695, pedestrian 40 arrived and started to wait.
# Car 144 departed at time 21.563881580082956, leaving 20 cars in the queue.
# Car 145 departed at time 21.596365287427194, leaving 19 cars in the queue.
# Car 146 departed at time 21.62805749548812, leaving 18 cars in the queue.
# Car 147 departed at time 21.66101149720537, leaving 17 cars in the queue.
# Car 148 departed at time 21.696693906936247, leaving 16 cars in the queue.
# The light turned red at time 21.7.
# Car 149 departed at time 21.728733138227966, leaving 15 cars in the queue.
# Car 165 arrived and joined the queue at position 16 at time 21.813208286574167
# Car 166 arrived and joined the queue at position 17 at time 21.91667596597785
# Car 167 arrived and joined the queue at position 18 at time 21.99715795432796
# Pedestrians [36, 40] crossed the road at time 22.046815444818904.
# At time 22.102768483425415, pedestrian 41 arrived and started to wait.
# Car 168 arrived and joined the queue at position 19 at time 22.278941375220555
# At time 22.40957059315819 pedestrian 42 arrived at the intersection and started to cross the road.
# Car 169 arrived and joined the queue at position 20 at time 22.448737695831547
# At time 22.664171832134194 pedestrian 43 arrived at the intersection and started to cross the road.
# Car 170 arrived and joined the queue at position 21 at time 22.75773784080315
# Car 171 arrived and joined the queue at position 22 at time 22.916295607211683
# Car 172 arrived and joined the queue at position 23 at time 22.96864411322857
# Car 173 arrived and joined the queue at position 24 at time 23.155027880262946
# The light turned green at time 23.2.
# Car 150 departed at time 23.23230949861504, leaving 23 cars in the queue.
# At time 23.249803679661433, pedestrian 44 arrived and started to wait.
# Car 151 departed at time 23.26419828907154, leaving 22 cars in the queue.
# Car 174 arrived and joined the queue at position 23 at time 23.288280947877286
# Car 152 departed at time 23.29991237565158, leaving 22 cars in the queue.
# Car 153 departed at time 23.33356420554479, leaving 21 cars in the queue.
# Car 154 departed at time 23.368452749882167, leaving 20 cars in the queue.
# Car 175 arrived and joined the queue at position 21 at time 23.369061222931183
# Car 155 departed at time 23.40164030712646, leaving 20 cars in the queue.
# Car 156 departed at time 23.435236509340545, leaving 19 cars in the queue.
# Car 157 departed at time 23.46990744233928, leaving 18 cars in the queue.
# Car 158 departed at time 23.50515083983029, leaving 17 cars in the queue.
# Car 159 departed at time 23.539792791530836, leaving 16 cars in the queue.
# Car 160 departed at time 23.571674956144307, leaving 15 cars in the queue.
# Car 161 departed at time 23.605469915765646, leaving 14 cars in the queue.
# The light turned red at time 23.633333333333333.
# Car 162 departed at time 23.638445498840607, leaving 13 cars in the queue.
# Car 176 arrived and joined the queue at position 14 at time 23.76903599106474
# Car 177 arrived and joined the queue at position 15 at time 23.841768917341426
# Pedestrians [41, 44] crossed the road at time 23.879512933140344.
# Car 178 arrived and joined the queue at position 16 at time 23.881230375975804
# At time 24.04558174040917, pedestrian 45 arrived and started to wait.
# At time 24.062517668129562 pedestrian 46 arrived at the intersection and started to cross the road.
# Car 179 arrived and joined the queue at position 17 at time 24.13049150522445
# Car 180 arrived and joined the queue at position 18 at time 24.18837648759608
# Car 181 arrived and joined the queue at position 19 at time 24.246535396931648
# Car 182 arrived and joined the queue at position 20 at time 24.24870580625673
# Car 183 arrived and joined the queue at position 21 at time 24.27571216359051
# Car 184 arrived and joined the queue at position 22 at time 24.343333039508455
# Car 185 arrived and joined the queue at position 23 at time 24.692584366025123
# Car 186 arrived and joined the queue at position 24 at time 24.706418000477626
# Car 187 arrived and joined the queue at position 25 at time 25.089515068311126
# The light turned green at time 25.133333333333333.
# Car 163 departed at time 25.16651020250109, leaving 24 cars in the queue.
# Car 164 departed at time 25.199204644854316, leaving 23 cars in the queue.
# Car 165 departed at time 25.231478868185864, leaving 22 cars in the queue.
# Car 166 departed at time 25.26521851401776, leaving 21 cars in the queue.
# Car 167 departed at time 25.296075830133134, leaving 20 cars in the queue.
# Car 168 departed at time 25.326664728623665, leaving 19 cars in the queue.
# Car 188 arrived and joined the queue at position 20 at time 25.35796651606644
# Car 169 departed at time 25.35975160306771, leaving 19 cars in the queue.
# Car 189 arrived and joined the queue at position 20 at time 25.36726102260999
# Car 170 departed at time 25.392117757886755, leaving 19 cars in the queue.
# Car 190 arrived and joined the queue at position 20 at time 25.400212872512334
# Car 191 arrived and joined the queue at position 21 at time 25.418732254002425
# Car 192 arrived and joined the queue at position 22 at time 25.420328656103052
# Car 171 departed at time 25.424489776219655, leaving 21 cars in the queue.
# Car 193 arrived and joined the queue at position 22 at time 25.436506585206633
# Car 172 departed at time 25.4582447051826, leaving 21 cars in the queue.
# Car 173 departed at time 25.49444817046664, leaving 20 cars in the queue.
# Car 174 departed at time 25.52746314824571, leaving 19 cars in the queue.
# Car 175 departed at time 25.559366095819268, leaving 18 cars in the queue.
# The light turned red at time 25.566666666666666.
# Car 176 departed at time 25.593199475260295, leaving 17 cars in the queue.
# At time 25.65939860967225 pedestrian 47 arrived at the intersection and started to cross the road.
# Pedestrians [45] crossed the road at time 25.86585482435139.
# Car 194 arrived and joined the queue at position 18 at time 25.918958836336248
# Car 195 arrived and joined the queue at position 19 at time 25.927862089482833
# Car 196 arrived and joined the queue at position 20 at time 26.129427197223357
# Car 197 arrived and joined the queue at position 21 at time 26.174281802941664
# Car 198 arrived and joined the queue at position 22 at time 26.210708037861234
# Car 199 arrived and joined the queue at position 23 at time 26.353905841429274
# Car 200 arrived and joined the queue at position 24 at time 26.391141733252407
# Car 201 arrived and joined the queue at position 25 at time 26.535656453892184
# Car 202 arrived and joined the queue at position 26 at time 26.631680898372117
# Car 203 arrived and joined the queue at position 27 at time 26.704426811723916
# Car 204 arrived and joined the queue at position 28 at time 26.811077300752718
# Car 205 arrived and joined the queue at position 29 at time 26.85568259745807
# Car 206 arrived and joined the queue at position 30 at time 27.01732769354174
# The light turned green at time 27.066666666666666.
# Car 207 arrived and joined the queue at position 31 at time 27.08797701786703
# Car 177 departed at time 27.09949723614406, leaving 30 cars in the queue.
# Car 178 departed at time 27.13487262361683, leaving 29 cars in the queue.
# Car 179 departed at time 27.165883754017116, leaving 28 cars in the queue.
# Car 180 departed at time 27.198157404986272, leaving 27 cars in the queue.
# Car 181 departed at time 27.2309403665163, leaving 26 cars in the queue.
# Car 182 departed at time 27.265579261989267, leaving 25 cars in the queue.
# Car 183 departed at time 27.301678114673155, leaving 24 cars in the queue.
# Car 208 arrived and joined the queue at position 25 at time 27.32054253810698
# Car 184 departed at time 27.337514409330424, leaving 24 cars in the queue.
# Car 185 departed at time 27.370081535977796, leaving 23 cars in the queue.
# Car 186 departed at time 27.40632686201727, leaving 22 cars in the queue.
# Car 187 departed at time 27.438681149081123, leaving 21 cars in the queue.
# Car 188 departed at time 27.470215251459877, leaving 20 cars in the queue.
# The light turned red at time 27.5.
# Car 189 departed at time 27.505837915264216, leaving 19 cars in the queue.
# Car 209 arrived and joined the queue at position 20 at time 27.63079050978035
# Car 210 arrived and joined the queue at position 21 at time 27.665833991471484
# Car 211 arrived and joined the queue at position 22 at time 27.820136435046155
# Car 212 arrived and joined the queue at position 23 at time 27.828063359332706
# At time 27.933310654095727, pedestrian 48 arrived and started to wait.
# Car 213 arrived and joined the queue at position 24 at time 28.00102382377183
# Car 214 arrived and joined the queue at position 25 at time 28.04295401423483
# Car 215 arrived and joined the queue at position 26 at time 28.105774683347956
# Car 216 arrived and joined the queue at position 27 at time 28.167588453599308
# Car 217 arrived and joined the queue at position 28 at time 28.34971081161853
# Car 218 arrived and joined the queue at position 29 at time 28.385510916961145
# Car 219 arrived and joined the queue at position 30 at time 28.410370033038788
# Car 220 arrived and joined the queue at position 31 at time 28.489015197218613
# Car 221 arrived and joined the queue at position 32 at time 28.536881091527952
# Car 222 arrived and joined the queue at position 33 at time 28.777809972363308
# Car 223 arrived and joined the queue at position 34 at time 28.813598763365576
# Car 224 arrived and joined the queue at position 35 at time 28.90561019718083
# The light turned green at time 29.0.
# At time 29.00066184368525, pedestrian 49 arrived and started to wait.
# Car 190 departed at time 29.03381475774551, leaving 34 cars in the queue.
# Car 191 departed at time 29.06932874337655, leaving 33 cars in the queue.
# Car 192 departed at time 29.103641995794778, leaving 32 cars in the queue.
# Car 193 departed at time 29.137724845561433, leaving 31 cars in the queue.
# Car 194 departed at time 29.173547784607546, leaving 30 cars in the queue.
# Car 195 departed at time 29.20986170930518, leaving 29 cars in the queue.
# Car 196 departed at time 29.24303038124104, leaving 28 cars in the queue.
# Car 197 departed at time 29.27428532504841, leaving 27 cars in the queue.
# Car 225 arrived and joined the queue at position 28 at time 29.282314098824575
# Car 226 arrived and joined the queue at position 29 at time 29.304105228061673
# Car 198 departed at time 29.30683611591244, leaving 28 cars in the queue.
# Car 199 departed at time 29.338544196892002, leaving 27 cars in the queue.
# Car 200 departed at time 29.372244825438067, leaving 26 cars in the queue.
# Car 227 arrived and joined the queue at position 27 at time 29.37534831772834
# Car 201 departed at time 29.40516147518719, leaving 26 cars in the queue.
# The light turned red at time 29.433333333333334.
# Car 202 departed at time 29.440982166700536, leaving 25 cars in the queue.
# Car 228 arrived and joined the queue at position 26 at time 29.67295900748284
# Car 229 arrived and joined the queue at position 27 at time 29.7153223706069
# Pedestrians [48, 49] crossed the road at time 29.73733656358725.
# Car 230 arrived and joined the queue at position 28 at time 29.833583859879948
# At time 30.01045409496906, pedestrian 50 arrived and started to wait.
# Car 231 arrived and joined the queue at position 29 at time 30.132939144422327
# Car 232 arrived and joined the queue at position 30 at time 30.238819344121392
# At time 30.271509750619728 pedestrian 51 arrived at the intersection and started to cross the road.
# Car 233 arrived and joined the queue at position 31 at time 30.280607528312586
# Car 234 arrived and joined the queue at position 32 at time 30.348328413497292
# Car 235 arrived and joined the queue at position 33 at time 30.385975917017465
# Car 236 arrived and joined the queue at position 34 at time 30.478911735741097
# Car 237 arrived and joined the queue at position 35 at time 30.527903079503307
# At time 30.57540213546624 pedestrian 52 arrived at the intersection and started to cross the road.
# Car 238 arrived and joined the queue at position 36 at time 30.58945136220981
# Car 239 arrived and joined the queue at position 37 at time 30.772525318242703
# Car 240 arrived and joined the queue at position 38 at time 30.82601357418645
# The light turned green at time 30.933333333333334.
# At time 30.94759126049143, pedestrian 53 arrived and started to wait.
# Car 203 departed at time 30.968250832241296, leaving 37 cars in the queue.
# At time 30.9725490645005, pedestrian 54 arrived and started to wait.
# Car 204 departed at time 31.00062496377494, leaving 36 cars in the queue.
# Car 205 departed at time 31.032149779893125, leaving 35 cars in the queue.
# Car 206 departed at time 31.06493256821914, leaving 34 cars in the queue.
# Car 207 departed at time 31.09919598489011, leaving 33 cars in the queue.
# Car 208 departed at time 31.133198129423853, leaving 32 cars in the queue.
# Car 241 arrived and joined the queue at position 33 at time 31.166026658883165
# Car 209 departed at time 31.166967994899036, leaving 32 cars in the queue.
# Car 210 departed at time 31.19910197233805, leaving 31 cars in the queue.
# Car 211 departed at time 31.23185756509487, leaving 30 cars in the queue.
# Car 212 departed at time 31.26584195446324, leaving 29 cars in the queue.
# At time 31.267966679422642, pedestrian 55 arrived and started to wait.
# Car 213 departed at time 31.300870429464492, leaving 28 cars in the queue.
# Car 242 arrived and joined the queue at position 29 at time 31.32946019125309
# Car 214 departed at time 31.333376864076737, leaving 28 cars in the queue.
# Car 243 arrived and joined the queue at position 29 at time 31.333507708053716
# Car 244 arrived and joined the queue at position 30 at time 31.33455121468342
# The light turned red at time 31.366666666666667.
# Car 215 departed at time 31.367506414396814, leaving 29 cars in the queue.
# Car 245 arrived and joined the queue at position 30 at time 31.396024705012977
# At time 31.660245027561363 pedestrian 56 arrived at the intersection and started to cross the road.
# Pedestrians [50, 53, 54, 55] crossed the road at time 31.669251523454584.
# At time 31.70712272188883, pedestrian 57 arrived and started to wait.
# Car 246 arrived and joined the queue at position 31 at time 31.73252618647907
# Car 247 arrived and joined the queue at position 32 at time 31.735771085399122
# Car 248 arrived and joined the queue at position 33 at time 31.79107244329658
# Car 249 arrived and joined the queue at position 34 at time 31.919408572762258
# Car 250 arrived and joined the queue at position 35 at time 31.962545808885476
# At time 31.96751215352383 pedestrian 58 arrived at the intersection and started to cross the road.
# Car 251 arrived and joined the queue at position 36 at time 31.993580148646476
# At time 32.02899343541189 pedestrian 59 arrived at the intersection and started to cross the road.
# Car 252 arrived and joined the queue at position 37 at time 32.1070510367358
# Car 253 arrived and joined the queue at position 38 at time 32.25399392158304
# At time 32.62315801526924 pedestrian 60 arrived at the intersection and started to cross the road.
# At time 32.624511452356245 pedestrian 61 arrived at the intersection and started to cross the road.
# Car 254 arrived and joined the queue at position 39 at time 32.64596187833413
# Car 255 arrived and joined the queue at position 40 at time 32.76688887805407
# The light turned green at time 32.86666666666667.
# Car 256 arrived and joined the queue at position 41 at time 32.884026580013234
# Car 257 arrived and joined the queue at position 42 at time 32.88626980610705
# Car 216 departed at time 32.90242375858337, leaving 41 cars in the queue.
# Car 217 departed at time 32.93705560966845, leaving 40 cars in the queue.
# Car 218 departed at time 32.970421795550685, leaving 39 cars in the queue.
# Car 219 departed at time 33.003146027836415, leaving 38 cars in the queue.
# Car 220 departed at time 33.037656773267805, leaving 37 cars in the queue.
# Car 258 arrived and joined the queue at position 38 at time 33.04345676992868
# Car 221 departed at time 33.069126791602024, leaving 37 cars in the queue.
# Car 222 departed at time 33.102527309924, leaving 36 cars in the queue.
# Car 259 arrived and joined the queue at position 37 at time 33.12037627105569
# Car 260 arrived and joined the queue at position 38 at time 33.13293794237698
# Car 223 departed at time 33.13658610990583, leaving 37 cars in the queue.
# At time 33.145433687589815, pedestrian 62 arrived and started to wait.
# Car 261 arrived and joined the queue at position 38 at time 33.1670114869627
# Car 224 departed at time 33.169605681482096, leaving 37 cars in the queue.
# Car 225 departed at time 33.20336193072258, leaving 36 cars in the queue.
# Car 226 departed at time 33.23508408358026, leaving 35 cars in the queue.
# Car 227 departed at time 33.2710938236112, leaving 34 cars in the queue.
# The light turned red at time 33.3.
# Car 228 departed at time 33.306072531186445, leaving 33 cars in the queue.
# Car 262 arrived and joined the queue at position 34 at time 33.45441084983353
# Pedestrians [57, 62] crossed the road at time 33.60022703937671.
# At time 33.63357969919538, pedestrian 63 arrived and started to wait.
# Car 263 arrived and joined the queue at position 35 at time 33.79131327171837
# At time 34.0233472138314 pedestrian 64 arrived at the intersection and started to cross the road.
# Car 264 arrived and joined the queue at position 36 at time 34.129852397452765
# Car 265 arrived and joined the queue at position 37 at time 34.58481054814684
# The light turned green at time 34.8.
# Car 229 departed at time 34.830894847192766, leaving 36 cars in the queue.
# Car 230 departed at time 34.86286558875743, leaving 35 cars in the queue.
# Car 231 departed at time 34.89580624128177, leaving 34 cars in the queue.
# At time 34.909023868829365, pedestrian 65 arrived and started to wait.
# Car 266 arrived and joined the queue at position 35 at time 34.91742834964381
# Car 232 departed at time 34.93144164871058, leaving 34 cars in the queue.
# Car 267 arrived and joined the queue at position 35 at time 34.94048735239673
# Car 233 departed at time 34.96651879879166, leaving 34 cars in the queue.
# Car 234 departed at time 35.00175465833843, leaving 33 cars in the queue.
# Car 268 arrived and joined the queue at position 34 at time 35.0184407698282
# Car 235 departed at time 35.03364163396873, leaving 33 cars in the queue.
# Car 236 departed at time 35.06676951487307, leaving 32 cars in the queue.
# At time 35.087381997993965, pedestrian 66 arrived and started to wait.
# Car 237 departed at time 35.098073242597124, leaving 31 cars in the queue.
# Car 238 departed at time 35.1304179707526, leaving 30 cars in the queue.
# Car 269 arrived and joined the queue at position 31 at time 35.16109786679325
# Car 239 departed at time 35.161356237743504, leaving 30 cars in the queue.
# Car 270 arrived and joined the queue at position 31 at time 35.16924729567646
# Car 240 departed at time 35.19252127028541, leaving 30 cars in the queue.
# Car 241 departed at time 35.22678369957163, leaving 29 cars in the queue.
# The light turned red at time 35.23333333333333.
# Car 242 departed at time 35.261945281207204, leaving 28 cars in the queue.
# Car 271 arrived and joined the queue at position 29 at time 35.48341512932614
# Pedestrians [63, 65, 66] crossed the road at time 35.5492317506464.
# Car 272 arrived and joined the queue at position 30 at time 35.58265526203006
# Car 273 arrived and joined the queue at position 31 at time 35.6305169782976
# At time 35.683508118709845, pedestrian 67 arrived and started to wait.
# At time 35.90836480379882 pedestrian 68 arrived at the intersection and started to cross the road.
# At time 36.2264165313713 pedestrian 69 arrived at the intersection and started to cross the road.
# Car 274 arrived and joined the queue at position 32 at time 36.44734440352401
# At time 36.4640212492972 pedestrian 70 arrived at the intersection and started to cross the road.
# At time 36.56000019931977 pedestrian 71 arrived at the intersection and started to cross the road.
# The light turned green at time 36.73333333333333.
# At time 36.75873974073319, pedestrian 72 arrived and started to wait.
# Car 243 departed at time 36.767334786504335, leaving 31 cars in the queue.
# ...
# Car 329 departed at time 48.53690418265373, leaving 35 cars in the queue.
# Car 330 departed at time 48.569436506828396, leaving 34 cars in the queue.
# Car 331 departed at time 48.6044325110654, leaving 33 cars in the queue.
# Car 332 departed at time 48.63601313905039, leaving 32 cars in the queue.
# Car 333 departed at time 48.66818587087561, leaving 31 cars in the queue.
# Car 334 departed at time 48.70020265209594, leaving 30 cars in the queue.
# At time 48.71638582971501, pedestrian 99 arrived and started to wait.
# Car 365 arrived and joined the queue at position 31 at time 48.73159560649885
# Car 335 departed at time 48.733195332063254, leaving 30 cars in the queue.
# Car 336 departed at time 48.76648733018509, leaving 29 cars in the queue.
# The light turned red at time 48.76666666666664.
# Car 337 departed at time 48.7965974780551, leaving 28 cars in the queue.
# Car 366 arrived and joined the queue at position 29 at time 48.830268142358335
# Car 367 arrived and joined the queue at position 30 at time 48.838924738231405
# Car 368 arrived and joined the queue at position 31 at time 48.8697096278241
# Pedestrians [98, 99] crossed the road at time 49.060199172928.
# Car 369 arrived and joined the queue at position 32 at time 49.22487622664533
# Car 370 arrived and joined the queue at position 33 at time 49.25685621908809
# At time 49.40008868978272, pedestrian 100 arrived and started to wait.
# Car 371 arrived and joined the queue at position 34 at time 49.514499261176724
# Car 372 arrived and joined the queue at position 35 at time 49.537350924061485
# Car 373 arrived and joined the queue at position 36 at time 49.660044722231646
# Car 374 arrived and joined the queue at position 37 at time 49.676249120761945
# Car 375 arrived and joined the queue at position 38 at time 49.847835756220974
# Car 376 arrived and joined the queue at position 39 at time 49.98159738245679
# Car 377 arrived and joined the queue at position 40 at time 50.20188911193824
# At time 50.21209390756429 pedestrian 101 arrived at the intersection and started to cross the road.
# The light turned green at time 50.26666666666664.
# Car 378 arrived and joined the queue at position 41 at time 50.28794247764477
# Car 338 departed at time 50.29771387403004, leaving 40 cars in the queue.
# Car 339 departed at time 50.33186416145248, leaving 39 cars in the queue.
# Car 379 arrived and joined the queue at position 40 at time 50.33363156164532
# Car 380 arrived and joined the queue at position 41 at time 50.35866562583529
# Car 340 departed at time 50.36491232742838, leaving 40 cars in the queue.
# Car 381 arrived and joined the queue at position 41 at time 50.37361614849438
# Car 341 departed at time 50.39956426561299, leaving 40 cars in the queue.
# Car 342 departed at time 50.43461355217535, leaving 39 cars in the queue.
# Car 382 arrived and joined the queue at position 40 at time 50.458098385868915
# Car 343 departed at time 50.468845694632584, leaving 39 cars in the queue.
# Car 344 departed at time 50.501726709169, leaving 38 cars in the queue.
# Car 383 arrived and joined the queue at position 39 at time 50.52759680487786
# Car 345 departed at time 50.53511258442251, leaving 38 cars in the queue.
# Car 346 departed at time 50.569363003216104, leaving 37 cars in the queue.
# Car 347 departed at time 50.59970139694697, leaving 36 cars in the queue.
# Car 348 departed at time 50.633761055329835, leaving 35 cars in the queue.
# Car 349 departed at time 50.66909029002029, leaving 34 cars in the queue.
# The light turned red at time 50.69999999999997.
# Car 350 departed at time 50.7032203612412, leaving 33 cars in the queue.
# Car 384 arrived and joined the queue at position 34 at time 50.81746736918596
# Car 385 arrived and joined the queue at position 35 at time 50.90457164158152
# Car 386 arrived and joined the queue at position 36 at time 50.92450357861386
# Pedestrians [100] crossed the road at time 50.966249059034105.
# Car 387 arrived and joined the queue at position 37 at time 50.98313229506369
# Car 388 arrived and joined the queue at position 38 at time 51.34784658680173
# At time 51.443841201042446, pedestrian 102 arrived and started to wait.
# At time 51.61006716202923 pedestrian 103 arrived at the intersection and started to cross the road.
# Car 389 arrived and joined the queue at position 39 at time 51.686384405569605
# Car 390 arrived and joined the queue at position 40 at time 51.80725224351786
# At time 51.81754545011261 pedestrian 104 arrived at the intersection and started to cross the road.
# At time 51.897513251789874 pedestrian 105 arrived at the intersection and started to cross the road.
# At time 52.045986777644906 pedestrian 106 arrived at the intersection and started to cross the road.
# The light turned green at time 52.19999999999997.
# Car 351 departed at time 52.23330619698176, leaving 39 cars in the queue.
# Car 391 arrived and joined the queue at position 40 at time 52.24259015936382
# Car 352 departed at time 52.268474428110395, leaving 39 cars in the queue.
# Car 392 arrived and joined the queue at position 40 at time 52.26964273176838
# Car 353 departed at time 52.30191849605853, leaving 39 cars in the queue.
# Car 393 arrived and joined the queue at position 40 at time 52.321707050030454
# Car 354 departed at time 52.3345707176007, leaving 39 cars in the queue.
# Car 355 departed at time 52.36767296570705, leaving 38 cars in the queue.
# Car 394 arrived and joined the queue at position 39 at time 52.39977542965812
# Car 356 departed at time 52.400490951116986, leaving 38 cars in the queue.
# Car 357 departed at time 52.43471605264553, leaving 37 cars in the queue.
# Car 358 departed at time 52.46892212765494, leaving 36 cars in the queue.
# Car 359 departed at time 52.50146033984112, leaving 35 cars in the queue.
# Car 360 departed at time 52.53506363662885, leaving 34 cars in the queue.
# Car 361 departed at time 52.569515100436995, leaving 33 cars in the queue.
# Car 362 departed at time 52.6040504679096, leaving 32 cars in the queue.
# The light turned red at time 52.6333333333333.
# Car 363 departed at time 52.636817457692956, leaving 31 cars in the queue.
# Car 395 arrived and joined the queue at position 32 at time 52.724712983082306
# Car 396 arrived and joined the queue at position 33 at time 52.90023645662943
# Car 397 arrived and joined the queue at position 34 at time 52.92035107950227
# Pedestrians [102] crossed the road at time 52.960254586174635.
# At time 53.079967927316176, pedestrian 107 arrived and started to wait.
# Car 398 arrived and joined the queue at position 35 at time 53.1852712980283
# Car 399 arrived and joined the queue at position 36 at time 53.273115917884496
# Car 400 arrived and joined the queue at position 37 at time 53.35154043800356
# At time 53.37105845335271 pedestrian 108 arrived at the intersection and started to cross the road.
# Car 401 arrived and joined the queue at position 38 at time 53.462145081582584
# Car 402 arrived and joined the queue at position 39 at time 53.553045868730386
# Car 403 arrived and joined the queue at position 40 at time 53.81879781086172
# At time 53.85639132165891 pedestrian 109 arrived at the intersection and started to cross the road.
# Car 404 arrived and joined the queue at position 41 at time 53.94906874224931
# Car 405 arrived and joined the queue at position 42 at time 54.020132118112556
# At time 54.11299550954662 pedestrian 110 arrived at the intersection and started to cross the road.
# The light turned green at time 54.1333333333333.
# Car 364 departed at time 54.165501049980335, leaving 41 cars in the queue.
# Car 365 departed at time 54.196649799909665, leaving 40 cars in the queue.
# Car 366 departed at time 54.2316566596794, leaving 39 cars in the queue.
# Car 406 arrived and joined the queue at position 40 at time 54.23965501801192
# Car 407 arrived and joined the queue at position 41 at time 54.25652572328162
# Car 367 departed at time 54.266977934632685, leaving 40 cars in the queue.
# Car 368 departed at time 54.298952056488176, leaving 39 cars in the queue.
# Car 408 arrived and joined the queue at position 40 at time 54.31020524885329
# At time 54.32699808510285, pedestrian 111 arrived and started to wait.
# Car 369 departed at time 54.33055689963611, leaving 39 cars in the queue.
# At time 54.35627750752567, pedestrian 112 arrived and started to wait.
# Car 370 departed at time 54.366565043772475, leaving 38 cars in the queue.
# Car 371 departed at time 54.40148987647074, leaving 37 cars in the queue.
# At time 54.406989898881406, pedestrian 113 arrived and started to wait.
# Car 372 departed at time 54.43505280384061, leaving 36 cars in the queue.
# Car 373 departed at time 54.467810993168676, leaving 35 cars in the queue.
# Car 374 departed at time 54.502155611617056, leaving 34 cars in the queue.
# Car 375 departed at time 54.534799570328296, leaving 33 cars in the queue.
# The light turned red at time 54.56666666666663.
# Car 376 departed at time 54.56870668355531, leaving 32 cars in the queue.
# Car 409 arrived and joined the queue at position 33 at time 54.613587156748544
# At time 54.636357566934876 pedestrian 114 arrived at the intersection and started to cross the road.
# Car 410 arrived and joined the queue at position 34 at time 54.701061430522024
# Car 411 arrived and joined the queue at position 35 at time 54.80769926413732
# Pedestrians [107, 111, 112, 113] crossed the road at time 54.86812323653431.
# Car 412 arrived and joined the queue at position 36 at time 55.03889063769407
# Car 413 arrived and joined the queue at position 37 at time 55.20936062148269
# Car 414 arrived and joined the queue at position 38 at time 55.21454434163616
# Car 415 arrived and joined the queue at position 39 at time 55.410091431929665
# Car 416 arrived and joined the queue at position 40 at time 55.442318998334095
# Car 417 arrived and joined the queue at position 41 at time 55.75009554834213
# Car 418 arrived and joined the queue at position 42 at time 55.75587942932987
# At time 55.79349499660733, pedestrian 115 arrived and started to wait.
# Car 419 arrived and joined the queue at position 43 at time 55.80928158435646
# At time 55.846026913796 pedestrian 116 arrived at the intersection and started to cross the road.
# Car 420 arrived and joined the queue at position 44 at time 55.89437733459218
# Car 421 arrived and joined the queue at position 45 at time 55.94105804200993
# Car 422 arrived and joined the queue at position 46 at time 55.96262853475536
# Car 423 arrived and joined the queue at position 47 at time 56.015477381349875
# The light turned green at time 56.06666666666663.
# Car 377 departed at time 56.098432917924704, leaving 46 cars in the queue.
# Car 378 departed at time 56.130680694352286, leaving 45 cars in the queue.
# Car 379 departed at time 56.1619176436865, leaving 44 cars in the queue.
# Car 380 departed at time 56.196027011622036, leaving 43 cars in the queue.
# Car 381 departed at time 56.22899061769699, leaving 42 cars in the queue.
# Car 424 arrived and joined the queue at position 43 at time 56.23713725666518
# Car 382 departed at time 56.261618840489604, leaving 42 cars in the queue.
# Car 383 departed at time 56.29435126937387, leaving 41 cars in the queue.
# Car 384 departed at time 56.32855835736485, leaving 40 cars in the queue.
# Car 385 departed at time 56.36319852949559, leaving 39 cars in the queue.
# Car 386 departed at time 56.39539783667669, leaving 38 cars in the queue.
# Car 425 arrived and joined the queue at position 39 at time 56.40431140491788
# Car 426 arrived and joined the queue at position 40 at time 56.427667580326116
# Car 387 departed at time 56.4313017407743, leaving 39 cars in the queue.
# Car 388 departed at time 56.46330060317762, leaving 38 cars in the queue.
# Car 427 arrived and joined the queue at position 39 at time 56.472975452106006
# Car 389 departed at time 56.49607150618469, leaving 38 cars in the queue.
# The light turned red at time 56.49999999999996.
# Car 390 departed at time 56.52947959739233, leaving 37 cars in the queue.
# Car 428 arrived and joined the queue at position 38 at time 56.559200195586726
# At time 56.70348845358672 pedestrian 117 arrived at the intersection and started to cross the road.
# At time 56.827785715092574 pedestrian 118 arrived at the intersection and started to cross the road.
# Pedestrians [115] crossed the road at time 56.83824176635507.
# Car 429 arrived and joined the queue at position 39 at time 56.849532586993035
# Car 430 arrived and joined the queue at position 40 at time 56.865117421891085
# Car 431 arrived and joined the queue at position 41 at time 56.9461000401727
# Car 432 arrived and joined the queue at position 42 at time 56.99739639756954
# Car 433 arrived and joined the queue at position 43 at time 57.0475628981274
# Car 434 arrived and joined the queue at position 44 at time 57.13442900903266
# Car 435 arrived and joined the queue at position 45 at time 57.30695865122587
# At time 57.31540023973997, pedestrian 119 arrived and started to wait.
# Car 436 arrived and joined the queue at position 46 at time 57.31641007520579
# Car 437 arrived and joined the queue at position 47 at time 57.491395485769544
# Car 438 arrived and joined the queue at position 48 at time 57.51699633092529
# Car 439 arrived and joined the queue at position 49 at time 57.88606674732329
# Car 440 arrived and joined the queue at position 50 at time 57.979121568538474
# The light turned green at time 57.99999999999996.
# Car 391 departed at time 58.032093691446505, leaving 49 cars in the queue.
# Car 392 departed at time 58.06554549056236, leaving 48 cars in the queue.
# Car 393 departed at time 58.09808516701839, leaving 47 cars in the queue.
# Car 394 departed at time 58.13068505401333, leaving 46 cars in the queue.
# Car 395 departed at time 58.164337183239276, leaving 45 cars in the queue.
# Car 396 departed at time 58.199684919926085, leaving 44 cars in the queue.
# Car 397 departed at time 58.23427132942692, leaving 43 cars in the queue.
# Car 398 departed at time 58.26846117644152, leaving 42 cars in the queue.
# Car 399 departed at time 58.301997964807754, leaving 41 cars in the queue.
# Car 400 departed at time 58.33735059193221, leaving 40 cars in the queue.
# Car 401 departed at time 58.370658365291, leaving 39 cars in the queue.
# At time 58.372099391403495, pedestrian 120 arrived and started to wait.
# Car 402 departed at time 58.40565059791288, leaving 38 cars in the queue.
# The light turned red at time 58.43333333333329.
# Car 403 departed at time 58.437830482450096, leaving 37 cars in the queue.
# Pedestrians [119, 120] crossed the road at time 58.76029802178781.
# Car 441 arrived and joined the queue at position 38 at time 59.107750789614876
# Car 442 arrived and joined the queue at position 39 at time 59.1093651984687
# Car 443 arrived and joined the queue at position 40 at time 59.16075808301113
# Car 444 arrived and joined the queue at position 41 at time 59.19514063316485
# At time 59.269927850244784, pedestrian 121 arrived and started to wait.
# Car 445 arrived and joined the queue at position 42 at time 59.28834260343103
# Car 446 arrived and joined the queue at position 43 at time 59.30189270090333
# Car 447 arrived and joined the queue at position 44 at time 59.39726699758532
# Car 448 arrived and joined the queue at position 45 at time 59.76472454268999
# Car 449 arrived and joined the queue at position 46 at time 59.79894960730239
# The light turned green at time 59.93333333333329.
# At time 59.937449391245764, pedestrian 122 arrived and started to wait.
# At time 59.94250672973072, pedestrian 123 arrived and started to wait.
# Car 450 arrived and joined the queue at position 47 at time 59.94799246791557
# Car 404 departed at time 59.96699215939684, leaving 46 cars in the queue.
# Car 405 departed at time 59.99798070976114, leaving 45 cars in the queue.
#
#
#       *** Statistics( random seed=0) ***
#  ( Baseline model with no distracted driver)
#
#
# Vehicle stats:
#
# Number of vehicles waiting in queue per minute: 23.883333333333333
# Average waiting time for a vehicle (minutes): 3.2269418589724594
#
#
# Pedestrian stats:
#
# Number of pedestrians waiting to cross per minute: 1.0
# Average waiting time for a pedestrian (minutes): 0.5018896355231119

# %%
# Import all necessary packages
# double-ended queue
from collections import deque 
import numpy as np
import simpy
from simpy.util import start_delayed
from colorama import Fore, Back, Style 

#define a utility class to keep track of the stats
class Struct(object): 
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)

random_seed = 0
np.random.seed(random_seed)

end_time= 60

# Cars cars arrive at the traffic light according to a Poisson process 
t_interarrival_mean = 7.91/60

p_interarrival_mean = 30/60 #interarrival time for pedestrian set to be 30 seconds

# Traffic light green and red durations:
t_green= 26/60
t_red= 90/60

# The time for a car at the head of the queue to depart (clear the intersection)
# is modeled as a triangular distribution with specified minimum, maximum, and
# mode.
t_depart_left= 1.8/60
t_depart_mode= 2/60 
t_depart_right= 2.2/60

#the time for a group of pedestrians to cross the road is modeled as a normal distribution
p_crossing_mode = 18/60 
p_crossing_lower = 13/60
p_crossing_upper = 23/60

#initially, no cars are waiting at the light:
queue= deque()
pedestrian = deque()

pedestrian_count = arrival_count= departure_count= 0

Q_stats= Struct(count=0, cars_waiting=0)
W_stats= Struct(count=0, waiting_time=0.0)
P_W_stats = Struct(count=0, waiting_time=0.0)
p_num_stats = Struct(count=0, pedestrian_waiting=0)

distracted_p = 0.2

def arrival():
    global arrival_count, env, light, queue, distracted_boolean
    distracted_boolean = np.random.choice([True,False],p=[distracted_p,1-distracted_p])

    while True:
        
        arrival_count+= 1

        if light == 'red' or len(queue):
            queue.append((arrival_count, env.now))
            print(f"Car {arrival_count} arrived and joined the queue at position {len(queue)} at time {env.now}")

        else:
            print("Car #%d arrived to a green light with no cars waiting at time "
           "%.3f." % (arrival_count, env.now))
            W_stats.count+= 1

      #schedule next arrival:
        if distracted_boolean:
            print(Fore.YELLOW + 'Watch out! Distracted driver!')
            print(Style.RESET_ALL)
            yield env.timeout( np.random.exponential(t_interarrival_mean) + 1)
        else:
            yield env.timeout( np.random.exponential(t_interarrival_mean))

def departure():
    global env, queue, distracted_boolean
    distracted_boolean = np.random.choice([True,False],p=[distracted_p,1-distracted_p])

    while True:
        
        car_number, t_arrival= queue.popleft()
        print(f"Car {car_number} departed at time {env.now}, leaving {len(queue)} cars in the queue.")

        W_stats.count += 1
        W_stats.waiting_time += env.now - t_arrival

        if light == 'red' or len(queue) == 0:
            return

        delay = np.random.triangular(left=t_depart_left, mode=t_depart_mode,
        right=t_depart_right)

      #schedule next departure:
        if distracted_boolean:
            print(Fore.YELLOW + 'Watch out! Distracted driver!')
            print(Style.RESET_ALL)
            yield env.timeout(delay + 1)
        else:
            yield env.timeout(delay) 


def Pedestrian():
    
    global env, light, pedestrian, pedestrian_count
    
    while True:
        
        pedestrian_count += 1
        
        if light == 'red' and len(pedestrian): #assume red light for vehicles means green for pedestrians
            print(f'At time {env.now} pedestrian {pedestrian_count} arrived at the intersection and started to cross the road.')
            P_W_stats.count += 1
        else:
            pedestrian.append((pedestrian_count, env.now))
            print(f'At time {env.now}, pedestrian {pedestrian_count} arrived and started to wait.')
        
        yield env.timeout(np.random.exponential(p_interarrival_mean))
    
def pedestrian_cross():
    global env, pedestrian
    
    while True:
        
        pedestrian_idx, t_arrival = [i[0] for i in pedestrian], [i[1] for i in pedestrian]
        P_W_stats.count += len(pedestrian)
        P_W_stats.waiting_time += len(pedestrian)*env.now - sum(t_arrival)
        pedestrian = deque()
        print(f'Pedestrians {pedestrian_idx} crossed the road at time {env.now}.')
        
        if light == 'green' or len(pedestrian)==0: #assume green light for vehicles means red light for pedestrian
            return
        #schedule next crossing
        yield env.timeout(np.random.triangular(p_crossing_lower,p_crossing_mode,p_crossing_upper))

def light():
    
    global env, light

    while True:
        
        light = 'green'
        print(f"The light turned green at time {env.now}.")

        if len(queue):
            delay= np.random.triangular(left=t_depart_left, mode=t_depart_mode,
            right=t_depart_right)
            if distracted_boolean:
                start_delayed(env, departure(), delay=delay + 1)
            else:
                start_delayed(env, departure(), delay=delay)

      # Schedule event that will turn the light red:
        yield env.timeout(t_green)

        light= 'red'
        print(f"The light turned red at time {env.now}.")
        
        if len(pedestrian):
            start_delayed(env,pedestrian_cross(),delay=np.random.triangular(p_crossing_lower,p_crossing_mode,p_crossing_upper))

      # Schedule event that will turn the light green:
        yield env.timeout(t_red)


def monitor():
    global env, Q_stats, p_num_stats 
    while True:
        Q_stats.count += 1
        Q_stats.cars_waiting += len(queue)
        p_num_stats.count += 1
        p_num_stats.pedestrian_waiting += len(pedestrian)
        #check the number of vehicles and the number of pedestrians every 1/60 min
        yield env.timeout(1) 

print("\nSimulation of Cars Arriving at Intersection Controlled by a Traffic "
  "Light\n\n")

#initialize environment:
env= simpy.Environment()

#schedule first change of the traffic light:
env.process(light())

#schedule first arrival of a car:
t_first_arrival = np.random.exponential(t_interarrival_mean)
start_delayed(env, arrival(), delay=t_first_arrival)

p_t_first_arrival = np.random.exponential(p_interarrival_mean)
start_delayed(env, Pedestrian(), delay=p_t_first_arrival)

#schedule first statistical monitoring event:
env.process(monitor())

env.run(until=end_time)


#report statistics.

print(f"\n\n      *** Statistics( random seed={random_seed}) ***")
print(f' ( Baseline model with {distracted_p*100}% distracted drivers)\n\n')
print('Vehicle stats:\n')
print(f"Number of vehicles waiting in queue per minute: {Q_stats.cars_waiting / float(Q_stats.count)}")
print(f"Average waiting time for a vehicle (minutes): {W_stats.waiting_time / float(W_stats.count)}")

print('\n\nPedestrian stats:\n')
print(f"Number of pedestrians waiting to cross per minute: {p_num_stats.pedestrian_waiting / float(p_num_stats.count)}")
print(f"Average waiting time for a pedestrian (minutes): {P_W_stats.waiting_time / float(P_W_stats.count)}")
# Out:
# Simulation of Cars Arriving at Intersection Controlled by a Traffic Light
#
#
# The light turned green at time 0.
# Car #1 arrived to a green light with no cars waiting at time 0.105.
# Car #2 arrived to a green light with no cars waiting at time 0.209.
# Car #3 arrived to a green light with no cars waiting at time 0.281.
# Car #4 arrived to a green light with no cars waiting at time 0.418.
# The light turned red at time 0.43333333333333335.
# Car 5 arrived and joined the queue at position 1 at time 0.4940853154565517
# At time 0.6279653814829189, pedestrian 1 arrived and started to wait.
# Car 6 arrived and joined the queue at position 2 at time 0.7872199505746903
# Car 7 arrived and joined the queue at position 3 at time 0.8509748275436374
# Car 8 arrived and joined the queue at position 4 at time 1.0578076353295727
# Car 9 arrived and joined the queue at position 5 at time 1.1570351721034795
# Car 10 arrived and joined the queue at position 6 at time 1.2677004023985476
# Car 11 arrived and joined the queue at position 7 at time 1.6102369083577182
# Car 12 arrived and joined the queue at position 8 at time 1.6199510943137285
# Car 13 arrived and joined the queue at position 9 at time 1.6319691566525834
# Car 14 arrived and joined the queue at position 10 at time 1.6346619298304537
# Car 15 arrived and joined the queue at position 11 at time 1.8703123889263498
# The light turned green at time 1.9333333333333333.
# Car 5 departed at time 1.9683004062462317, leaving 10 cars in the queue.
# Car 6 departed at time 2.0028544577048195, leaving 9 cars in the queue.
# Car 7 departed at time 2.036056815732735, leaving 8 cars in the queue.
# Car 16 arrived and joined the queue at position 9 at time 2.068824943493914
# Car 8 departed at time 2.070515060017733, leaving 8 cars in the queue.
# Car 17 arrived and joined the queue at position 9 at time 2.0854193867869073
# Car 9 departed at time 2.104352989319141, leaving 8 cars in the queue.
# Car 18 arrived and joined the queue at position 9 at time 2.105817916626502
# Car 10 departed at time 2.139910791872798, leaving 8 cars in the queue.
# Car 11 departed at time 2.1729463659169563, leaving 7 cars in the queue.
# Car 19 arrived and joined the queue at position 8 at time 2.2030881461505096
# Car 12 departed at time 2.2053710336472494, leaving 7 cars in the queue.
# Car 13 departed at time 2.2385548480339965, leaving 6 cars in the queue.
# Car 14 departed at time 2.272124684596862, leaving 5 cars in the queue.
# At time 2.285421472509826, pedestrian 2 arrived and started to wait.
# Car 15 departed at time 2.302770866553286, leaving 4 cars in the queue.
# Car 16 departed at time 2.3365015333816332, leaving 3 cars in the queue.
# The light turned red at time 2.3666666666666667.
# Car 17 departed at time 2.3702505678152677, leaving 2 cars in the queue.
# Car 20 arrived and joined the queue at position 3 at time 2.3992897423893176
# Car 21 arrived and joined the queue at position 4 at time 2.550257228438059
# Car 22 arrived and joined the queue at position 5 at time 2.6089914163964605
# Car 23 arrived and joined the queue at position 6 at time 2.6847339389509886
# Pedestrians [1, 2] crossed the road at time 2.72204867288845.
# At time 2.7661119371072553, pedestrian 3 arrived and started to wait.
# At time 2.797169585069913 pedestrian 4 arrived at the intersection and started to cross the road.
# Car 24 arrived and joined the queue at position 7 at time 2.8424208174004044
# Car 25 arrived and joined the queue at position 8 at time 2.988834579023047
# Car 26 arrived and joined the queue at position 9 at time 3.019974496342914
# Car 27 arrived and joined the queue at position 10 at time 3.0381712783291253
# Car 28 arrived and joined the queue at position 11 at time 3.0881310975314507
# Car 29 arrived and joined the queue at position 12 at time 3.147733218626449
# Car 30 arrived and joined the queue at position 13 at time 3.2590569477089275
# Car 31 arrived and joined the queue at position 14 at time 3.335167536033146
# At time 3.346625825098933 pedestrian 5 arrived at the intersection and started to cross the road.
# At time 3.4004433813665784 pedestrian 6 arrived at the intersection and started to cross the road.
# At time 3.5175941391830574 pedestrian 7 arrived at the intersection and started to cross the road.
# At time 3.6055509159003587 pedestrian 8 arrived at the intersection and started to cross the road.
# The light turned green at time 3.8666666666666667.
# Car 18 departed at time 3.8990391552922796, leaving 13 cars in the queue.
# Car 32 arrived and joined the queue at position 14 at time 3.9224187740434395
# Car 19 departed at time 3.931369751744319, leaving 13 cars in the queue.
# Car 33 arrived and joined the queue at position 14 at time 3.9452427432340405
# Car 20 departed at time 3.9629358874072684, leaving 13 cars in the queue.
# Car 21 departed at time 3.994688237900803, leaving 12 cars in the queue.
# Car 22 departed at time 4.026778332857073, leaving 11 cars in the queue.
# Car 23 departed at time 4.059640830487003, leaving 10 cars in the queue.
# Car 34 arrived and joined the queue at position 11 at time 4.086050260255894
# Car 24 departed at time 4.094313022730268, leaving 10 cars in the queue.
# Car 35 arrived and joined the queue at position 11 at time 4.099516361147839
# Car 36 arrived and joined the queue at position 12 at time 4.1128361133476625
# Car 25 departed at time 4.129082000202729, leaving 11 cars in the queue.
# At time 4.134922278353566, pedestrian 9 arrived and started to wait.
# Car 26 departed at time 4.162309146178313, leaving 10 cars in the queue.
# Car 27 departed at time 4.196012502082954, leaving 9 cars in the queue.
# Car 28 departed at time 4.230272066200905, leaving 8 cars in the queue.
# Car 29 departed at time 4.261205254192616, leaving 7 cars in the queue.
# Car 30 departed at time 4.2937121644758856, leaving 6 cars in the queue.
# The light turned red at time 4.3.
# Car 31 departed at time 4.325346494520162, leaving 5 cars in the queue.
# Pedestrians [3, 9] crossed the road at time 4.580799796162417.
# Car 37 arrived and joined the queue at position 6 at time 4.607083426265551
# Car 38 arrived and joined the queue at position 7 at time 4.623745662198853
# Car 39 arrived and joined the queue at position 8 at time 4.674198405135172
# Car 40 arrived and joined the queue at position 9 at time 4.744713996721719
# Car 41 arrived and joined the queue at position 10 at time 4.7534542034924545
# Car 42 arrived and joined the queue at position 11 at time 4.908910689485804
# Car 43 arrived and joined the queue at position 12 at time 5.019136215865375
# Car 44 arrived and joined the queue at position 13 at time 5.059795572255146
# Car 45 arrived and joined the queue at position 14 at time 5.157452294039424
# Car 46 arrived and joined the queue at position 15 at time 5.17045769372627
# Car 47 arrived and joined the queue at position 16 at time 5.283556935861351
# Car 48 arrived and joined the queue at position 17 at time 5.632817175308659
# Car 49 arrived and joined the queue at position 18 at time 5.6833831963853205
# The light turned green at time 5.8.
# Car 50 arrived and joined the queue at position 19 at time 5.828511383671452
# Car 32 departed at time 5.831711385808859, leaving 18 cars in the queue.
# Car 33 departed at time 5.863729037700468, leaving 17 cars in the queue.
# Car 34 departed at time 5.897364433767425, leaving 16 cars in the queue.
# Car 35 departed at time 5.928032890467386, leaving 15 cars in the queue.
# Car 36 departed at time 5.9627498564688075, leaving 14 cars in the queue.
# Car 37 departed at time 5.993072879556821, leaving 13 cars in the queue.
# Car 51 arrived and joined the queue at position 14 at time 5.994612660550835
# At time 6.015885864413336, pedestrian 10 arrived and started to wait.
# Car 38 departed at time 6.027063797259993, leaving 13 cars in the queue.
# Car 52 arrived and joined the queue at position 14 at time 6.036103466994268
# Car 39 departed at time 6.062813809928171, leaving 13 cars in the queue.
# Car 53 arrived and joined the queue at position 14 at time 6.073810565864969
# Car 40 departed at time 6.09641148231302, leaving 13 cars in the queue.
# Car 41 departed at time 6.12999504774803, leaving 12 cars in the queue.
# Car 42 departed at time 6.162221562875811, leaving 11 cars in the queue.
# Car 54 arrived and joined the queue at position 12 at time 6.192011130552365
# Car 43 departed at time 6.197863523747485, leaving 11 cars in the queue.
# Car 44 departed at time 6.232682721710289, leaving 10 cars in the queue.
# The light turned red at time 6.233333333333333.
# Car 45 departed at time 6.266765159608778, leaving 9 cars in the queue.
# Car 55 arrived and joined the queue at position 10 at time 6.270138731525597
# Car 56 arrived and joined the queue at position 11 at time 6.491740308854287
# Pedestrians [10] crossed the road at time 6.5142733907762524.
# Car 57 arrived and joined the queue at position 12 at time 6.558318614204738
# At time 6.68026480446752, pedestrian 11 arrived and started to wait.
# Car 58 arrived and joined the queue at position 13 at time 6.8390576137874035
# At time 7.115532713744828 pedestrian 12 arrived at the intersection and started to cross the road.
# Car 59 arrived and joined the queue at position 14 at time 7.120499430677939
# Car 60 arrived and joined the queue at position 15 at time 7.290816135178335
# Car 61 arrived and joined the queue at position 16 at time 7.382545697136467
# At time 7.7052241782313615 pedestrian 13 arrived at the intersection and started to cross the road.
# The light turned green at time 7.733333333333333.
# Car 46 departed at time 7.766402372446651, leaving 15 cars in the queue.
# Car 62 arrived and joined the queue at position 16 at time 7.7945865938413
# Car 47 departed at time 7.797055454002036, leaving 15 cars in the queue.
# Car 48 departed at time 7.830974085158228, leaving 14 cars in the queue.
# Car 63 arrived and joined the queue at position 15 at time 7.841905165217601
# Car 49 departed at time 7.863513015848326, leaving 14 cars in the queue.
# Car 50 departed at time 7.896599793027578, leaving 13 cars in the queue.
# Car 51 departed at time 7.928334882293437, leaving 12 cars in the queue.
# Car 52 departed at time 7.960909468887894, leaving 11 cars in the queue.
# Car 64 arrived and joined the queue at position 12 at time 7.968778277457818
# Car 53 departed at time 7.994484803266088, leaving 11 cars in the queue.
# Car 54 departed at time 8.028075849846585, leaving 10 cars in the queue.
# Car 55 departed at time 8.061966431419524, leaving 9 cars in the queue.
# Car 65 arrived and joined the queue at position 10 at time 8.086601560396934
# Car 56 departed at time 8.095852623586325, leaving 9 cars in the queue.
# Car 57 departed at time 8.131003056584772, leaving 8 cars in the queue.
# Car 66 arrived and joined the queue at position 9 at time 8.161036045014972
# Car 58 departed at time 8.163861035163526, leaving 8 cars in the queue.
# The light turned red at time 8.166666666666666.
# Car 59 departed at time 8.198977958876709, leaving 7 cars in the queue.
# At time 8.221622687358977 pedestrian 14 arrived at the intersection and started to cross the road.
# Car 67 arrived and joined the queue at position 8 at time 8.23650556093183
# Car 68 arrived and joined the queue at position 9 at time 8.250428827892256
# Pedestrians [11] crossed the road at time 8.49811792070341.
# Car 69 arrived and joined the queue at position 10 at time 8.582554189956335
# Car 70 arrived and joined the queue at position 11 at time 8.747689615862651
# At time 8.830132431620568, pedestrian 15 arrived and started to wait.
# At time 8.911067474969698 pedestrian 16 arrived at the intersection and started to cross the road.
# Car 71 arrived and joined the queue at position 12 at time 9.639594023133554
# Car 72 arrived and joined the queue at position 13 at time 9.662971445313046
# The light turned green at time 9.666666666666666.
# Car 60 departed at time 9.698325447898304, leaving 12 cars in the queue.
# Car 61 departed at time 9.73292286327109, leaving 11 cars in the queue.
# Car 62 departed at time 9.766495093132473, leaving 10 cars in the queue.
# Car 73 arrived and joined the queue at position 11 at time 9.788999684442755
# Car 74 arrived and joined the queue at position 12 at time 9.798448890014724
# Car 63 departed at time 9.799503168549768, leaving 11 cars in the queue.
# Car 64 departed at time 9.832677869524936, leaving 10 cars in the queue.
# Car 65 departed at time 9.866859271168714, leaving 9 cars in the queue.
# Car 66 departed at time 9.901802777469648, leaving 8 cars in the queue.
# At time 9.924021871340685, pedestrian 17 arrived and started to wait.
# Car 67 departed at time 9.937731903252368, leaving 7 cars in the queue.
# Car 75 arrived and joined the queue at position 8 at time 9.956047541301718
# Car 68 departed at time 9.968242112015414, leaving 7 cars in the queue.
# Car 69 departed at time 10.002459246129957, leaving 6 cars in the queue.
# Car 76 arrived and joined the queue at position 7 at time 10.014878539253369
# Car 70 departed at time 10.034412190785607, leaving 6 cars in the queue.
# Car 71 departed at time 10.065511058772211, leaving 5 cars in the queue.
# Car 72 departed at time 10.097619225563506, leaving 4 cars in the queue.
# The light turned red at time 10.1.
# Car 77 arrived and joined the queue at position 5 at time 10.111925156810704
# Car 73 departed at time 10.128260782601078, leaving 4 cars in the queue.
# Car 78 arrived and joined the queue at position 5 at time 10.145345659847916
# Car 79 arrived and joined the queue at position 6 at time 10.201197788142032
# Pedestrians [15, 17] crossed the road at time 10.429804745872133.
# Car 80 arrived and joined the queue at position 7 at time 10.548211976333182
# Car 81 arrived and joined the queue at position 8 at time 10.70889002272589
# Car 82 arrived and joined the queue at position 9 at time 10.713155728901626
# Car 83 arrived and joined the queue at position 10 at time 10.73688010509624
# Car 84 arrived and joined the queue at position 11 at time 10.864953834456271
# At time 10.89231048797411, pedestrian 18 arrived and started to wait.
# Car 85 arrived and joined the queue at position 12 at time 10.97845226826874
# At time 11.028144527385223 pedestrian 19 arrived at the intersection and started to cross the road.
# Car 86 arrived and joined the queue at position 13 at time 11.337216672332374
# Car 87 arrived and joined the queue at position 14 at time 11.438343341756664
# At time 11.504059385598666 pedestrian 20 arrived at the intersection and started to cross the road.
# Car 88 arrived and joined the queue at position 15 at time 11.555856750365562
# The light turned green at time 11.6.
# Car 89 arrived and joined the queue at position 16 at time 11.605147453397
# Car 74 departed at time 11.632974786872724, leaving 15 cars in the queue.
# Watch out! Distracted driver!
#
# Car 90 arrived and joined the queue at position 16 at time 11.63619744214264
# Watch out! Distracted driver!
#
# The light turned red at time 12.033333333333333.
# At time 12.158952077259775 pedestrian 21 arrived at the intersection and started to cross the road.
# At time 12.287958458442805 pedestrian 22 arrived at the intersection and started to cross the road.
# Pedestrians [18] crossed the road at time 12.332534404326113.
# At time 12.434712283737689, pedestrian 23 arrived and started to wait.
# At time 12.46460276405906 pedestrian 24 arrived at the intersection and started to cross the road.
# Car 75 departed at time 12.668529622117155, leaving 15 cars in the queue.
# At time 12.749551543750528 pedestrian 25 arrived at the intersection and started to cross the road.
# Car 91 arrived and joined the queue at position 16 at time 12.813559077987433
# Watch out! Distracted driver!
#
# At time 12.936386444701743 pedestrian 26 arrived at the intersection and started to cross the road.
# At time 13.173594591508053 pedestrian 27 arrived at the intersection and started to cross the road.
# At time 13.272578459226116 pedestrian 28 arrived at the intersection and started to cross the road.
# At time 13.285072635685289 pedestrian 29 arrived at the intersection and started to cross the road.
# At time 13.31988147157189 pedestrian 30 arrived at the intersection and started to cross the road.
# The light turned green at time 13.533333333333333.
# At time 13.88865072082553, pedestrian 31 arrived and started to wait.
# The light turned red at time 13.966666666666667.
# Car 92 arrived and joined the queue at position 17 at time 13.970685705991453
# Watch out! Distracted driver!
#
# At time 14.273210623992709 pedestrian 32 arrived at the intersection and started to cross the road.
# Pedestrians [23, 31] crossed the road at time 14.31211701001775.
# At time 14.39545613718347, pedestrian 33 arrived and started to wait.
# Car 76 departed at time 14.56650857381261, leaving 16 cars in the queue.
# At time 14.939408353301443 pedestrian 34 arrived at the intersection and started to cross the road.
# At time 14.949841959912336 pedestrian 35 arrived at the intersection and started to cross the road.
# The light turned green at time 15.466666666666667.
# Car 77 departed at time 15.499333404794136, leaving 15 cars in the queue.
# Car 78 departed at time 15.532975421301247, leaving 14 cars in the queue.
# Car 79 departed at time 15.567704440225796, leaving 13 cars in the queue.
# Car 93 arrived and joined the queue at position 14 at time 15.58234658319073
# Car 80 departed at time 15.601499722571235, leaving 13 cars in the queue.
# Car 81 departed at time 15.633965226958738, leaving 12 cars in the queue.
# At time 15.660033691660923, pedestrian 36 arrived and started to wait.
# Car 82 departed at time 15.66851343944009, leaving 11 cars in the queue.
# Car 83 departed at time 15.704155862830229, leaving 10 cars in the queue.
# Car 84 departed at time 15.738187248682797, leaving 9 cars in the queue.
# At time 15.76270757670867, pedestrian 37 arrived and started to wait.
# Car 85 departed at time 15.770375640670402, leaving 8 cars in the queue.
# Car 86 departed at time 15.804596702693678, leaving 7 cars in the queue.
# Car 87 departed at time 15.836972233710782, leaving 6 cars in the queue.
# Car 94 arrived and joined the queue at position 7 at time 15.854031514605998
# Car 88 departed at time 15.869149448942155, leaving 6 cars in the queue.
# Car 89 departed at time 15.899904619534428, leaving 5 cars in the queue.
# The light turned red at time 15.9.
# Car 90 departed at time 15.932051814476885, leaving 4 cars in the queue.
# Car 95 arrived and joined the queue at position 5 at time 15.950299862513598
# Car 96 arrived and joined the queue at position 6 at time 16.012087044973256
# Car 97 arrived and joined the queue at position 7 at time 16.094196709370724
# Car 98 arrived and joined the queue at position 8 at time 16.13707102069009
# Pedestrians [33, 36, 37] crossed the road at time 16.19346776879558.
# Car 99 arrived and joined the queue at position 9 at time 16.253583430036816
# Car 100 arrived and joined the queue at position 10 at time 16.51646426922659
# Car 101 arrived and joined the queue at position 11 at time 16.53294773210872
# Car 102 arrived and joined the queue at position 12 at time 16.628991457619126
# Car 103 arrived and joined the queue at position 13 at time 16.647664598696927
# Car 104 arrived and joined the queue at position 14 at time 16.814013570085926
# Car 105 arrived and joined the queue at position 15 at time 16.880494474407175
# Car 106 arrived and joined the queue at position 16 at time 16.99036150706285
# Car 107 arrived and joined the queue at position 17 at time 17.017052320200854
# Car 108 arrived and joined the queue at position 18 at time 17.03768104210402
# Car 109 arrived and joined the queue at position 19 at time 17.125948808979608
# Car 110 arrived and joined the queue at position 20 at time 17.18388367853626
# At time 17.23494767636144, pedestrian 38 arrived and started to wait.
# The light turned green at time 17.4.
# Car 91 departed at time 17.434303352702713, leaving 19 cars in the queue.
# Car 92 departed at time 17.465664907658898, leaving 18 cars in the queue.
# Car 93 departed at time 17.499177009625615, leaving 17 cars in the queue.
# Car 94 departed at time 17.53280494874044, leaving 16 cars in the queue.
# Car 111 arrived and joined the queue at position 17 at time 17.55573750380966
# Car 95 departed at time 17.568551909881133, leaving 16 cars in the queue.
# Car 96 departed at time 17.60086529499062, leaving 15 cars in the queue.
# Car 112 arrived and joined the queue at position 16 at time 17.60128850153261
# Car 113 arrived and joined the queue at position 17 at time 17.603472464755228
# Car 97 departed at time 17.632358196284265, leaving 16 cars in the queue.
# Car 98 departed at time 17.666316507757546, leaving 15 cars in the queue.
# Car 99 departed at time 17.70079813901653, leaving 14 cars in the queue.
# Car 100 departed at time 17.733300271910036, leaving 13 cars in the queue.
# Car 101 departed at time 17.76693529130239, leaving 12 cars in the queue.
# Car 102 departed at time 17.798127444034222, leaving 11 cars in the queue.
# Car 103 departed at time 17.831412520038533, leaving 10 cars in the queue.
# The light turned red at time 17.833333333333332.
# Car 104 departed at time 17.86737200355659, leaving 9 cars in the queue.
# Car 114 arrived and joined the queue at position 10 at time 17.953168093233383
# At time 17.959725067503957 pedestrian 39 arrived at the intersection and started to cross the road.
# Car 115 arrived and joined the queue at position 11 at time 18.007579646494886
# Car 116 arrived and joined the queue at position 12 at time 18.04232789603508
# Pedestrians [38] crossed the road at time 18.175251634055808.
# Car 117 arrived and joined the queue at position 13 at time 18.43548135341864
# Car 118 arrived and joined the queue at position 14 at time 18.80944508500161
# Car 119 arrived and joined the queue at position 15 at time 19.021098067032728
# Car 120 arrived and joined the queue at position 16 at time 19.152333357821142
# The light turned green at time 19.333333333333332.
# Car 105 departed at time 19.365885109553528, leaving 15 cars in the queue.
# Car 106 departed at time 19.399637736229305, leaving 14 cars in the queue.
# Car 121 arrived and joined the queue at position 15 at time 19.42572424060695
# Car 107 departed at time 19.430180094408595, leaving 14 cars in the queue.
# Car 108 departed at time 19.46199448662975, leaving 13 cars in the queue.
# Car 122 arrived and joined the queue at position 14 at time 19.48195587974428
# Car 109 departed at time 19.498025707517947, leaving 13 cars in the queue.
# Car 110 departed at time 19.531350334031636, leaving 12 cars in the queue.
# Car 111 departed at time 19.56518650218076, leaving 11 cars in the queue.
# Car 123 arrived and joined the queue at position 12 at time 19.56775266283637
# Car 124 arrived and joined the queue at position 13 at time 19.587161829889286
# At time 19.58918551539894, pedestrian 40 arrived and started to wait.
# Car 112 departed at time 19.598048454141416, leaving 12 cars in the queue.
# Car 113 departed at time 19.631419733400563, leaving 11 cars in the queue.
# Car 114 departed at time 19.6636524050885, leaving 10 cars in the queue.
# At time 19.6944521583279, pedestrian 41 arrived and started to wait.
# Car 115 departed at time 19.69512696328594, leaving 9 cars in the queue.
# Car 116 departed at time 19.731017879262748, leaving 8 cars in the queue.
# The light turned red at time 19.766666666666666.
# Car 117 departed at time 19.766751625283305, leaving 7 cars in the queue.
# Car 125 arrived and joined the queue at position 8 at time 19.814789662496466
# Car 126 arrived and joined the queue at position 9 at time 20.010882483004174
# Car 127 arrived and joined the queue at position 10 at time 20.064299092154517
# Car 128 arrived and joined the queue at position 11 at time 20.075449488139682
# Pedestrians [40, 41] crossed the road at time 20.11397444950324.
# Car 129 arrived and joined the queue at position 12 at time 20.14439405796517
# Car 130 arrived and joined the queue at position 13 at time 20.17923371425923
# Car 131 arrived and joined the queue at position 14 at time 20.197970594440015
# Car 132 arrived and joined the queue at position 15 at time 20.20520921698764
# Car 133 arrived and joined the queue at position 16 at time 20.375689207853867
# Car 134 arrived and joined the queue at position 17 at time 20.377204401807635
# Car 135 arrived and joined the queue at position 18 at time 20.571289983135436
# Car 136 arrived and joined the queue at position 19 at time 20.59224267457154
# Car 137 arrived and joined the queue at position 20 at time 20.60316668361839
# Car 138 arrived and joined the queue at position 21 at time 20.615542478259506
# At time 20.685397340890415, pedestrian 42 arrived and started to wait.
# Car 139 arrived and joined the queue at position 22 at time 20.76252180515301
# At time 20.82615935024827 pedestrian 43 arrived at the intersection and started to cross the road.
# Car 140 arrived and joined the queue at position 23 at time 20.834457681665853
# Car 141 arrived and joined the queue at position 24 at time 21.09417693962602
# At time 21.233668521100498 pedestrian 44 arrived at the intersection and started to cross the road.
# Car 142 arrived and joined the queue at position 25 at time 21.265355355367713
# The light turned green at time 21.266666666666666.
# Car 143 arrived and joined the queue at position 26 at time 21.283939621991173
# Car 118 departed at time 21.297775963945938, leaving 25 cars in the queue.
# Car 119 departed at time 21.330959744252432, leaving 24 cars in the queue.
# Car 144 arrived and joined the queue at position 25 at time 21.33126268924538
# Car 120 departed at time 21.3649734517141, leaving 24 cars in the queue.
# At time 21.391248536606565, pedestrian 45 arrived and started to wait.
# Car 121 departed at time 21.39748351522185, leaving 23 cars in the queue.
# Car 122 departed at time 21.42948989926472, leaving 22 cars in the queue.
# Car 123 departed at time 21.46398885086353, leaving 21 cars in the queue.
# Car 145 arrived and joined the queue at position 22 at time 21.488077944772506
# Car 124 departed at time 21.495112812867962, leaving 21 cars in the queue.
# Car 125 departed at time 21.529561850149406, leaving 20 cars in the queue.
# Car 126 departed at time 21.564004444284524, leaving 19 cars in the queue.
# Car 127 departed at time 21.596405474453917, leaving 18 cars in the queue.
# Car 128 departed at time 21.62928765394533, leaving 17 cars in the queue.
# At time 21.63020753401561, pedestrian 46 arrived and started to wait.
# Car 146 arrived and joined the queue at position 18 at time 21.64548870742324
# Car 129 departed at time 21.66292703592912, leaving 17 cars in the queue.
# Car 130 departed at time 21.695019638137882, leaving 16 cars in the queue.
# The light turned red at time 21.7.
# Car 147 arrived and joined the queue at position 17 at time 21.706578959205327
# Car 131 departed at time 21.72821635827562, leaving 16 cars in the queue.
# At time 21.7894994617246 pedestrian 47 arrived at the intersection and started to cross the road.
# At time 21.82953889133919 pedestrian 48 arrived at the intersection and started to cross the road.
# Car 148 arrived and joined the queue at position 17 at time 21.91862204651801
# Pedestrians [42, 45, 46] crossed the road at time 21.941558739605576.
# Car 149 arrived and joined the queue at position 18 at time 21.96693254167534
# Car 150 arrived and joined the queue at position 19 at time 22.08052903929036
# At time 22.195311562174943, pedestrian 49 arrived and started to wait.
# Car 151 arrived and joined the queue at position 20 at time 22.503029659833537
# Car 152 arrived and joined the queue at position 21 at time 22.507776032827632
# Car 153 arrived and joined the queue at position 22 at time 22.581975155256725
# Car 154 arrived and joined the queue at position 23 at time 22.676022982962643
# At time 22.71393411389349 pedestrian 50 arrived at the intersection and started to cross the road.
# Car 155 arrived and joined the queue at position 24 at time 22.777304380515634
# Car 156 arrived and joined the queue at position 25 at time 22.820172740880743
# Car 157 arrived and joined the queue at position 26 at time 22.838359574952612
# Car 158 arrived and joined the queue at position 27 at time 22.904103846476882
# The light turned green at time 23.2.
# Car 132 departed at time 23.23203923129172, leaving 26 cars in the queue.
# Car 133 departed at time 23.265521931006006, leaving 25 cars in the queue.
# At time 23.28583180118121, pedestrian 51 arrived and started to wait.
# Car 134 departed at time 23.29870840039197, leaving 24 cars in the queue.
# Car 159 arrived and joined the queue at position 25 at time 23.31711518825649
# Car 135 departed at time 23.33190076615272, leaving 24 cars in the queue.
# Car 136 departed at time 23.364878555495704, leaving 23 cars in the queue.
# Car 137 departed at time 23.40008496642298, leaving 22 cars in the queue.
# Car 138 departed at time 23.434127069719363, leaving 21 cars in the queue.
# Car 139 departed at time 23.468210121580935, leaving 20 cars in the queue.
# Car 160 arrived and joined the queue at position 21 at time 23.486911508867482
# Car 140 departed at time 23.500908764867876, leaving 20 cars in the queue.
# Car 141 departed at time 23.534731572870477, leaving 19 cars in the queue.
# Car 142 departed at time 23.56704107148552, leaving 18 cars in the queue.
# Car 143 departed at time 23.59892986194202, leaving 17 cars in the queue.
# The light turned red at time 23.633333333333333.
# Car 144 departed at time 23.633469409923794, leaving 16 cars in the queue.
# Car 161 arrived and joined the queue at position 17 at time 23.673295275901857
# Car 162 arrived and joined the queue at position 18 at time 23.754075550955754
# Car 163 arrived and joined the queue at position 19 at time 23.871934736590106
# Pedestrians [49, 51] crossed the road at time 23.992852164500974.
# Car 164 arrived and joined the queue at position 20 at time 24.129006693416752
# Car 165 arrived and joined the queue at position 21 at time 24.20956444841664
# At time 24.35454262631115, pedestrian 52 arrived and started to wait.
# Car 166 arrived and joined the queue at position 22 at time 24.609539216550196
# At time 24.783260183275356 pedestrian 53 arrived at the intersection and started to cross the road.
# Car 167 arrived and joined the queue at position 23 at time 24.836169854846915
# Car 168 arrived and joined the queue at position 24 at time 25.058999158842926
# Car 169 arrived and joined the queue at position 25 at time 25.081892882353692
# The light turned green at time 25.133333333333333.
# Car 145 departed at time 25.166308916408294, leaving 24 cars in the queue.
# Watch out! Distracted driver!
#
# Car 170 arrived and joined the queue at position 25 at time 25.21257656372032
# Watch out! Distracted driver!
#
# The light turned red at time 25.566666666666666.
# Pedestrians [52] crossed the road at time 25.904210370598626.
# At time 25.980850115973567, pedestrian 54 arrived and started to wait.
# At time 25.99778604369396 pedestrian 55 arrived at the intersection and started to cross the road.
# Car 146 departed at time 26.199378596999313, leaving 24 cars in the queue.
# Car 171 arrived and joined the queue at position 25 at time 26.252038022354697
# Watch out! Distracted driver!
#
# The light turned green at time 27.066666666666666.
# Car 172 arrived and joined the queue at position 26 at time 27.309923004726326
# Watch out! Distracted driver!
#
# The light turned red at time 27.5.
# At time 27.59466698523665 pedestrian 56 arrived at the intersection and started to cross the road.
# Pedestrians [54] crossed the road at time 27.767388172794107.
# At time 27.85113048429333, pedestrian 57 arrived and started to wait.
# Car 147 departed at time 28.099482127514683, leaving 25 cars in the queue.
# Car 173 arrived and joined the queue at position 26 at time 28.312093414051407
# Watch out! Distracted driver!
#
# The light turned green at time 29.0.
# At time 29.175724643016473, pedestrian 58 arrived and started to wait.
# The light turned red at time 29.433333333333334.
# At time 29.478441531872466 pedestrian 59 arrived at the intersection and started to cross the road.
# At time 29.61090899880815 pedestrian 60 arrived at the intersection and started to cross the road.
# Car 174 arrived and joined the queue at position 27 at time 29.695190481884907
# Watch out! Distracted driver!
#
# Pedestrians [57, 58] crossed the road at time 29.717361058830615.
# Car 148 departed at time 30.03496365319733, leaving 26 cars in the queue.
# At time 30.08747026759828, pedestrian 61 arrived and started to wait.
# At time 30.367474457278917 pedestrian 62 arrived at the intersection and started to cross the road.
# At time 30.402725430263306 pedestrian 63 arrived at the intersection and started to cross the road.
# At time 30.547862135963506 pedestrian 64 arrived at the intersection and started to cross the road.
# At time 30.672837546465438 pedestrian 65 arrived at the intersection and started to cross the road.
# Car 175 arrived and joined the queue at position 27 at time 30.69962455413305
# Watch out! Distracted driver!
#
# At time 30.81881058414975 pedestrian 66 arrived at the intersection and started to cross the road.
# At time 30.824865206528873 pedestrian 67 arrived at the intersection and started to cross the road.
# At time 30.886222712610714 pedestrian 68 arrived at the intersection and started to cross the road.
# The light turned green at time 30.933333333333334.
# The light turned red at time 31.366666666666667.
# At time 31.36801905521064 pedestrian 69 arrived at the intersection and started to cross the road.
# At time 31.63103445406037 pedestrian 70 arrived at the intersection and started to cross the road.
# Car 176 arrived and joined the queue at position 28 at time 31.71814393562314
# Watch out! Distracted driver!
#
# At time 31.719972834463984 pedestrian 71 arrived at the intersection and started to cross the road.
# Pedestrians [61] crossed the road at time 31.738419965434286.
# Car 149 departed at time 31.969243637547468, leaving 27 cars in the queue.
# At time 32.05694456010919, pedestrian 72 arrived and started to wait.
# At time 32.09071163904694 pedestrian 73 arrived at the intersection and started to cross the road.
# Car 177 arrived and joined the queue at position 28 at time 32.85237895410063
# At time 32.8551810742196 pedestrian 74 arrived at the intersection and started to cross the road.
# The light turned green at time 32.86666666666667.
# Car 178 arrived and joined the queue at position 29 at time 32.897233559818936
# Car 150 departed at time 32.90059473909351, leaving 28 cars in the queue.
# Car 151 departed at time 32.93398627562605, leaving 27 cars in the queue.
# Car 179 arrived and joined the queue at position 28 at time 32.934469451642066
# Car 152 departed at time 32.96705616157556, leaving 27 cars in the queue.
# At time 32.9933336718918, pedestrian 75 arrived and started to wait.
# Car 153 departed at time 32.99958181449409, leaving 26 cars in the queue.
# Car 154 departed at time 33.032618101954256, leaving 25 cars in the queue.
# Car 180 arrived and joined the queue at position 26 at time 33.04111994067087
# Car 155 departed at time 33.065448671431646, leaving 25 cars in the queue.
# Car 156 departed at time 33.100824058904415, leaving 24 cars in the queue.
# Car 157 departed at time 33.1318351893047, leaving 23 cars in the queue.
# Car 158 departed at time 33.16410884027386, leaving 22 cars in the queue.
# Car 159 departed at time 33.196891801803886, leaving 21 cars in the queue.
# Car 160 departed at time 33.23153069727685, leaving 20 cars in the queue.
# Car 161 departed at time 33.267629549960745, leaving 19 cars in the queue.
# Car 181 arrived and joined the queue at position 20 at time 33.27368546091082
# The light turned red at time 33.3.
# Car 162 departed at time 33.30346584461801, leaving 19 cars in the queue.
# Pedestrians [72, 75] crossed the road at time 33.58084483285095.
# Car 182 arrived and joined the queue at position 20 at time 33.58393343258419
# At time 33.606399775875374, pedestrian 76 arrived and started to wait.
# At time 33.74985432221849 pedestrian 77 arrived at the intersection and started to cross the road.
# At time 33.805826590793636 pedestrian 78 arrived at the intersection and started to cross the road.
# Car 183 arrived and joined the queue at position 21 at time 34.22065153937523
# Car 184 arrived and joined the queue at position 22 at time 34.255695021066366
# Car 185 arrived and joined the queue at position 23 at time 34.40999746464104
# Car 186 arrived and joined the queue at position 24 at time 34.41792438892759
# Car 187 arrived and joined the queue at position 25 at time 34.59088485336671
# The light turned green at time 34.8.
# Car 163 departed at time 34.83246051889498, leaving 24 cars in the queue.
# Car 164 departed at time 34.86534455997699, leaving 23 cars in the queue.
# Car 188 arrived and joined the queue at position 24 at time 34.87230978368848
# Car 165 departed at time 34.899648498735964, leaving 23 cars in the queue.
# Car 189 arrived and joined the queue at position 24 at time 34.908109889031095
# Car 166 departed at time 34.93160271411729, leaving 23 cars in the queue.
# Car 167 departed at time 34.964203860904455, leaving 22 cars in the queue.
# Car 190 arrived and joined the queue at position 23 at time 34.98675505321092
# Car 168 departed at time 34.99898013738364, leaving 22 cars in the queue.
# Car 191 arrived and joined the queue at position 23 at time 35.02254384421319
# Car 169 departed at time 35.03232144511392, leaving 22 cars in the queue.
# Car 170 departed at time 35.06613620285943, leaving 21 cars in the queue.
# Car 171 departed at time 35.101085568060704, leaving 20 cars in the queue.
# Car 172 departed at time 35.136599553691745, leaving 19 cars in the queue.
# Car 173 departed at time 35.170912806109975, leaving 18 cars in the queue.
# Car 174 departed at time 35.20499565587663, leaving 17 cars in the queue.
# The light turned red at time 35.23333333333333.
# Car 175 departed at time 35.24081859492274, leaving 16 cars in the queue.
# At time 35.31331075425041 pedestrian 79 arrived at the intersection and started to cross the road.
# Car 192 arrived and joined the queue at position 17 at time 35.39924774585693
# Car 193 arrived and joined the queue at position 18 at time 35.408938336401086
# Car 194 arrived and joined the queue at position 19 at time 35.45460979680766
# Car 195 arrived and joined the queue at position 20 at time 35.47640092604476
# Car 196 arrived and joined the queue at position 21 at time 35.54764401571143
# Car 197 arrived and joined the queue at position 22 at time 35.566198918423176
# Pedestrians [76] crossed the road at time 35.6078481174408.
# At time 35.61388807843845, pedestrian 80 arrived and started to wait.
# Car 198 arrived and joined the queue at position 23 at time 35.688360773446014
# At time 35.85517568653342 pedestrian 81 arrived at the intersection and started to cross the road.
# Car 199 arrived and joined the queue at position 24 at time 35.98597146320052
# Car 200 arrived and joined the queue at position 25 at time 36.0903319302851
# Car 201 arrived and joined the queue at position 26 at time 36.132695293409164
# Car 202 arrived and joined the queue at position 27 at time 36.250956782682216
# Car 203 arrived and joined the queue at position 28 at time 36.550312067224596
# Car 204 arrived and joined the queue at position 29 at time 36.61914374176449
# Car 205 arrived and joined the queue at position 30 at time 36.725023941463554
# The light turned green at time 36.73333333333333.
# Car 176 departed at time 36.76651468227661, leaving 29 cars in the queue.
# Car 206 arrived and joined the queue at position 30 at time 36.766812125654745
# Car 177 departed at time 36.79886421397975, leaving 29 cars in the queue.
# Car 178 departed at time 36.83149049494119, leaving 28 cars in the queue.
# Car 207 arrived and joined the queue at position 29 at time 36.85974794437838
# Car 179 departed at time 36.86436967253936, leaving 28 cars in the queue.
# Car 180 departed at time 36.89868212323807, leaving 27 cars in the queue.
# Car 181 departed at time 36.931404489307795, leaving 26 cars in the queue.
# Car 208 arrived and joined the queue at position 27 at time 36.95788181034335
# Car 182 departed at time 36.96677294153079, leaving 26 cars in the queue.
# Car 183 departed at time 36.99781313698225, leaving 25 cars in the queue.
# Car 184 departed at time 37.030187268515895, leaving 24 cars in the queue.
# Car 185 departed at time 37.063335938473756, leaving 23 cars in the queue.
# Car 186 departed at time 37.09486075459194, leaving 22 cars in the queue.
# Car 187 departed at time 37.12764354291796, leaving 21 cars in the queue.
# Car 188 departed at time 37.161906959588926, leaving 20 cars in the queue.
# The light turned red at time 37.16666666666666.
# Car 189 departed at time 37.19590910412267, leaving 19 cars in the queue.
# Car 209 arrived and joined the queue at position 20 at time 37.219282601149345
# Car 210 arrived and joined the queue at position 21 at time 37.38271613351927
# Car 211 arrived and joined the queue at position 22 at time 37.4129477814446
# Car 212 arrived and joined the queue at position 23 at time 37.46806619873607
# Pedestrians [80] crossed the road at time 37.477579970212915.
# At time 37.5729873705457, pedestrian 82 arrived and started to wait.
# Car 213 arrived and joined the queue at position 24 at time 37.61674261746431
# Car 214 arrived and joined the queue at position 25 at time 37.720173341923555
# Car 215 arrived and joined the queue at position 26 at time 37.76397636821
# Car 216 arrived and joined the queue at position 27 at time 37.76802388501063
# Car 217 arrived and joined the queue at position 28 at time 37.93137019828027
# Car 218 arrived and joined the queue at position 29 at time 37.932413704909976
# Car 219 arrived and joined the queue at position 30 at time 37.99388719523953
# Car 220 arrived and joined the queue at position 31 at time 38.0935751122306
# Car 221 arrived and joined the queue at position 32 at time 38.4300765936967
# Car 222 arrived and joined the queue at position 33 at time 38.44243667910104
# Car 223 arrived and joined the queue at position 34 at time 38.511092692575474
# Car 224 arrived and joined the queue at position 35 at time 38.514337591495526
# Car 225 arrived and joined the queue at position 36 at time 38.56963894939298
# At time 38.629940774712836 pedestrian 83 arrived at the intersection and started to cross the road.
# The light turned green at time 38.66666666666666.
# Car 226 arrived and joined the queue at position 37 at time 38.697975078858654
# Car 190 departed at time 38.69882562706285, leaving 36 cars in the queue.
# Car 227 arrived and joined the queue at position 37 at time 38.71418564351647
# Car 191 departed at time 38.73289002978315, leaving 36 cars in the queue.
# Car 192 departed at time 38.76849066560516, leaving 35 cars in the queue.
# At time 38.79354596860621, pedestrian 84 arrived and started to wait.
# Car 193 departed at time 38.79873576032125, leaving 34 cars in the queue.
# Car 194 departed at time 38.832422465157805, leaving 33 cars in the queue.
# Car 228 arrived and joined the queue at position 34 at time 38.861128528363714
# Car 195 departed at time 38.866066034112116, leaving 33 cars in the queue.
# Car 196 departed at time 38.89667834618524, leaving 32 cars in the queue.
# Car 197 departed at time 38.93074793085988, leaving 31 cars in the queue.
# Car 198 departed at time 38.96537978194496, leaving 30 cars in the queue.
# Car 199 departed at time 38.9987459678272, leaving 29 cars in the queue.
# Car 200 departed at time 39.03147020011293, leaving 28 cars in the queue.
# Car 201 departed at time 39.06598094554432, leaving 27 cars in the queue.
# Car 202 departed at time 39.097450963878536, leaving 26 cars in the queue.
# The light turned red at time 39.09999999999999.
# Car 203 departed at time 39.130585132695266, leaving 25 cars in the queue.
# Car 229 arrived and joined the queue at position 26 at time 39.29494575249892
# At time 39.31446820383978 pedestrian 85 arrived at the intersection and started to cross the road.
# At time 39.362110446524824 pedestrian 86 arrived at the intersection and started to cross the road.
# Pedestrians [82, 84] crossed the road at time 39.40167962471601.
# Car 230 arrived and joined the queue at position 27 at time 39.451040076123135
# At time 39.49134007200798, pedestrian 87 arrived and started to wait.
# Car 231 arrived and joined the queue at position 28 at time 39.520667059589734
# Car 232 arrived and joined the queue at position 29 at time 39.80806642246056
# Car 233 arrived and joined the queue at position 30 at time 39.935219640368565
# Car 234 arrived and joined the queue at position 31 at time 39.954104594730154
# At time 39.979486083613544 pedestrian 88 arrived at the intersection and started to cross the road.
# Car 235 arrived and joined the queue at position 32 at time 40.47372022725592
# Car 236 arrived and joined the queue at position 33 at time 40.56581946349463
# The light turned green at time 40.59999999999999.
# Car 204 departed at time 40.63347424784756, leaving 32 cars in the queue.
# Car 205 departed at time 40.668196677266494, leaving 31 cars in the queue.
# Car 206 departed at time 40.70402385215958, leaving 30 cars in the queue.
# Car 207 departed at time 40.739355376809485, leaving 29 cars in the queue.
# Car 208 departed at time 40.770250224002254, leaving 28 cars in the queue.
# Car 209 departed at time 40.80222096556692, leaving 27 cars in the queue.
# Car 210 departed at time 40.835161618091256, leaving 26 cars in the queue.
# Car 211 departed at time 40.87079702552007, leaving 25 cars in the queue.
# Car 237 arrived and joined the queue at position 26 at time 40.90272188537947
# Car 212 departed at time 40.90337913886415, leaving 25 cars in the queue.
# Car 238 arrived and joined the queue at position 26 at time 40.925780888132394
# Car 213 departed at time 40.93845628894523, leaving 25 cars in the queue.
# Car 214 departed at time 40.973692148492, leaving 24 cars in the queue.
# Car 239 arrived and joined the queue at position 25 at time 41.00373430556387
# Car 215 departed at time 41.0055791241223, leaving 24 cars in the queue.
# At time 41.00651231727749, pedestrian 89 arrived and started to wait.
# The light turned red at time 41.03333333333332.
# Car 216 departed at time 41.038707005026644, leaving 23 cars in the queue.
# At time 41.04629739350823 pedestrian 90 arrived at the intersection and started to cross the road.
# Car 240 arrived and joined the queue at position 24 at time 41.14639140252891
# Car 241 arrived and joined the queue at position 25 at time 41.15172031381415
# Car 242 arrived and joined the queue at position 26 at time 41.15986974269737
# Car 243 arrived and joined the queue at position 27 at time 41.16817833317663
# At time 41.188407267145905 pedestrian 91 arrived at the intersection and started to cross the road.
# Pedestrians [87, 89] crossed the road at time 41.35173755410838.
# Car 244 arrived and joined the queue at position 28 at time 41.482346166826304
# Car 245 arrived and joined the queue at position 29 at time 41.78337360887992
# At time 41.86172090600419, pedestrian 92 arrived and started to wait.
# Car 246 arrived and joined the queue at position 30 at time 41.93056797602493
# Car 247 arrived and joined the queue at position 31 at time 41.97842969229247
# At time 42.238105732946984 pedestrian 93 arrived at the intersection and started to cross the road.
# At time 42.46296241803596 pedestrian 94 arrived at the intersection and started to cross the road.
# The light turned green at time 42.53333333333332.
# Car 217 departed at time 42.566232548456696, leaving 30 cars in the queue.
# Car 218 departed at time 42.59820264933057, leaving 29 cars in the queue.
# Car 219 departed at time 42.630902394178214, leaving 28 cars in the queue.
# Car 220 departed at time 42.66490384734922, leaving 27 cars in the queue.
# Car 221 departed at time 42.696089011363554, leaving 26 cars in the queue.
# Car 222 departed at time 42.7298013944134, leaving 25 cars in the queue.
# Car 223 departed at time 42.76305936413864, leaving 24 cars in the queue.
# At time 42.78101414560844, pedestrian 95 arrived and started to wait.
# Car 248 arrived and joined the queue at position 25 at time 42.79525711751889
# Car 224 departed at time 42.79557155652672, leaving 24 cars in the queue.
# Car 225 departed at time 42.82843095654357, leaving 23 cars in the queue.
# Car 226 departed at time 42.86161606038372, leaving 22 cars in the queue.
# Car 249 arrived and joined the queue at position 23 at time 42.89052017941028
# Car 227 departed at time 42.89435458140291, leaving 22 cars in the queue.
# ...
# Car 270 departed at time 48.75171589130905, leaving 15 cars in the queue.
# The light turned red at time 48.76666666666664.
# Car 271 departed at time 48.78292832194502, leaving 14 cars in the queue.
# Car 286 arrived and joined the queue at position 15 at time 48.81775301202492
# At time 48.89526860657578 pedestrian 107 arrived at the intersection and started to cross the road.
# At time 48.98370895557457 pedestrian 108 arrived at the intersection and started to cross the road.
# Pedestrians [99, 104, 105, 106] crossed the road at time 49.01351907021762.
# Car 287 arrived and joined the queue at position 16 at time 49.073491450756464
# Car 288 arrived and joined the queue at position 17 at time 49.269239440510056
# Car 289 arrived and joined the queue at position 18 at time 49.34959966080598
# Car 290 arrived and joined the queue at position 19 at time 49.37154861755295
# At time 49.39383845932408, pedestrian 109 arrived and started to wait.
# Car 291 arrived and joined the queue at position 20 at time 49.40089984011434
# Car 292 arrived and joined the queue at position 21 at time 49.49994258063833
# Car 293 arrived and joined the queue at position 22 at time 49.5566206570036
# At time 49.6775225197036 pedestrian 110 arrived at the intersection and started to cross the road.
# Car 294 arrived and joined the queue at position 23 at time 49.75712279728243
# Car 295 arrived and joined the queue at position 24 at time 50.10255269847654
# Car 296 arrived and joined the queue at position 25 at time 50.106425954392336
# The light turned green at time 50.26666666666664.
# Car 272 departed at time 50.29962026631024, leaving 24 cars in the queue.
# Car 273 departed at time 50.333665588013204, leaving 23 cars in the queue.
# Car 274 departed at time 50.36980202950913, leaving 22 cars in the queue.
# At time 50.372717184451396, pedestrian 111 arrived and started to wait.
# Car 275 departed at time 50.404155845369814, leaving 21 cars in the queue.
# Car 297 arrived and joined the queue at position 22 at time 50.40442207681869
# Car 276 departed at time 50.4374927244985, leaving 21 cars in the queue.
# Car 298 arrived and joined the queue at position 22 at time 50.46667756719915
# Car 277 departed at time 50.47034038176572, leaving 21 cars in the queue.
# Car 278 departed at time 50.50366025557649, leaving 20 cars in the queue.
# Car 299 arrived and joined the queue at position 21 at time 50.506534493241645
# Car 279 departed at time 50.537667515229344, leaving 20 cars in the queue.
# Car 300 arrived and joined the queue at position 21 at time 50.54935617545336
# Car 301 arrived and joined the queue at position 22 at time 50.565816998220185
# Car 280 departed at time 50.571083130138256, leaving 21 cars in the queue.
# Car 302 arrived and joined the queue at position 22 at time 50.58877830729254
# At time 50.59942389079429, pedestrian 112 arrived and started to wait.
# At time 50.601357801743745, pedestrian 113 arrived and started to wait.
# Car 281 departed at time 50.60210300327538, leaving 21 cars in the queue.
# Car 282 departed at time 50.635836589472326, leaving 20 cars in the queue.
# Car 283 departed at time 50.66718128769418, leaving 19 cars in the queue.
# At time 50.69971814684193, pedestrian 114 arrived and started to wait.
# The light turned red at time 50.69999999999997.
# Car 284 departed at time 50.702227916659616, leaving 18 cars in the queue.
# Car 303 arrived and joined the queue at position 19 at time 51.05431364125644
# Pedestrians [109, 111, 112, 113, 114] crossed the road at time 51.06172764074427.
# Car 304 arrived and joined the queue at position 20 at time 51.14772231434778
# Car 305 arrived and joined the queue at position 21 at time 51.194820010049
# Car 306 arrived and joined the queue at position 22 at time 51.299943708792256
# At time 51.33552315484211, pedestrian 115 arrived and started to wait.
# Car 307 arrived and joined the queue at position 23 at time 51.652073829275025
# Car 308 arrived and joined the queue at position 24 at time 51.69305976605607
# At time 51.70330153595072 pedestrian 116 arrived at the intersection and started to cross the road.
# At time 51.93584440571742 pedestrian 117 arrived at the intersection and started to cross the road.
# At time 51.93653655957289 pedestrian 118 arrived at the intersection and started to cross the road.
# Car 309 arrived and joined the queue at position 25 at time 51.9697539890602
# Car 310 arrived and joined the queue at position 26 at time 52.02025512943595
# At time 52.078836654401904 pedestrian 119 arrived at the intersection and started to cross the road.
# The light turned green at time 52.19999999999997.
# Car 285 departed at time 52.23314320179224, leaving 25 cars in the queue.
# Car 286 departed at time 52.26818149587696, leaving 24 cars in the queue.
# Car 311 arrived and joined the queue at position 25 at time 52.27830812094278
# Car 287 departed at time 52.30374289009798, leaving 24 cars in the queue.
# Car 288 departed at time 52.33663633582145, leaving 23 cars in the queue.
# Car 289 departed at time 52.372435662309144, leaving 22 cars in the queue.
# At time 52.38554568502675, pedestrian 120 arrived and started to wait.
# Car 290 departed at time 52.40695177126846, leaving 21 cars in the queue.
# Car 291 departed at time 52.439284578253954, leaving 20 cars in the queue.
# Car 292 departed at time 52.47147778625921, leaving 19 cars in the queue.
# Car 293 departed at time 52.50339871094696, leaving 18 cars in the queue.
# Car 294 departed at time 52.53875521740481, leaving 17 cars in the queue.
# Car 295 departed at time 52.5713115892365, leaving 16 cars in the queue.
# Car 296 departed at time 52.604484720341574, leaving 15 cars in the queue.
# The light turned red at time 52.6333333333333.
# Car 297 departed at time 52.63779785190481, leaving 14 cars in the queue.
# Car 312 arrived and joined the queue at position 15 at time 52.913045807005325
# At time 52.94857208617115 pedestrian 121 arrived at the intersection and started to cross the road.
# Pedestrians [115, 120] crossed the road at time 52.96116036014934.
# At time 53.023444694248674, pedestrian 122 arrived and started to wait.
# Car 313 arrived and joined the queue at position 16 at time 53.15817757327411
# At time 53.30179602703319 pedestrian 123 arrived at the intersection and started to cross the road.
# Car 314 arrived and joined the queue at position 17 at time 53.40214644407408
# Car 315 arrived and joined the queue at position 18 at time 53.41639051794889
# Car 316 arrived and joined the queue at position 19 at time 53.43880971129541
# Car 317 arrived and joined the queue at position 20 at time 53.486624492703626
# Car 318 arrived and joined the queue at position 21 at time 53.49695360795418
# Car 319 arrived and joined the queue at position 22 at time 53.56983098600873
# Car 320 arrived and joined the queue at position 23 at time 53.584841615896735
# Car 321 arrived and joined the queue at position 24 at time 53.695559666527714
# Car 322 arrived and joined the queue at position 25 at time 53.732881924564424
# Car 323 arrived and joined the queue at position 26 at time 53.85250919450438
# Car 324 arrived and joined the queue at position 27 at time 53.868991729211004
# The light turned green at time 54.1333333333333.
# At time 54.15376183068824, pedestrian 124 arrived and started to wait.
# Car 298 departed at time 54.168775810507164, leaving 26 cars in the queue.
# Car 299 departed at time 54.201134709557586, leaving 25 cars in the queue.
# Car 300 departed at time 54.23441222058885, leaving 24 cars in the queue.
# Car 301 departed at time 54.2653549447962, leaving 23 cars in the queue.
# Car 302 departed at time 54.29919202612252, leaving 22 cars in the queue.
# Car 303 departed at time 54.33220423427653, leaving 21 cars in the queue.
# Car 325 arrived and joined the queue at position 22 at time 54.36005432471511
# Car 304 departed at time 54.365100233710955, leaving 21 cars in the queue.
# Car 305 departed at time 54.399224091170744, leaving 20 cars in the queue.
# At time 54.402385065764165, pedestrian 125 arrived and started to wait.
# Car 306 departed at time 54.43488338298047, leaving 19 cars in the queue.
# Car 307 departed at time 54.470041133661326, leaving 18 cars in the queue.
# Car 308 departed at time 54.50444686240192, leaving 17 cars in the queue.
# Car 309 departed at time 54.53726515444418, leaving 16 cars in the queue.
# The light turned red at time 54.56666666666663.
# Car 310 departed at time 54.571032263429835, leaving 15 cars in the queue.
# Car 326 arrived and joined the queue at position 16 at time 54.578554169518206
# At time 54.61926816235091 pedestrian 126 arrived at the intersection and started to cross the road.
# At time 54.67890059479444 pedestrian 127 arrived at the intersection and started to cross the road.
# At time 54.798304875303494 pedestrian 128 arrived at the intersection and started to cross the road.
# Pedestrians [122, 124, 125] crossed the road at time 54.84664143769992.
# Car 327 arrived and joined the queue at position 17 at time 54.85206250626661
# At time 54.89938334236961, pedestrian 129 arrived and started to wait.
# Car 328 arrived and joined the queue at position 18 at time 54.920072913238016
# Car 329 arrived and joined the queue at position 19 at time 55.0187454490975
# Car 330 arrived and joined the queue at position 20 at time 55.106915407500544
# Car 331 arrived and joined the queue at position 21 at time 55.10698740352824
# Car 332 arrived and joined the queue at position 22 at time 55.180034162011886
# Car 333 arrived and joined the queue at position 23 at time 55.188690757884956
# Car 334 arrived and joined the queue at position 24 at time 55.21947564747765
# Car 335 arrived and joined the queue at position 25 at time 55.57464224629888
# At time 55.58308620243732 pedestrian 130 arrived at the intersection and started to cross the road.
# Car 336 arrived and joined the queue at position 26 at time 55.60662223874164
# Car 337 arrived and joined the queue at position 27 at time 55.82072094783005
# Car 338 arrived and joined the queue at position 28 at time 55.84357261071481
# Car 339 arrived and joined the queue at position 29 at time 55.96626640888497
# Car 340 arrived and joined the queue at position 30 at time 55.98247080741527
# The light turned green at time 56.06666666666663.
# Car 311 departed at time 56.10049495459955, leaving 29 cars in the queue.
# Car 312 departed at time 56.13375884644616, leaving 28 cars in the queue.
# Car 341 arrived and joined the queue at position 29 at time 56.1540574428743
# Car 342 arrived and joined the queue at position 30 at time 56.16072929188491
# Car 313 departed at time 56.169050038147056, leaving 29 cars in the queue.
# Car 314 departed at time 56.2032003255695, leaving 28 cars in the queue.
# Car 343 arrived and joined the queue at position 29 at time 56.20641837588546
# Car 344 arrived and joined the queue at position 30 at time 56.23145244007544
# Car 315 departed at time 56.236248491545396, leaving 29 cars in the queue.
# Car 345 arrived and joined the queue at position 30 at time 56.24640296273452
# Car 316 departed at time 56.270900429730005, leaving 29 cars in the queue.
# Car 317 departed at time 56.30594971629237, leaving 28 cars in the queue.
# Car 346 arrived and joined the queue at position 29 at time 56.33088520010906
# Car 318 departed at time 56.3401818587496, leaving 28 cars in the queue.
# Car 319 departed at time 56.37306287328602, leaving 27 cars in the queue.
# Car 347 arrived and joined the queue at position 28 at time 56.400383619118
# Car 320 departed at time 56.406448748539525, leaving 27 cars in the queue.
# Car 321 departed at time 56.44069916733312, leaving 26 cars in the queue.
# Car 322 departed at time 56.47103756106399, leaving 25 cars in the queue.
# The light turned red at time 56.49999999999996.
# Car 323 departed at time 56.50509721944685, leaving 24 cars in the queue.
# At time 56.560240597210885 pedestrian 131 arrived at the intersection and started to cross the road.
# Car 348 arrived and joined the queue at position 25 at time 56.690254183426106
# Car 349 arrived and joined the queue at position 26 at time 56.715936121380544
# Car 350 arrived and joined the queue at position 27 at time 56.8030403937761
# Car 351 arrived and joined the queue at position 28 at time 56.82297233080844
# Pedestrians [129] crossed the road at time 56.84989753392811.
# Car 352 arrived and joined the queue at position 29 at time 56.88160104725827
# At time 57.17996418557798, pedestrian 132 arrived and started to wait.
# Car 353 arrived and joined the queue at position 30 at time 57.24631533899631
# Car 354 arrived and joined the queue at position 31 at time 57.29014358404316
# Car 355 arrived and joined the queue at position 32 at time 57.34484869266781
# Car 356 arrived and joined the queue at position 33 at time 57.46571653061606
# Car 357 arrived and joined the queue at position 34 at time 57.90105444646203
# Car 358 arrived and joined the queue at position 35 at time 57.92213929017093
# Car 359 arrived and joined the queue at position 36 at time 57.961286809821374
# The light turned green at time 57.99999999999996.
# Car 324 departed at time 58.03330619698175, leaving 35 cars in the queue.
# Car 325 departed at time 58.06533662056932, leaving 34 cars in the queue.
# Car 326 departed at time 58.09878068851746, leaving 33 cars in the queue.
# Car 327 departed at time 58.13147335193517, leaving 32 cars in the queue.
# Car 328 departed at time 58.164125573477335, leaving 31 cars in the queue.
# Car 329 departed at time 58.19727685880221, leaving 30 cars in the queue.
# Car 330 departed at time 58.230379106908565, leaving 29 cars in the queue.
# Car 360 arrived and joined the queue at position 30 at time 58.23391317295137
# Car 331 departed at time 58.2631970923185, leaving 29 cars in the queue.
# Car 332 departed at time 58.29742219384704, leaving 28 cars in the queue.
# Car 333 departed at time 58.331628268856456, leaving 27 cars in the queue.
# Car 334 departed at time 58.36416648104263, leaving 26 cars in the queue.
# Car 335 departed at time 58.39776977783036, leaving 25 cars in the queue.
# Car 336 departed at time 58.43222124163851, leaving 24 cars in the queue.
# The light turned red at time 58.43333333333329.
# At time 58.46392557154969 pedestrian 133 arrived at the intersection and started to cross the road.
# Car 337 departed at time 58.466756609111115, leaving 23 cars in the queue.
# Car 361 arrived and joined the queue at position 24 at time 58.55885072637555
# Pedestrians [132] crossed the road at time 58.7191747445839.
# Car 362 arrived and joined the queue at position 25 at time 58.73437419992268
# Car 363 arrived and joined the queue at position 26 at time 58.754488822795516
# Car 364 arrived and joined the queue at position 27 at time 59.019409041321545
# Car 365 arrived and joined the queue at position 28 at time 59.09615991001984
# Car 366 arrived and joined the queue at position 29 at time 59.18400452987604
# At time 59.200664462335354, pedestrian 134 arrived and started to wait.
# Car 367 arrived and joined the queue at position 30 at time 59.262429049995106
# Car 368 arrived and joined the queue at position 31 at time 59.390395149605176
# Car 369 arrived and joined the queue at position 32 at time 59.48129593675298
# At time 59.62015110043531 pedestrian 135 arrived at the intersection and started to cross the road.
# Car 370 arrived and joined the queue at position 33 at time 59.74704787888431
# Car 371 arrived and joined the queue at position 34 at time 59.81470584975737
# Car 372 arrived and joined the queue at position 35 at time 59.885769225620614
# The light turned green at time 59.93333333333329.
# Car 338 departed at time 59.966114987288705, leaving 34 cars in the queue.
# Car 339 departed at time 59.997263737218034, leaving 33 cars in the queue.
#
#
#       *** Statistics( random seed=0) ***
#  ( Baseline model with 20.0% distracted drivers)
#
#
# Vehicle stats:
#
# Number of vehicles waiting in queue per minute: 19.333333333333332
# Average waiting time for a vehicle (minutes): 3.264308314567652
#
#
# Pedestrian stats:
#
# Number of pedestrians waiting to cross per minute: 1.0166666666666666
# Average waiting time for a pedestrian (minutes): 0.43405908646128827
